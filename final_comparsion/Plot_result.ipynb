# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm

file_path = 'eval_rewards - sheet1.csv'
data = pd.read_csv(file_path)
plt.figure(figsize=(12, 8))

colors = cm.tab10.colors
x = data['Day Number']
y_values = data.columns[1:]
for i, y in enumerate(y_values):
    plt.plot(
        x, data[y],
        label=y,
        color=colors[i % len(colors)],
        linestyle='-',
        linewidth=2
    )

plt.xlabel('Day Number', fontsize=14)
plt.ylabel('Reward Values', fontsize=14)
plt.title('Reward Over Time', fontsize=16, fontweight='bold')
plt.legend(fontsize=12, loc='upper left')
plt.grid(alpha=0.5, linestyle='--')

plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm

file_path = 'eval_net - eval_net_transformer (2).csv'
data = pd.read_csv(file_path)
plt.figure(figsize=(12, 8))

colors = cm.tab10.colors
x = data['Day Number']
y_values = data.columns[1:]
for i, y in enumerate(y_values):
    plt.plot(
        x, data[y],
        label=y,
        color=colors[i % len(colors)],
        linestyle='-',
        linewidth=2
    )

plt.xlabel('Day Number', fontsize=14)
plt.ylabel('Net Portfolio Values', fontsize=14)
plt.title('Net Portfolio Values Over Time', fontsize=16, fontweight='bold')
plt.legend(fontsize=12, loc='upper left')
plt.grid(alpha=0.5, linestyle='--')

plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.show()
