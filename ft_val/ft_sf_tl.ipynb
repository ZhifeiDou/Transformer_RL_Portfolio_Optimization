# %%
# !pip install tushare
import tushare as ts
# !pip install alpha_vantage
from alpha_vantage.timeseries import TimeSeries
import requests
import pandas as pd
#!pip install -U "ray[default]"
# !pip install gymnasium
#!pip install 'ray[rllib]'
# !pip install 'ray[all]'
import gymnasium
from gymnasium import spaces
import ray
from ray import tune
from ray.rllib.algorithms.ppo import PPO
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
from ray.rllib.models.torch.torch_modelv2 import TorchModelV2
from ray.rllib.models.modelv2 import ModelV2
from ray.rllib.utils.annotations import override
from ray.rllib.models import ModelCatalog
from ray.rllib.models.torch.misc import SlimFC
import math
from collections import deque
from datetime import datetime, timedelta
from os import close
from ray.rllib.algorithms import ppo
from ray.rllib.algorithms.ppo import PPO  # Import PPOTrainer
from ray.rllib.algorithms.ppo import PPOConfig
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import ray
from ray import tune
from ray.rllib.algorithms.ppo import PPO
from ray.rllib.models.torch.torch_modelv2 import TorchModelV2
from ray.rllib.models.modelv2 import ModelV2
from ray.rllib.utils.annotations import override
from ray.rllib.models import ModelCatalog
from ray.rllib.models.torch.misc import SlimFC
from ray.rllib.algorithms import ppo
from ray.rllib.algorithms.ppo import PPO
from ray.rllib.algorithms.ppo import PPOConfig
from ray.rllib.algorithms.callbacks import DefaultCallbacks
from ray.rllib.env import EnvContext
from ray.tune.registry import register_env
np.random.seed(135)
torch.manual_seed(135)
# Out:
# Requirement already satisfied: tushare in /usr/local/lib/python3.10/dist-packages (1.4.13)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from tushare) (2.2.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from tushare) (2.32.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from tushare) (5.3.0)
# Requirement already satisfied: simplejson in /usr/local/lib/python3.10/dist-packages (from tushare) (3.19.3)
# Requirement already satisfied: bs4 in /usr/local/lib/python3.10/dist-packages (from tushare) (0.0.2)
# Requirement already satisfied: websocket-client>=0.57.0 in /usr/local/lib/python3.10/dist-packages (from tushare) (1.8.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from tushare) (4.66.6)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4->tushare) (4.12.3)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas->tushare) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->tushare) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->tushare) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->tushare) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->tushare) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->tushare) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->tushare) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->tushare) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->tushare) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4->tushare) (2.6)
# Requirement already satisfied: alpha_vantage in /usr/local/lib/python3.10/dist-packages (3.0.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from alpha_vantage) (3.11.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from alpha_vantage) (2.32.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->alpha_vantage) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->alpha_vantage) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->alpha_vantage) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->alpha_vantage) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->alpha_vantage) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->alpha_vantage) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->alpha_vantage) (1.17.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->alpha_vantage) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->alpha_vantage) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->alpha_vantage) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->alpha_vantage) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->alpha_vantage) (2024.8.30)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from multidict<7.0,>=4.5->aiohttp->alpha_vantage) (4.12.2)
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.10/dist-packages (1.0.0)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (3.1.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: ray[all] in /usr/local/lib/python3.10/dist-packages (2.39.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from ray[all]) (8.1.7)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from ray[all]) (3.16.1)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from ray[all]) (4.23.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ray[all]) (1.1.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from ray[all]) (24.2)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /usr/local/lib/python3.10/dist-packages (from ray[all]) (5.28.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from ray[all]) (6.0.2)
# Requirement already satisfied: aiosignal in /usr/local/lib/python3.10/dist-packages (from ray[all]) (1.3.1)
# Requirement already satisfied: frozenlist in /usr/local/lib/python3.10/dist-packages (from ray[all]) (1.5.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from ray[all]) (2.32.3)
# Requirement already satisfied: grpcio in /usr/local/lib/python3.10/dist-packages (from ray[all]) (1.68.0)
# Requirement already satisfied: opentelemetry-exporter-otlp in /usr/local/lib/python3.10/dist-packages (from ray[all]) (1.28.2)
# Requirement already satisfied: prometheus-client>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from ray[all]) (0.21.0)
# Requirement already satisfied: opentelemetry-api in /usr/local/lib/python3.10/dist-packages (from ray[all]) (1.28.2)
# Requirement already satisfied: typer in /usr/local/lib/python3.10/dist-packages (from ray[all]) (0.13.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from ray[all]) (13.9.4)
# Requirement already satisfied: gymnasium==1.0.0 in /usr/local/lib/python3.10/dist-packages (from ray[all]) (1.0.0)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.10/dist-packages (from ray[all]) (0.1.8)
# Requirement already satisfied: opentelemetry-sdk in /usr/local/lib/python3.10/dist-packages (from ray[all]) (1.28.2)
# Requirement already satisfied: aiohttp>=3.7 in /usr/local/lib/python3.10/dist-packages (from ray[all]) (3.11.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from ray[all]) (2024.10.0)
# Requirement already satisfied: pyOpenSSL in /usr/local/lib/python3.10/dist-packages (from ray[all]) (24.2.1)
# Requirement already satisfied: lz4 in /usr/local/lib/python3.10/dist-packages (from ray[all]) (4.3.3)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from ray[all]) (0.24.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from ray[all]) (2.2.2)
# Requirement already satisfied: fastapi in /usr/local/lib/python3.10/dist-packages (from ray[all]) (0.115.5)
# Requirement already satisfied: smart-open in /usr/local/lib/python3.10/dist-packages (from ray[all]) (7.0.5)
# Requirement already satisfied: py-spy>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ray[all]) (0.4.0)
# Requirement already satisfied: virtualenv!=20.21.1,>=20.0.24 in /usr/local/lib/python3.10/dist-packages (from ray[all]) (20.27.1)
# Requirement already satisfied: colorful in /usr/local/lib/python3.10/dist-packages (from ray[all]) (0.5.6)
# Requirement already satisfied: pyarrow>=6.0.1 in /usr/local/lib/python3.10/dist-packages (from ray[all]) (17.0.0)
# Requirement already satisfied: pydantic!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,<3 in /usr/local/lib/python3.10/dist-packages (from ray[all]) (2.9.2)
# Requirement already satisfied: aiohttp-cors in /usr/local/lib/python3.10/dist-packages (from ray[all]) (0.7.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from ray[all]) (1.13.1)
# Requirement already satisfied: tensorboardX>=1.9 in /usr/local/lib/python3.10/dist-packages (from ray[all]) (2.6.2.2)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from ray[all]) (1.26.4)
# Requirement already satisfied: opencensus in /usr/local/lib/python3.10/dist-packages (from ray[all]) (0.11.4)
# Requirement already satisfied: starlette in /usr/local/lib/python3.10/dist-packages (from ray[all]) (0.41.3)
# Requirement already satisfied: watchfiles in /usr/local/lib/python3.10/dist-packages (from ray[all]) (0.24.0)
# Requirement already satisfied: uvicorn[standard] in /usr/local/lib/python3.10/dist-packages (from ray[all]) (0.32.1)
# Requirement already satisfied: cupy-cuda12x in /usr/local/lib/python3.10/dist-packages (from ray[all]) (12.2.0)
# Requirement already satisfied: memray in /usr/local/lib/python3.10/dist-packages (from ray[all]) (1.14.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium==1.0.0->ray[all]) (3.1.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium==1.0.0->ray[all]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium==1.0.0->ray[all]) (0.0.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.7->ray[all]) (2.4.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.7->ray[all]) (24.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.7->ray[all]) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.7->ray[all]) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.7->ray[all]) (1.17.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.7->ray[all]) (4.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->ray[all]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->ray[all]) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->ray[all]) (2024.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,<3->ray[all]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,<3->ray[all]) (2.23.4)
# Requirement already satisfied: distlib<1,>=0.3.7 in /usr/local/lib/python3.10/dist-packages (from virtualenv!=20.21.1,>=20.0.24->ray[all]) (0.3.9)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in /usr/local/lib/python3.10/dist-packages (from virtualenv!=20.21.1,>=20.0.24->ray[all]) (4.3.6)
# Requirement already satisfied: fastrlock>=0.5 in /usr/local/lib/python3.10/dist-packages (from cupy-cuda12x->ray[all]) (0.8.2)
# Requirement already satisfied: anyio<5,>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from starlette->ray[all]) (3.7.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray[all]) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray[all]) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray[all]) (0.21.0)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from memray->ray[all]) (3.1.4)
# Requirement already satisfied: textual>=0.41.0 in /usr/local/lib/python3.10/dist-packages (from memray->ray[all]) (0.86.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->ray[all]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->ray[all]) (2.18.0)
# Requirement already satisfied: opencensus-context>=0.1.3 in /usr/local/lib/python3.10/dist-packages (from opencensus->ray[all]) (0.1.3)
# Requirement already satisfied: six~=1.16 in /usr/local/lib/python3.10/dist-packages (from opencensus->ray[all]) (1.16.0)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from opencensus->ray[all]) (2.19.2)
# Requirement already satisfied: deprecated>=1.2.6 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-api->ray[all]) (1.2.15)
# Requirement already satisfied: importlib-metadata<=8.5.0,>=6.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-api->ray[all]) (8.5.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc==1.28.2 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp->ray[all]) (1.28.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http==1.28.2 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp->ray[all]) (1.28.2)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-grpc==1.28.2->opentelemetry-exporter-otlp->ray[all]) (1.66.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.28.2 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-grpc==1.28.2->opentelemetry-exporter-otlp->ray[all]) (1.28.2)
# Requirement already satisfied: opentelemetry-proto==1.28.2 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-grpc==1.28.2->opentelemetry-exporter-otlp->ray[all]) (1.28.2)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.49b2 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-sdk->ray[all]) (0.49b2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->ray[all]) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->ray[all]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->ray[all]) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->ray[all]) (2024.8.30)
# Requirement already satisfied: cryptography<44,>=41.0.5 in /usr/local/lib/python3.10/dist-packages (from pyOpenSSL->ray[all]) (43.0.3)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.10/dist-packages (from scikit-image->ray[all]) (3.4.2)
# Requirement already satisfied: pillow>=9.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->ray[all]) (11.0.0)
# Requirement already satisfied: imageio>=2.33 in /usr/local/lib/python3.10/dist-packages (from scikit-image->ray[all]) (2.36.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image->ray[all]) (2024.9.20)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image->ray[all]) (0.4)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open->ray[all]) (1.16.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer->ray[all]) (1.5.4)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]; extra == "all"->ray[all]) (0.14.0)
# Requirement already satisfied: httptools>=0.6.3 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]; extra == "all"->ray[all]) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]; extra == "all"->ray[all]) (1.0.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]; extra == "all"->ray[all]) (0.21.0)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]; extra == "all"->ray[all]) (14.1)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette->ray[all]) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette->ray[all]) (1.2.2)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography<44,>=41.0.5->pyOpenSSL->ray[all]) (1.17.1)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[all]) (1.25.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in /usr/local/lib/python3.10/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[all]) (2.27.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata<=8.5.0,>=6.0->opentelemetry-api->ray[all]) (3.21.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9->memray->ray[all]) (3.0.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->ray[all]) (0.1.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography<44,>=41.0.5->pyOpenSSL->ray[all]) (2.22)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[all]) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[all]) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[all]) (4.9)
# Requirement already satisfied: linkify-it-py<3,>=1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py[linkify,plugins]>=2.1.0->textual>=0.41.0->memray->ray[all]) (2.0.3)
# Requirement already satisfied: mdit-py-plugins in /usr/local/lib/python3.10/dist-packages (from markdown-it-py[linkify,plugins]>=2.1.0->textual>=0.41.0->memray->ray[all]) (0.4.2)
# Requirement already satisfied: uc-micro-py in /usr/local/lib/python3.10/dist-packages (from linkify-it-py<3,>=1->markdown-it-py[linkify,plugins]>=2.1.0->textual>=0.41.0->memray->ray[all]) (1.0.3)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[all]) (0.6.1)

# %% [markdown]
# Setup Env

# %%
class PortfolioOptimizationEnv(gymnasium.Env):
    '''
    Environment setting with OpenAI

    Assumptions:
    1. In this case, the team has loose the constrain of 24 hours holding period. Once a person buy in the stock, the person can sell it immediately
    2. We have simplified the buy order mechanism so that stocks can be bought at the closing price of the day in this environment.

    State: A stack of stock price data, stock index data, current stock volums, current cash amount
    Observation: Same with state but in a 365 trading days duration
    Action: A float list with a length of N (number of stocks chosen) which elements are within range (-1,1). When positive -> buy Ni * cash amount of stock i. When negtive -> sell Ni present of stocki's volume

    '''

    def __init__(self,env_config):
        super(PortfolioOptimizationEnv, self).__init__()
        try:
            self.history_length = env_config['history_length']
            self.start = env_config['start']                        #define start date
            self.end = env_config['end']                            #define end date
            self.market = env_config['market']                      #define market -> currently only China
            self.n_stock = env_config['n_stock']                    #define the number of stock chosen
            self.cash = env_config['cash']                          #define the initial cash we take into the market
            self.smoothing_factor = env_config['smoothing_factor']  #define smooth for the DSR reward function

            self.market_data = self.load_market_data(self.start, self.end, self.market)         #Initialize market data during the start to end -> execute once to shorten running time
            self.close_data = self.load_full_close_data(self.start, self.end, self.market)      #Initialize close data

            self.stock_tensor_length = self.market_data.shape[1] - 1                                    #See observation_space
            self.date_list = self.load_trading_days(self.start, self.end, self.market)                  #Filter trading days from the period
            self.action_space = spaces.Box(low=-1, high=1, shape=(self.n_stock,), dtype=np.float32)     #define action space, please see 'Action' in the class comment for detail
            self.observation_space = spaces.Box(                                                        #define observation space as required by Rllib, the observation space have to be a flattened np list
                low=-np.inf, high=np.inf,                                                               #Thus the dimension is calcualted as shape
                shape=(self.history_length * (self.stock_tensor_length + self.n_stock + 1 + self.n_stock + 1),),
                dtype=np.float32
            )

            self.state_buffer = deque(maxlen=self.history_length)           #define state deque
            self.initial_cash = np.float32(self.cash)                       #define cash buffer
            self.stock_volume = np.zeros(self.n_stock, dtype=np.float32)    #define stock volume recorder

            self.A_t = np.float32(0.0)
            self.B_t = np.float32(0.0)
            self.Previous_A_t = np.float32(0.0)
            self.Previous_B_t = np.float32(0.0)                             #define reward parameters
            self.net_price = np.array([], dtype=np.float32)                 #define net price loader
            self.current_step = 0                                           #define step recorder

        except Exception as e:
            print("Error during initialization:", e)
            raise


    def step(self, action):
        '''
        Step function, step forward according to policy model's return
        '''

        self.current_step += 1
        next_date = self.date_list[self.current_step]
        action = self.normalize_action(action)
        reward = self.calculate_reward(action, next_date)

        next_state = self.get_state(self.current_step, action,  reward, next_date)
        stacked_state = np.array(self.state_buffer).flatten().astype(np.float32)
        stacked_state = np.nan_to_num(stacked_state, nan=1e-8, posinf=999999, neginf=-999999)

        done = self.net_price[-1] <= 0
        turncated = self.current_step >= len(self.date_list) - 1
        info = {
                "net_price": self.net_price[-1],  # Pass the current net price
                "cash": self.cash,  # Example: Pass cash if needed
            }

        '''log monitoring -> comment back when needed
        if self.current_step % 100 == 0:
          print('-------------------------------------------------')
          print(f'The net price is: {self.net_price[-1]}')
          print(f'The current step is: {self.current_step}')
          print(f'The cash is :{self.cash}')
          print(f'The stock volume is :{self.stock_volume}')
          print(f'The actions are: {action}')
        '''


        return stacked_state, reward, done, turncated, info




    def reset(self, seed = None, options = None):
        '''
        Reset function, reset the environment when an episode is done
        '''
        if seed is not None:
          np.random.seed(seed)
          torch.manual_seed(seed)
        self.state_buffer = deque(maxlen=self.history_length)
        self.cash = self.initial_cash
        self.stock_volume = np.zeros_like(self.stock_volume)
        self.A_t = np.float32(0.0)
        self.B_t = np.float32(0.0)
        self.Previous_A_t = np.float32(0.0)
        self.Previous_B_t = np.float32(0.0)
        self.net_price = np.zeros(self.history_length, dtype=np.float32)
        self.current_step = self.history_length

        self.date_list = self.load_trading_days(self.start, self.end, self.market)
        first_365_days = self.date_list[:self.history_length]

        for idx, date in enumerate(first_365_days):
            dummy_action = np.zeros(self.action_space.shape, dtype=np.float32)
            dummy_reward = 0.0
            next_state = self.get_state(idx, dummy_action, dummy_reward, date)

        stacked_state = np.array(self.state_buffer).flatten()
        stacked_state = stacked_state.astype(np.float32)
        stacked_state = np.nan_to_num(stacked_state, nan=1e-8, posinf=999999, neginf=-999999)
        return stacked_state, {}




    def get_state(self, idx, action, reward, date):
        '''
        Obtain state and return to step function
        '''
        stock_data_current = self.market_data[self.market_data['trade_date'] == date].iloc[0].drop(['trade_date']).values
        reward_array = np.array([reward], dtype=np.float32)
        net_price_current = np.array([self.net_price[self.current_step-1]], dtype=np.float32)
        full_state = np.concatenate([stock_data_current, action, reward_array, self.stock_volume, net_price_current])
        date_encodings = self.calculate_date_encoding(idx, full_state.shape[0])
        full_state_with_encoding = full_state + date_encodings
        self.state_buffer.append(full_state_with_encoding)
        return full_state_with_encoding



    def load_trading_days(self, start, end, market):
        '''
        Filter trading days
        '''
        if market == 'CHINA':
            ts.set_token('28b2dbb3562598167a7ae7929457748793ba2c1fb2f47d4542ac6b8b')
            pro = ts.pro_api()
            trade_cal = pro.trade_cal(exchange = '',start_date = start, end_date = end)
            trade_cal = trade_cal[trade_cal['is_open'] == 1]
            trading_dates = trade_cal['cal_date'].tolist()
            return trading_dates
        elif market == 'US':
            raise ValueError('Not support yet')
        else:
            raise ValueError('Invalid market type')




    def load_full_close_data(self, start, end, market='CHINA'):
        '''
        Load close price , the close price is loaded separately for calculating cumulative return and net price
        The close price in the "load_market_data" function has been normalized; thus need to load separately
        '''
        if market == 'CHINA':
            ts.set_token('28b2dbb3562598167a7ae7929457748793ba2c1fb2f47d4542ac6b8b')
            pro = ts.pro_api()
            stock_codes = ['601318.SH', '601398.SH', '600519.SH', '000001.SZ', '601857.SH']
            df_close = pd.DataFrame()

            for code in stock_codes:
                df = pro.daily(ts_code=code, start_date=start, end_date=end)
                df = df[['trade_date', 'close']]
                df_renamed = df.rename(columns={'close': f"close_{code.split('.')[0]}"})

                if df_close.empty:
                    df_close = df_renamed
                else:
                    df_close = pd.merge(df_close, df_renamed, on='trade_date', how='outer')

            df_close.sort_values('trade_date', inplace=True)
            return df_close

        elif market == 'US':
            raise ValueError('Not support yet')
        else:
            raise ValueError('Invalid market type')



    def load_close_data(self, date):
            '''
            Load close price for a specific day
            '''
            data_on_date = self.close_data[self.close_data['trade_date'] == date]
            close_columns = [col for col in data_on_date.columns if 'close_' in col]
            close_array = data_on_date[close_columns].values.flatten().astype(np.float32)
            return close_array



    def load_market_data(self, start, end, market='CHINA'):
        '''
        Load the market data and normalize it
        '''
        if market == 'CHINA':
            ts.set_token('28b2dbb3562598167a7ae7929457748793ba2c1fb2f47d4542ac6b8b')
            pro = ts.pro_api()

            stock_codes = ['601318.SH', '601398.SH', '600519.SH', '000001.SZ', '601857.SH']
            Full_CHINA_STOCK_df = pd.DataFrame()

            for code in stock_codes:
                df = pro.daily(ts_code=code, start_date=start, end_date=end)
                adj_factors = pro.adj_factor(ts_code=code, start_date=start, end_date=end)
                daily_basic = pro.daily_basic(ts_code=code, start_date=start, end_date=end)
                daily_basic = daily_basic.drop(columns=['close'])

                df = pd.merge(df, adj_factors[['trade_date', 'adj_factor']], on='trade_date', how='left')
                df['close_adj'] = df['close'] / df['adj_factor']
                df['open_adj'] = df['open'] / df['adj_factor']
                df['high_adj'] = df['high'] / df['adj_factor']
                df['low_adj'] = df['low'] / df['adj_factor']
                df['close_price'] = df['close']
                df = pd.merge(df, daily_basic, on='trade_date', how='left')
                df = df.drop(columns=['adj_factor', 'ts_code_x','ts_code_y','close'])
                df_renamed = df.rename(columns=lambda x: f"{x}_{code.split('.')[0]}" if x != 'trade_date' else x)

                if Full_CHINA_STOCK_df.empty:
                    Full_CHINA_STOCK_df = df_renamed
                else:
                    Full_CHINA_STOCK_df = pd.merge(Full_CHINA_STOCK_df, df_renamed, on='trade_date', how='outer')

            Full_CHINA_STOCK_df.sort_values('trade_date', inplace=True)
            columns_to_normalize = [col for col in Full_CHINA_STOCK_df.columns if col != 'trade_date']
            scaler = MinMaxScaler()
            Full_CHINA_STOCK_df[columns_to_normalize] = scaler.fit_transform(Full_CHINA_STOCK_df[columns_to_normalize])

            return Full_CHINA_STOCK_df

        elif market == 'US':
            raise ValueError('Not support yet')
        else:
            raise ValueError('Invalid market type')



    def calculate_date_encoding(self, idx, embedding_dimension):
        '''
        Add date encoding to the data according to the paper "Attention is all you need" by Vaswani et al.
        But somehow it also works on our value function which is a LSTM setting in this case. Need further investigate

        Also. there are two possible method to implement this embedding, one put it here follow the instruction in 'attention is all you need',
        two you can put it within the model to make it trainable parameters, we will investigate on this
        '''
        encoding = []
        for i in range(embedding_dimension):
            if i % 2 == 0:
                value = np.sin(idx / (10000 ** (i / embedding_dimension)))
            else:
                value = np.cos(idx / (10000 ** (i / embedding_dimension)))
            encoding.append(value)
        return np.array(encoding, dtype=np.float32)




    def calculate_reward(self, action, date):
        '''
        Implement Differencial Sharpe Ratio (DSR) as the reward function to take in consideration of the risk
        '''

        portfolio_return = self.get_portfolio_return(action, date)
        self.Previous_A_t = self.A_t.copy()
        self.Previous_B_t = self.B_t.copy()
        self.A_t = (1 - self.smoothing_factor) * self.A_t + self.smoothing_factor * portfolio_return
        self.B_t = (1 - self.smoothing_factor) * self.B_t + self.smoothing_factor * (portfolio_return ** 2)

        delta_A_t = self.A_t - self.Previous_A_t
        delta_B_t = self.B_t - self.Previous_B_t

        if self.Previous_B_t - (self.Previous_A_t ** 2) > 0:
            denom = (self.Previous_B_t - (self.Previous_A_t ** 2)) ** 1.5
            numer = self.Previous_B_t * delta_A_t - 0.5 * self.Previous_A_t * delta_B_t
            DSR = numer / denom
        else:
            DSR = 0
        return DSR



    def calculate_net_price(self, action, date):
        '''
        Calcualte the net price for a day
        '''
        close_values = self.load_close_data(date)
        for idx, act in enumerate(action):
            if act > 0:
                self.stock_volume[idx] += (self.cash * act) / close_values[idx]
                self.cash -= self.cash * act
            elif act < 0:
                self.cash += (-act) * self.stock_volume[idx] * close_values[idx]
                self.stock_volume[idx] += self.stock_volume[idx] * act
        net_price_value = self.cash + np.sum(self.stock_volume * close_values)
        self.net_price = np.append(self.net_price, net_price_value)
        return net_price_value



    def get_portfolio_return(self, action, date):
        '''
        Calcualte the return for a day
        '''
        current_price = self.calculate_net_price(action, date)
        last_day = self.current_step - 2
        previous_price = self.net_price[last_day]
        return np.float32(current_price - previous_price)



    def normalize_action(self, action):
        '''
        Since the positive action sampled from the policy model does not always sum up to 1 which represent over 100% of the cash, thus we needs to normalize it
        '''
        positive_mask = (action >= 0).astype(np.float32)
        positive_action = action * positive_mask
        positive_sum = np.sum(positive_action)
        if positive_sum > 1:
            positive_action = positive_action / positive_sum
        action = action * (1 - positive_mask) + positive_action

        for i, a in enumerate(action):
            if a < 0:
              if self.stock_volume[i] > 0:
                continue
              else:
                action[i] = 0
        return action

# %% [markdown]
# Build Transformer Actor and Critic

# %%
#Code Reference: University of Toronto ECE1786 Assignment3 Author: Jonathan Rose
class NewGELU(nn.Module):
    """
    Implementation of the GELU activation function currently in Google BERT repo (identical to OpenAI GPT).
    Reference: Gaussian Error Linear Units (GELU) paper: https://arxiv.org/abs/1606.08415
    """
    def forward(self, x):
        return 0.5 * x * (1.0 + torch.tanh(math.sqrt(2.0 / math.pi) * (x + 0.044715 * torch.pow(x, 3.0))))

class CausalSelfAttention(nn.Module):
    """
    A vanilla multi-head masked self-attention layer with a projection at the end.
    It is possible to use torch.nn.MultiheadAttention here but I am including an
    explicit implementation here to show that there is nothing too scary here.
    """


    def __init__(self, model_config):
        super().__init__()
        assert model_config['n_embd'] % model_config['n_head'] == 0
        # key, query, value projections for all heads, but in a batch
        self.c_attn = nn.Linear(model_config['n_embd'], 3 * model_config['n_embd'])
        # output projection
        self.c_proj = nn.Linear(model_config['n_embd'], model_config['n_embd'])
        # regularization
        self.attn_dropout = nn.Dropout(model_config['attn_pdrop'])
        self.resid_dropout = nn.Dropout(model_config['resid_pdrop'])
        # causal mask to ensure that attention is only applied to the left in the input sequence
        self.register_buffer("bias", torch.tril(torch.ones(model_config['block_size'], model_config['block_size']))
                                     .view(1, 1, model_config['block_size'], model_config['block_size']))
        self.n_head = model_config['n_head']
        self.n_embd = model_config['n_embd']



    def forward(self, x):
        B, T, C = x.size() # batch size, sequence length, embedding dimensionality (n_embd)

        # calculate query, key, values for all heads in batch and move head forward to be the batch dim
        q, k ,v  = self.c_attn(x).split(self.n_embd, dim=2)
        k = k.view(B, T, self.n_head, C // self.n_head).transpose(1, 2) # (B, nh, T, hs)
        q = q.view(B, T, self.n_head, C // self.n_head).transpose(1, 2) # (B, nh, T, hs)
        v = v.view(B, T, self.n_head, C // self.n_head).transpose(1, 2) # (B, nh, T, hs)

        # causal self-attention; Self-attend: (B, nh, T, hs) x (B, nh, hs, T) -> (B, nh, T, T)
        att = (q @ k.transpose(-2, -1)) * (1.0 / math.sqrt(k.size(-1)))
        att = att.masked_fill(self.bias[:,:,:T,:T] == 0, float('-inf'))
        att = F.softmax(att, dim=-1)
        att = self.attn_dropout(att)
        y = att @ v # (B, nh, T, T) x (B, nh, T, hs) -> (B, nh, T, hs)
        y = y.transpose(1, 2).contiguous().view(B, T, C) # re-assemble all head outputs side by side

        # output projection
        y = self.resid_dropout(self.c_proj(y))
        return y



class Block(nn.Module):
    """ an unassuming Transformer block """
    def __init__(self, model_config):
        super().__init__()
        self.ln_1 = nn.LayerNorm(model_config['n_embd'])
        self.attn = CausalSelfAttention(model_config)
        self.ln_2 = nn.LayerNorm(model_config['n_embd'])
        self.mlp = nn.ModuleDict(dict(
            c_fc    = nn.Linear(model_config['n_embd'], 4 * model_config['n_embd']),
            c_proj  = nn.Linear(4 * model_config['n_embd'], model_config['n_embd']),
            act     = NewGELU(),
            dropout = nn.Dropout(model_config['resid_pdrop']),
        ))
        m = self.mlp
        self.mlpf = lambda x: m.dropout(m.c_proj(m.act(m.c_fc(x)))) # MLP forward



    def forward(self, x):
        x = x + self.attn(self.ln_1(x))
        x = x + self.mlpf(self.ln_2(x))
        return x



# This actor model is responsible for choosing the actions for cash allocation
class CustomActorCriticModel(TorchModelV2, nn.Module):
    def __init__(self, obs_space, action_space, num_outputs, model_config, name):
        TorchModelV2.__init__(self, obs_space, action_space, num_outputs, model_config, name)
        nn.Module.__init__(self)
        custom_model_config = model_config['custom_model_config']
        self.n_embd = custom_model_config['n_embd']
        self.n_layer = custom_model_config['n_layer']
        self.n_head = custom_model_config['n_head']
        self.block_size = custom_model_config['block_size']
        self.embd_pdrop = custom_model_config['embd_pdrop']
        self.resid_pdrop = custom_model_config['resid_pdrop']
        self.attn_pdrop = custom_model_config['attn_pdrop']

        self.transformer = nn.ModuleDict({
            'drop': nn.Dropout(self.embd_pdrop),
            'h': nn.ModuleList([Block(custom_model_config) for _ in range(self.n_layer)]),
            'ln_f': nn.LayerNorm(self.n_embd),
        })

        self.policy_head = nn.Linear(self.n_embd, num_outputs)
        self.value_head = nn.Linear(self.n_embd, 1)
        self.apply(self._init_weights)

        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        self.to(self.device)



    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)
            if module.bias is not None:
                torch.nn.init.zeros_(module.bias)
        elif isinstance(module, nn.Embedding):
            torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)
        elif isinstance(module, nn.LayerNorm):
            torch.nn.init.zeros_(module.bias)
            torch.nn.init.ones_(module.weight)



    def forward(self, input_dict, state, seq_lens):

        if isinstance(input_dict['obs'], np.ndarray):
            obs = torch.tensor(input_dict['obs'], dtype=torch.float32).to(self.device)
        else:
            obs = input_dict['obs'].to(self.device)

        batch_size = obs.size(0)
        orig = obs.size(1)
        obs = obs.view(batch_size, orig//self.n_embd, self.n_embd )
        x = self.transformer.drop(obs)
        for block in self.transformer.h:
            x = block(x)
        x = self.transformer.ln_f(x)
        last_hidden_state = x[:, -1, :]

        policy = self.policy_head(last_hidden_state)
        value = self.value_head(last_hidden_state)      #no need in this LSTM value function case
        self._value_out = self.value_head(last_hidden_state).squeeze(-1)
        return policy, state

    def value_function(self):       #no need in this LSTM value function case
        return self._value_out

ModelCatalog.register_custom_model('custom_actor_critic_model',CustomActorCriticModel)

# %%
class CustomValueModel(TorchModelV2, nn.Module):
    def __init__(self, obs_space, action_space, num_outputs, model_config, name):
        TorchModelV2.__init__(self, obs_space, action_space, num_outputs, model_config, name)
        nn.Module.__init__(self)

        custom_model_config = model_config.get('custom_model_config', {})
        n_embd = custom_model_config['n_embd']
        n_layer = custom_model_config['n_layer']
        lstm_hidden_size = custom_model_config.get('lstm_hidden_size', 128)
        embd_pdrop = custom_model_config['embd_pdrop']

        self.embedding = nn.Linear(n_embd, lstm_hidden_size)
        self.lstm = nn.LSTM(input_size=lstm_hidden_size, hidden_size=lstm_hidden_size, num_layers=n_layer, batch_first=True)
        self.dropout = nn.Dropout(embd_pdrop)
        self.value_head = nn.Linear(lstm_hidden_size, 1)
        self.apply(self._init_weights)

        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        self.to(self.device)



    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)
            if module.bias is not None:
                torch.nn.init.zeros_(module.bias)
        elif isinstance(module, nn.LayerNorm):
            torch.nn.init.zeros_(module.bias)
            torch.nn.init.ones_(module.weight)



    def forward(self, input_dict, state, seq_lens):
        obs = input_dict['obs'].to(self.device)
        batch_size = obs.size(0)

        x = self.embedding(obs)
        x, (h_n, c_n) = self.lstm(x)
        x = self.dropout(x)
        last_hidden_state = x[:, -1, :]

        value = self.value_head(last_hidden_state).squeeze(-1)
        self._value_out = value

        return None, state


    def value_function(self):
        return self._value_out


ModelCatalog.register_custom_model('custom_value_model', CustomValueModel)

# %%
class CustomMetricsCallback(DefaultCallbacks):
    '''
    Custom call back class to monitor the net price
    '''
    def on_episode_end(self, *, worker, base_env, policies, episode, **kwargs):
        #print(f"The episode is {episode}")
        env = base_env.get_sub_environments()[0]
        final_net_price = env.net_price[-1] if len(env.net_price) > 0 else None
        if final_net_price is not None:
            episode.custom_metrics["final_net_price"] = final_net_price

# %%
config = {
    'env': 'my_portfolio_env',
    'num_workers': 0,
    'num_gpus': 1,
    'framework': 'torch',
    'env_config': {
        'n_stock': 5,
        'cash': 10000,
        'history_length': 365,
        'market': 'CHINA',
        'start': '20210101',
        'end': '20230631',
        'smoothing_factor': 0.5
    },
    'val_env_config': {
        'n_stock': 5,
        'cash': 10000,
        'history_length': 100,
        'market': 'CHINA',
        'start': '20230701',
        'end': '20231231',
        'smoothing_factor': 0.5
    },
    'model': {
        'custom_model': 'custom_actor_critic_model',
        'custom_action_dist': None,
        'vf_share_layers': False,
        'custom_model_config': {
            'n_embd': 152,
            'n_layer': 2,
            'n_head': 2,
            'block_size': 512,
            'embd_pdrop': 0.1,
            'resid_pdrop': 0.1,
            'attn_pdrop': 0.1
        }
    },
    'custom_model_config_for_value_model': {
        'custom_model': 'custom_value_model',
        'custom_model_config': {
            'n_embd': 152,
            'n_layer': 2,
            'lstm_hidden_size': 128,
            'embd_pdrop': 0.1,
        }
    },
    'lr': 1e-4, #change 4
    'train_batch_size': 512,
    'sgd_minibatch_size': 16,
    'num_epochs': 100,
    'callbacks': CustomMetricsCallback,
}

# %%
ray.init(ignore_reinit_error=True)

def env_creator(env_config):
    return PortfolioOptimizationEnv(env_config)

register_env('my_portfolio_env', env_creator)

learning_rate_list = [5e-3, 1e-3, 5e-4, 1e-4, 5e-5, 1e-5]

eval_rewards = {}
eval_net_prices = {}

def evaluate(trainer, env, num_episodes=10):
    all_rewards = []
    net_prices = []

    for episode in range(num_episodes):
        episode_reward = 0
        done = False
        truncated = False
        obs = env.reset()

        while not done and not truncated:
            if isinstance(obs, tuple):
                obs_input = obs[0]
            elif isinstance(obs, dict):
                obs_input = obs["obs"]
            else:
                obs_input = obs

            action = trainer.compute_single_action(obs_input, explore=False)
            obs, reward, done, truncated, info = env.step(action)
            episode_reward += reward

        all_rewards.append(episode_reward)
        net_price = env.net_price[-1]
        net_prices.append(net_price)

    return all_rewards, net_prices

for lr in learning_rate_list:
    config['lr'] = lr

    algo = (
        PPOConfig()
        .environment('my_portfolio_env', env_config=config['env_config'])
        .framework('torch')
        .resources(num_gpus=1)
        .env_runners(num_env_runners=config['num_workers'])
        .training(
            model=config['model'],
            lr=config['lr'],
            train_batch_size=config['train_batch_size'],
            num_epochs=config['num_epochs']
        )
        .api_stack(
            enable_rl_module_and_learner=False,
            enable_env_runner_and_connector_v2=False
        )
        .rollouts(sample_timeout_s=300)
        .callbacks(CustomMetricsCallback)
        .build()
    )

    num_epochs = 2
    epoch_net_values = []
    epoch_policy_loss = []
    epoch_value_loss = []

    for i in range(num_epochs):
        print(f"Training iteration {i}, Hyperparameter tuned = {lr}")
        result = algo.train()
        if i != 0:
            policy_loss = result["info"]["learner"]["default_policy"]["learner_stats"]["policy_loss"]
            value_loss = result["info"]["learner"]["default_policy"]["learner_stats"]["vf_loss"]
            net_value = result["env_runners"]["custom_metrics"]["final_net_price_mean"]
            epoch_policy_loss.append(policy_loss)
            epoch_value_loss.append(value_loss)
            epoch_net_values.append(net_value)
            print(f"Epoch {i}: Policy Loss={policy_loss}, Value Loss={value_loss}")
            torch.cuda.empty_cache()

    epochs = range(1, len(epoch_policy_loss) + 1)
    epochs = np.array(epochs)
    epoch_net_values = np.array(epoch_net_values)

    coefficients = np.polyfit(epochs, epoch_net_values, deg=1)
    trendline = np.polyval(coefficients, epochs)

    plt.figure(figsize=(10, 6))
    plt.plot(epochs, epoch_net_values, marker='o', label='Net Value')
    plt.plot(epochs, trendline, color='red', linestyle='--', label='Trendline')

    plt.title(f'Net Value with Trendline')
    plt.xlabel('Epoch')
    plt.ylabel('Metric Value')
    plt.legend()
    plt.grid()
    plt.show()



    plt.figure(figsize=(10, 6))
    plt.plot(epochs, epoch_policy_loss, marker='o', label='Policy Loss')
    plt.title(f'Policy Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Metric Value')
    plt.legend()
    plt.grid()
    plt.show()

    plt.figure(figsize=(10, 6))
    plt.plot(epochs, epoch_value_loss, marker='o', label='Value Loss')
    plt.title(f'Value Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Metric Value')
    plt.legend()
    plt.grid()
    plt.show()


    evaluation_env = PortfolioOptimizationEnv(config['val_env_config'])
    all_rewards, net_prices = evaluate(algo, evaluation_env, num_episodes=10)
    evaluation_env.close()

    eval_rewards[lr] = all_rewards
    eval_net_prices[lr] = net_prices

plt.figure(figsize=(12, 6))
for lr, rewards in eval_rewards.items():
    episodes = range(1, len(rewards) + 1)
    plt.plot(episodes, rewards, marker='o', linestyle='-', label=f'LR={lr}')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.title('Episode Rewards for Different Learning Rates')
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(12, 6))
for lr, net_prices in eval_net_prices.items():
    episodes = range(1, len(net_prices) + 1)
    plt.plot(episodes, net_prices, marker='x', linestyle='--', label=f'LR={lr}')
plt.xlabel('Episode')
plt.ylabel('Net Price')
plt.title('Episode Net Prices for Different Learning Rates')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 2024-11-23 23:15:00,594	INFO worker.py:1652 -- Calling ray.init() again after it has already been called.
# 2024-11-23 23:15:14,797	WARNING catalog.py:547 -- Custom ModelV2 should accept all custom options as **kwargs, instead of expecting them in config['custom_model_config']!
# 2024-11-23 23:15:14,837	INFO trainable.py:161 -- Trainable.setup took 14.201 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2024-11-23 23:15:14,839	WARNING util.py:61 -- Install gputil for GPU system monitoring.
# Training iteration 0, Hyperparameter tuned = 0.1
# Training iteration 1, Hyperparameter tuned = 0.1
# Epoch 1: Policy Loss=-0.020023834742605686, Value Loss=0.07507537612691521
# Training iteration 2, Hyperparameter tuned = 0.1
# Epoch 2: Policy Loss=-0.02133454296737909, Value Loss=0.10148973429575563
# Training iteration 3, Hyperparameter tuned = 0.1
# Epoch 3: Policy Loss=-0.01884634967893362, Value Loss=0.083449611896649
# Training iteration 4, Hyperparameter tuned = 0.1
# Epoch 4: Policy Loss=-0.017871147207915782, Value Loss=0.12490848422981798
# Training iteration 5, Hyperparameter tuned = 0.1
# Epoch 5: Policy Loss=-0.014275403004139662, Value Loss=0.07626226550899445
# Training iteration 6, Hyperparameter tuned = 0.1
# Epoch 6: Policy Loss=-0.011964547168463468, Value Loss=0.09071934887208044
# Training iteration 7, Hyperparameter tuned = 0.1
# Epoch 7: Policy Loss=-0.014485036507248878, Value Loss=0.08418648935854435
# Training iteration 8, Hyperparameter tuned = 0.1
# Epoch 8: Policy Loss=-0.024211907051503657, Value Loss=0.1725936404056847
# Training iteration 9, Hyperparameter tuned = 0.1
# Epoch 9: Policy Loss=-0.017834227457642557, Value Loss=0.12640291824936867
# Training iteration 10, Hyperparameter tuned = 0.1
# Epoch 10: Policy Loss=-0.012767492576967925, Value Loss=0.08360360261984169
# Training iteration 11, Hyperparameter tuned = 0.1
# Epoch 11: Policy Loss=-0.014356364123523235, Value Loss=0.08769595166668295
# Training iteration 12, Hyperparameter tuned = 0.1
# Epoch 12: Policy Loss=-0.013675852725282312, Value Loss=0.0748915185732767
# Training iteration 13, Hyperparameter tuned = 0.1
# Epoch 13: Policy Loss=-0.02355221375823021, Value Loss=0.10460603863932193
# Training iteration 14, Hyperparameter tuned = 0.1
# Epoch 14: Policy Loss=-0.021543090166524052, Value Loss=0.05885563450399786
# Training iteration 15, Hyperparameter tuned = 0.1
# Epoch 15: Policy Loss=-0.02660903824493289, Value Loss=0.05316564147360623
# Training iteration 16, Hyperparameter tuned = 0.1
# Epoch 16: Policy Loss=-0.02977632451802492, Value Loss=0.0358176055084914
# Training iteration 17, Hyperparameter tuned = 0.1
# Epoch 17: Policy Loss=-0.025043211542069913, Value Loss=0.05510269119171426
# Training iteration 18, Hyperparameter tuned = 0.1
# Epoch 18: Policy Loss=-0.025818946957588195, Value Loss=0.13655170578509568
# Training iteration 19, Hyperparameter tuned = 0.1
# Epoch 19: Policy Loss=-0.020128901414573193, Value Loss=0.05926981985569
# Training iteration 20, Hyperparameter tuned = 0.1
# Epoch 20: Policy Loss=-0.019919303767383097, Value Loss=0.052744663937482984
# Training iteration 21, Hyperparameter tuned = 0.1
# Epoch 21: Policy Loss=-0.025860534496605397, Value Loss=0.03588387881405652
# Training iteration 22, Hyperparameter tuned = 0.1
# Epoch 22: Policy Loss=-0.028002966782078146, Value Loss=0.0378450890770182
# Training iteration 23, Hyperparameter tuned = 0.1
# Epoch 23: Policy Loss=-0.017608857974410058, Value Loss=0.048221500534564254
# Training iteration 24, Hyperparameter tuned = 0.1
# Epoch 24: Policy Loss=-0.01815944252535701, Value Loss=0.050475344294682145
# Training iteration 25, Hyperparameter tuned = 0.1
# Epoch 25: Policy Loss=-0.01807730222120881, Value Loss=0.041119726290926334
# Training iteration 26, Hyperparameter tuned = 0.1
# Epoch 26: Policy Loss=-0.036578384088352324, Value Loss=0.040296717560850084
# Training iteration 27, Hyperparameter tuned = 0.1
# Epoch 27: Policy Loss=-0.02000640904530883, Value Loss=0.08131229464896023
# Training iteration 28, Hyperparameter tuned = 0.1
# Epoch 28: Policy Loss=-0.012052759509533644, Value Loss=0.04624729447066784
# Training iteration 29, Hyperparameter tuned = 0.1
# Epoch 29: Policy Loss=-0.016784508638083936, Value Loss=0.08376539995428174
# Training iteration 30, Hyperparameter tuned = 0.1
# Epoch 30: Policy Loss=-0.0108825468365103, Value Loss=0.03672396491281688
# Training iteration 31, Hyperparameter tuned = 0.1
# Epoch 31: Policy Loss=-0.004078785674646496, Value Loss=0.05489009606186301
# Training iteration 32, Hyperparameter tuned = 0.1
# Epoch 32: Policy Loss=-0.001979576647281647, Value Loss=0.061894146627746525
# Training iteration 33, Hyperparameter tuned = 0.1
# Epoch 33: Policy Loss=0.005974997235462069, Value Loss=0.07161489618942142
# Training iteration 34, Hyperparameter tuned = 0.1
# Epoch 34: Policy Loss=0.014134759339503944, Value Loss=0.06270194502547383
# Training iteration 35, Hyperparameter tuned = 0.1
# Epoch 35: Policy Loss=0.01839930046349764, Value Loss=0.055951515310443935
# Training iteration 36, Hyperparameter tuned = 0.1
# Epoch 36: Policy Loss=0.019088387489318848, Value Loss=0.03315383208915591
# Training iteration 37, Hyperparameter tuned = 0.1
# Epoch 37: Policy Loss=0.025339625868946315, Value Loss=0.045337896794080734
# Training iteration 38, Hyperparameter tuned = 0.1
# Epoch 38: Policy Loss=0.10825606601312757, Value Loss=0.04285737633239478
# Training iteration 39, Hyperparameter tuned = 0.1
# Epoch 39: Policy Loss=0.034410479217767714, Value Loss=0.04971481715561822
# Training iteration 40, Hyperparameter tuned = 0.1
# Epoch 40: Policy Loss=0.07225771555677056, Value Loss=0.028590428149327635
# Training iteration 41, Hyperparameter tuned = 0.1
# Epoch 41: Policy Loss=0.09003840200603008, Value Loss=0.052739503267221155
# Training iteration 42, Hyperparameter tuned = 0.1
# Epoch 42: Policy Loss=0.056384272321593015, Value Loss=0.026968412532005458
# Training iteration 43, Hyperparameter tuned = 0.1
# Epoch 43: Policy Loss=0.12966977826319634, Value Loss=0.03447502021212131
# Training iteration 44, Hyperparameter tuned = 0.1
# Epoch 44: Policy Loss=0.047100003473460675, Value Loss=0.044516845354810354
# Training iteration 45, Hyperparameter tuned = 0.1
# Epoch 45: Policy Loss=0.21117771110963077, Value Loss=0.02766805861145258
# Training iteration 46, Hyperparameter tuned = 0.1
# Epoch 46: Policy Loss=0.6339526306651533, Value Loss=0.05535883460659534
# Training iteration 47, Hyperparameter tuned = 0.1
# Epoch 47: Policy Loss=0.22305899491533637, Value Loss=0.06236494003795087
# Training iteration 48, Hyperparameter tuned = 0.1
# Epoch 48: Policy Loss=0.08530044458573684, Value Loss=0.06889479887671769
# Training iteration 49, Hyperparameter tuned = 0.1
# Epoch 49: Policy Loss=0.16168079945258795, Value Loss=0.058650742480531336
# 2024-11-24 00:07:52,465	WARNING catalog.py:547 -- Custom ModelV2 should accept all custom options as **kwargs, instead of expecting them in config['custom_model_config']!
# 2024-11-24 00:07:52,505	INFO trainable.py:161 -- Trainable.setup took 14.054 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2024-11-24 00:07:52,507	WARNING util.py:61 -- Install gputil for GPU system monitoring.
# Training iteration 0, Hyperparameter tuned = 0.2
# Training iteration 1, Hyperparameter tuned = 0.2
# Epoch 1: Policy Loss=-0.021222880855202676, Value Loss=0.9454932552576065
# Training iteration 2, Hyperparameter tuned = 0.2
# Epoch 2: Policy Loss=-0.013188384342938661, Value Loss=0.8456323578208685
# Training iteration 3, Hyperparameter tuned = 0.2
# Epoch 3: Policy Loss=-0.017634585108608006, Value Loss=2.037212793789804
# Training iteration 4, Hyperparameter tuned = 0.2
# Epoch 4: Policy Loss=-0.01541483772918582, Value Loss=0.6860001560300588
# Training iteration 5, Hyperparameter tuned = 0.2
# Epoch 5: Policy Loss=-0.01220294326543808, Value Loss=0.699290636330843
# Training iteration 6, Hyperparameter tuned = 0.2
# Epoch 6: Policy Loss=-0.006619192473590374, Value Loss=1.206743088811636
# Training iteration 7, Hyperparameter tuned = 0.2
# Epoch 7: Policy Loss=-0.011152138262987136, Value Loss=1.646914908438921
# Training iteration 8, Hyperparameter tuned = 0.2
# Epoch 8: Policy Loss=-0.03136524397879839, Value Loss=1.1939618508517742
# Training iteration 9, Hyperparameter tuned = 0.2
# Epoch 9: Policy Loss=-0.01470697596669197, Value Loss=1.744839052259922
# Training iteration 10, Hyperparameter tuned = 0.2
# Epoch 10: Policy Loss=-0.011120885834097862, Value Loss=0.781899225488305
# Training iteration 11, Hyperparameter tuned = 0.2
# Epoch 11: Policy Loss=-0.01033195950090885, Value Loss=1.3466865754127502
# Training iteration 12, Hyperparameter tuned = 0.2
# Epoch 12: Policy Loss=-0.0239797293394804, Value Loss=0.5952207544445991
# Training iteration 13, Hyperparameter tuned = 0.2
# Epoch 13: Policy Loss=-0.01823916065506637, Value Loss=1.801359951645136
# Training iteration 14, Hyperparameter tuned = 0.2
# Epoch 14: Policy Loss=-0.01925574541091919, Value Loss=1.2444521406292914
# Training iteration 15, Hyperparameter tuned = 0.2
# Epoch 15: Policy Loss=-0.016779248118400574, Value Loss=1.5886149907112121
# Training iteration 16, Hyperparameter tuned = 0.2
# Epoch 16: Policy Loss=-0.014543724693357945, Value Loss=0.8326194344460964
# Training iteration 17, Hyperparameter tuned = 0.2
# Epoch 17: Policy Loss=-0.007028596447780728, Value Loss=0.6717348132282496
# Training iteration 18, Hyperparameter tuned = 0.2
# Epoch 18: Policy Loss=-0.010147706737043335, Value Loss=0.7952945883572101
# Training iteration 19, Hyperparameter tuned = 0.2
# Epoch 19: Policy Loss=-0.02355066961608827, Value Loss=0.7826280070841313
# Training iteration 20, Hyperparameter tuned = 0.2
# Epoch 20: Policy Loss=-0.015853104274719955, Value Loss=0.5679299628734589
# Training iteration 21, Hyperparameter tuned = 0.2
# Epoch 21: Policy Loss=-0.014208289477974177, Value Loss=0.37538600876927375
# Training iteration 22, Hyperparameter tuned = 0.2
# Epoch 22: Policy Loss=-0.01226938328705728, Value Loss=0.431189378015697
# Training iteration 23, Hyperparameter tuned = 0.2
# Epoch 23: Policy Loss=-0.024453796949237584, Value Loss=0.33079111374914644
# Training iteration 24, Hyperparameter tuned = 0.2
# Epoch 24: Policy Loss=-0.021348213739693166, Value Loss=0.3197766186669469
# Training iteration 25, Hyperparameter tuned = 0.2
# Epoch 25: Policy Loss=-0.012740509607829154, Value Loss=0.23464225433766842
# Training iteration 26, Hyperparameter tuned = 0.2
# Epoch 26: Policy Loss=-0.010650572441518307, Value Loss=0.21066479124128817
# Training iteration 27, Hyperparameter tuned = 0.2
# Epoch 27: Policy Loss=-0.018539957962930204, Value Loss=0.16959920486435295
# Training iteration 28, Hyperparameter tuned = 0.2
# Epoch 28: Policy Loss=-0.016737983170896767, Value Loss=0.18152659587562084
# Training iteration 29, Hyperparameter tuned = 0.2
# Epoch 29: Policy Loss=-0.023349842876195907, Value Loss=0.29675554182380437
# Training iteration 30, Hyperparameter tuned = 0.2
# Epoch 30: Policy Loss=-0.01423441145569086, Value Loss=0.21427370861172676
# Training iteration 31, Hyperparameter tuned = 0.2
# Epoch 31: Policy Loss=-0.0019946640520356594, Value Loss=0.14886049162596465
# Training iteration 32, Hyperparameter tuned = 0.2
# Epoch 32: Policy Loss=0.003919718060642481, Value Loss=0.20335934456437826
# Training iteration 33, Hyperparameter tuned = 0.2
# Epoch 33: Policy Loss=0.012223517745733261, Value Loss=0.21141208985820412
# Training iteration 34, Hyperparameter tuned = 0.2
# Epoch 34: Policy Loss=0.011447334997355937, Value Loss=0.3478105451539159
# Training iteration 35, Hyperparameter tuned = 0.2
# Epoch 35: Policy Loss=0.003318282924592495, Value Loss=0.23145371362566947
# Training iteration 36, Hyperparameter tuned = 0.2
# Epoch 36: Policy Loss=0.005843467898666859, Value Loss=0.311465899720788
# Training iteration 37, Hyperparameter tuned = 0.2
# Epoch 37: Policy Loss=0.018668260239064694, Value Loss=0.4786624190583825
# Training iteration 38, Hyperparameter tuned = 0.2
# Epoch 38: Policy Loss=0.015545752290636301, Value Loss=0.7647131662070751
# Training iteration 39, Hyperparameter tuned = 0.2
# Epoch 39: Policy Loss=0.033609275690978394, Value Loss=0.9849120938032866
# Training iteration 40, Hyperparameter tuned = 0.2
# Epoch 40: Policy Loss=0.02527761522680521, Value Loss=1.2984530254453421
# Training iteration 41, Hyperparameter tuned = 0.2
# Epoch 41: Policy Loss=0.024221755303442477, Value Loss=1.6431021605432035
# Training iteration 42, Hyperparameter tuned = 0.2
# Epoch 42: Policy Loss=0.03911561194807291, Value Loss=1.1826694889366627
# Training iteration 43, Hyperparameter tuned = 0.2
# Epoch 43: Policy Loss=0.02906137007288635, Value Loss=2.356554052680731
# Training iteration 44, Hyperparameter tuned = 0.2
# Epoch 44: Policy Loss=0.024990988983772694, Value Loss=1.8419015497714282
# Training iteration 45, Hyperparameter tuned = 0.2
# Epoch 45: Policy Loss=0.05613154493272304, Value Loss=2.164840531051159
# Training iteration 46, Hyperparameter tuned = 0.2
# Epoch 46: Policy Loss=0.059970277827233076, Value Loss=3.1856016340851783
# Training iteration 47, Hyperparameter tuned = 0.2
# Epoch 47: Policy Loss=0.059254572307690975, Value Loss=3.2737624514102937
# Training iteration 48, Hyperparameter tuned = 0.2
# Epoch 48: Policy Loss=0.06434185847640038, Value Loss=2.213062419593334
# Training iteration 49, Hyperparameter tuned = 0.2
# Epoch 49: Policy Loss=0.08210402208380402, Value Loss=3.3076383563876153
# 2024-11-24 01:00:37,525	WARNING catalog.py:547 -- Custom ModelV2 should accept all custom options as **kwargs, instead of expecting them in config['custom_model_config']!
# 2024-11-24 01:00:37,566	INFO trainable.py:161 -- Trainable.setup took 14.008 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2024-11-24 01:00:37,568	WARNING util.py:61 -- Install gputil for GPU system monitoring.
# Training iteration 0, Hyperparameter tuned = 0.3
# Training iteration 1, Hyperparameter tuned = 0.3
# Epoch 1: Policy Loss=-0.01649901277385652, Value Loss=4.152562145590782
# Training iteration 2, Hyperparameter tuned = 0.3
# Epoch 2: Policy Loss=-0.01664839806035161, Value Loss=5.4263262182474135
# Training iteration 3, Hyperparameter tuned = 0.3
# Epoch 3: Policy Loss=-0.010397448241710662, Value Loss=4.699264757633209
# Training iteration 4, Hyperparameter tuned = 0.3
# Epoch 4: Policy Loss=-0.01989101991057396, Value Loss=3.2946176412701607
# Training iteration 5, Hyperparameter tuned = 0.3
# Epoch 5: Policy Loss=-0.01576151007786393, Value Loss=4.498201520442962
# Training iteration 6, Hyperparameter tuned = 0.3
# Epoch 6: Policy Loss=-0.01631669119000435, Value Loss=7.517435326576233
# Training iteration 7, Hyperparameter tuned = 0.3
# Epoch 7: Policy Loss=-0.009489115979522466, Value Loss=6.074592017531395
# Training iteration 8, Hyperparameter tuned = 0.3
# Epoch 8: Policy Loss=-0.018280374417081476, Value Loss=4.554149736166
# Training iteration 9, Hyperparameter tuned = 0.3
# Epoch 9: Policy Loss=-0.016560060866177083, Value Loss=2.2695576149225234
# Training iteration 10, Hyperparameter tuned = 0.3
# Epoch 10: Policy Loss=-0.01888494849205017, Value Loss=4.961142522096634
# Training iteration 11, Hyperparameter tuned = 0.3
# Epoch 11: Policy Loss=-0.012794446293264627, Value Loss=5.296323790550232
# Training iteration 12, Hyperparameter tuned = 0.3
# Epoch 12: Policy Loss=-0.017528386297635735, Value Loss=5.885341023206711
# Training iteration 13, Hyperparameter tuned = 0.3
# Epoch 13: Policy Loss=-0.01601971760392189, Value Loss=4.142581270933151
# Training iteration 14, Hyperparameter tuned = 0.3
# Epoch 14: Policy Loss=-0.009027365893125534, Value Loss=4.841658456921578
# Training iteration 15, Hyperparameter tuned = 0.3
# Epoch 15: Policy Loss=-0.005725527927279472, Value Loss=3.248368804305792
# Training iteration 16, Hyperparameter tuned = 0.3
# Epoch 16: Policy Loss=-0.011070557874627412, Value Loss=4.263002249598503
# Training iteration 17, Hyperparameter tuned = 0.3
# Epoch 17: Policy Loss=-0.008052701801061631, Value Loss=3.0536518850922585
# Training iteration 18, Hyperparameter tuned = 0.3
# Epoch 18: Policy Loss=-0.020075560733675956, Value Loss=1.9823986703157426
# Training iteration 19, Hyperparameter tuned = 0.3
# Epoch 19: Policy Loss=-0.013686480466276407, Value Loss=4.16064957767725
# Training iteration 20, Hyperparameter tuned = 0.3
# Epoch 20: Policy Loss=-0.018013504296541215, Value Loss=4.852721417546272
# Training iteration 21, Hyperparameter tuned = 0.3
# Epoch 21: Policy Loss=-0.020897678583860397, Value Loss=4.157699736356736
# Training iteration 22, Hyperparameter tuned = 0.3
# Epoch 22: Policy Loss=-0.014566786093637348, Value Loss=1.724188330024481
# Training iteration 23, Hyperparameter tuned = 0.3
# Epoch 23: Policy Loss=-0.015867451205849648, Value Loss=2.070534886419773
# Training iteration 24, Hyperparameter tuned = 0.3
# Epoch 24: Policy Loss=-0.02288941890001297, Value Loss=3.5496775072813036
# Training iteration 25, Hyperparameter tuned = 0.3
# Epoch 25: Policy Loss=-0.011182100735604763, Value Loss=2.797369382083416
# Training iteration 26, Hyperparameter tuned = 0.3
# Epoch 26: Policy Loss=-0.014119833260774612, Value Loss=2.2280706964433192
# Training iteration 27, Hyperparameter tuned = 0.3
# Epoch 27: Policy Loss=-0.01130253114271909, Value Loss=2.1882553942501546
# Training iteration 28, Hyperparameter tuned = 0.3
# Epoch 28: Policy Loss=-0.017124355640262365, Value Loss=1.0666842152178289
# Training iteration 29, Hyperparameter tuned = 0.3
# Epoch 29: Policy Loss=-0.03156354257138446, Value Loss=1.4419310282170772
# Training iteration 30, Hyperparameter tuned = 0.3
# Epoch 30: Policy Loss=-0.028417942727683113, Value Loss=1.271626442372799
# Training iteration 31, Hyperparameter tuned = 0.3
# Epoch 31: Policy Loss=-0.01305634731426835, Value Loss=0.9427928930521011
# Training iteration 32, Hyperparameter tuned = 0.3
# Epoch 32: Policy Loss=-0.010126426555216313, Value Loss=1.0313316340744496
# Training iteration 33, Hyperparameter tuned = 0.3
# Epoch 33: Policy Loss=-0.011981434477493167, Value Loss=1.04004031971097
# Training iteration 34, Hyperparameter tuned = 0.3
# Epoch 34: Policy Loss=-0.008243268043734132, Value Loss=0.8568166135251523
# Training iteration 35, Hyperparameter tuned = 0.3
# Epoch 35: Policy Loss=-0.002646007314324379, Value Loss=0.9868517611920834
# Training iteration 36, Hyperparameter tuned = 0.3
# Epoch 36: Policy Loss=-0.009604818508960307, Value Loss=0.800493356436491
# Training iteration 37, Hyperparameter tuned = 0.3
# Epoch 37: Policy Loss=-0.0066165243275463585, Value Loss=0.7959470665454864
# Training iteration 38, Hyperparameter tuned = 0.3
# Epoch 38: Policy Loss=0.012438851026818156, Value Loss=1.0123119837045669
# Training iteration 39, Hyperparameter tuned = 0.3
# Epoch 39: Policy Loss=0.0047411741130054, Value Loss=0.9279757715761662
# Training iteration 40, Hyperparameter tuned = 0.3
# Epoch 40: Policy Loss=0.009029526836238802, Value Loss=0.8750135041773319
# Training iteration 41, Hyperparameter tuned = 0.3
# Epoch 41: Policy Loss=0.009509848016314208, Value Loss=0.8818453060090542
# Training iteration 42, Hyperparameter tuned = 0.3
# Epoch 42: Policy Loss=0.01249261926393956, Value Loss=0.9581241641938686
# Training iteration 43, Hyperparameter tuned = 0.3
# Epoch 43: Policy Loss=0.02091608364135027, Value Loss=0.9647936962544919
# Training iteration 44, Hyperparameter tuned = 0.3
# Epoch 44: Policy Loss=0.032124804090708496, Value Loss=1.1780616281926632
# Training iteration 45, Hyperparameter tuned = 0.3
# Epoch 45: Policy Loss=0.03810709992423653, Value Loss=1.1234822197258472
# Training iteration 46, Hyperparameter tuned = 0.3
# Epoch 46: Policy Loss=0.05352275324519724, Value Loss=1.0695125468075275
# Training iteration 47, Hyperparameter tuned = 0.3
# Epoch 47: Policy Loss=0.03316017355769873, Value Loss=1.0905966421961784
# Training iteration 48, Hyperparameter tuned = 0.3
# Epoch 48: Policy Loss=0.07370828449027612, Value Loss=1.043864392787218
# Training iteration 49, Hyperparameter tuned = 0.3
# Epoch 49: Policy Loss=0.08663610296323895, Value Loss=1.158073619157076
# 2024-11-24 01:53:14,649	WARNING catalog.py:547 -- Custom ModelV2 should accept all custom options as **kwargs, instead of expecting them in config['custom_model_config']!
# 2024-11-24 01:53:14,688	INFO trainable.py:161 -- Trainable.setup took 14.091 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2024-11-24 01:53:14,690	WARNING util.py:61 -- Install gputil for GPU system monitoring.
# Training iteration 0, Hyperparameter tuned = 0.4
# Training iteration 1, Hyperparameter tuned = 0.4
# Epoch 1: Policy Loss=-0.012844352386891841, Value Loss=6.02812089920044
# Training iteration 2, Hyperparameter tuned = 0.4
# Epoch 2: Policy Loss=-0.012495518885552883, Value Loss=8.042315429449081
# Training iteration 3, Hyperparameter tuned = 0.4
# Epoch 3: Policy Loss=-0.011536161340773106, Value Loss=6.906379142999649
# Training iteration 4, Hyperparameter tuned = 0.4
# Epoch 4: Policy Loss=-0.01925662986934185, Value Loss=7.127322183847427
# Training iteration 5, Hyperparameter tuned = 0.4
# Epoch 5: Policy Loss=-0.015499307736754418, Value Loss=8.575127277374268
# Training iteration 6, Hyperparameter tuned = 0.4
# Epoch 6: Policy Loss=-0.030031646881252528, Value Loss=7.467346894741058
# Training iteration 7, Hyperparameter tuned = 0.4
# Epoch 7: Policy Loss=-0.011838586013764143, Value Loss=8.560288120508194
# Training iteration 8, Hyperparameter tuned = 0.4
# Epoch 8: Policy Loss=-0.02489032220095396, Value Loss=6.862375855445862
# Training iteration 9, Hyperparameter tuned = 0.4
# Epoch 9: Policy Loss=-0.014803093429654836, Value Loss=7.499804253578186
# Training iteration 10, Hyperparameter tuned = 0.4
# Epoch 10: Policy Loss=-0.021397638749331236, Value Loss=8.470957889556885
# Training iteration 11, Hyperparameter tuned = 0.4
# Epoch 11: Policy Loss=-0.01430237079039216, Value Loss=5.164248067140579
# Training iteration 12, Hyperparameter tuned = 0.4
# Epoch 12: Policy Loss=-0.017936354354023933, Value Loss=6.5332121175527575
# Training iteration 13, Hyperparameter tuned = 0.4
# Epoch 13: Policy Loss=-0.028333059642463923, Value Loss=6.890930345058441
# Training iteration 14, Hyperparameter tuned = 0.4
# Epoch 14: Policy Loss=-0.0073179390933364626, Value Loss=5.651489951610565
# Training iteration 15, Hyperparameter tuned = 0.4
# Epoch 15: Policy Loss=-0.016062355171889066, Value Loss=6.224522387981414
# Training iteration 16, Hyperparameter tuned = 0.4
# Epoch 16: Policy Loss=-0.017485107257962228, Value Loss=6.1539657253026965
# Training iteration 17, Hyperparameter tuned = 0.4
# Epoch 17: Policy Loss=-0.003299248442053795, Value Loss=5.142631704807282
# Training iteration 18, Hyperparameter tuned = 0.4
# Epoch 18: Policy Loss=-0.00825531356036663, Value Loss=5.959912702143193
# Training iteration 19, Hyperparameter tuned = 0.4
# Epoch 19: Policy Loss=-0.010975518780760467, Value Loss=5.96603271484375
# Training iteration 20, Hyperparameter tuned = 0.4
# Epoch 20: Policy Loss=-0.015087600527331234, Value Loss=5.257638368010521
# Training iteration 21, Hyperparameter tuned = 0.4
# Epoch 21: Policy Loss=-0.005045629786327482, Value Loss=6.469782482981682
# Training iteration 22, Hyperparameter tuned = 0.4
# Epoch 22: Policy Loss=-0.008027045615017414, Value Loss=5.970459498763084
# Training iteration 23, Hyperparameter tuned = 0.4
# Epoch 23: Policy Loss=0.0025787776708602905, Value Loss=6.24846582531929
# Training iteration 24, Hyperparameter tuned = 0.4
# Epoch 24: Policy Loss=-0.0017062192410230636, Value Loss=4.802671818137169
# Training iteration 25, Hyperparameter tuned = 0.4
# Epoch 25: Policy Loss=-0.011380596831440926, Value Loss=6.952005659937859
# Training iteration 26, Hyperparameter tuned = 0.4
# Epoch 26: Policy Loss=-0.004618453830480576, Value Loss=6.033717806935311
# Training iteration 27, Hyperparameter tuned = 0.4
# Epoch 27: Policy Loss=-0.007823255211114884, Value Loss=6.433349545001984
# Training iteration 28, Hyperparameter tuned = 0.4
# Epoch 28: Policy Loss=-0.014721372686326504, Value Loss=5.565770142674446
# Training iteration 29, Hyperparameter tuned = 0.4
# Epoch 29: Policy Loss=-0.008359124511480331, Value Loss=5.416335984170437
# Training iteration 30, Hyperparameter tuned = 0.4
# Epoch 30: Policy Loss=0.002881997264921665, Value Loss=5.66181826710701
# Training iteration 31, Hyperparameter tuned = 0.4
# Epoch 31: Policy Loss=-0.0019239429384469986, Value Loss=5.053199828863144
# Training iteration 32, Hyperparameter tuned = 0.4
# Epoch 32: Policy Loss=-0.0004580743983387947, Value Loss=5.751387671232224
# Training iteration 33, Hyperparameter tuned = 0.4
# Epoch 33: Policy Loss=-0.01248612992465496, Value Loss=7.243914058208466
# Training iteration 34, Hyperparameter tuned = 0.4
# Epoch 34: Policy Loss=0.013054199833422899, Value Loss=5.247791990339756
# Training iteration 35, Hyperparameter tuned = 0.4
# Epoch 35: Policy Loss=0.004313982501626015, Value Loss=5.09041643679142
# Training iteration 36, Hyperparameter tuned = 0.4
# Epoch 36: Policy Loss=0.011682200049981474, Value Loss=6.36291824221611
# Training iteration 37, Hyperparameter tuned = 0.4
# Epoch 37: Policy Loss=0.004780273623764515, Value Loss=6.66963694781065
# Training iteration 38, Hyperparameter tuned = 0.4
# Epoch 38: Policy Loss=-7.599118165671826e-05, Value Loss=6.106902426481247
# Training iteration 39, Hyperparameter tuned = 0.4
# Epoch 39: Policy Loss=-0.005514337010681629, Value Loss=6.302279714941978
# Training iteration 40, Hyperparameter tuned = 0.4
# Epoch 40: Policy Loss=-0.00113862544298172, Value Loss=3.897547302246094
# Training iteration 41, Hyperparameter tuned = 0.4
# Epoch 41: Policy Loss=-0.00037989264354109764, Value Loss=7.227015091180801
# Training iteration 42, Hyperparameter tuned = 0.4
# Epoch 42: Policy Loss=0.006431072987616062, Value Loss=5.390962522029877
# Training iteration 43, Hyperparameter tuned = 0.4
# Epoch 43: Policy Loss=0.0030556680262088776, Value Loss=6.307909924983978
# Training iteration 44, Hyperparameter tuned = 0.4
# Epoch 44: Policy Loss=0.006569684986025095, Value Loss=6.412288806438446
# Training iteration 45, Hyperparameter tuned = 0.4
# Epoch 45: Policy Loss=-0.0029279177449643614, Value Loss=5.903825791478157
# Training iteration 46, Hyperparameter tuned = 0.4
# Epoch 46: Policy Loss=-0.0009085553139448166, Value Loss=6.6884791404008865
# Training iteration 47, Hyperparameter tuned = 0.4
# Epoch 47: Policy Loss=0.008618014343082904, Value Loss=6.9463768899440765
# Training iteration 48, Hyperparameter tuned = 0.4
# Epoch 48: Policy Loss=0.013602558374404907, Value Loss=6.746230169534683
# Training iteration 49, Hyperparameter tuned = 0.4
# Epoch 49: Policy Loss=0.0018725268170237542, Value Loss=5.949227749109268
# 2024-11-24 02:46:08,175	WARNING catalog.py:547 -- Custom ModelV2 should accept all custom options as **kwargs, instead of expecting them in config['custom_model_config']!
# 2024-11-24 02:46:08,214	INFO trainable.py:161 -- Trainable.setup took 16.598 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2024-11-24 02:46:08,216	WARNING util.py:61 -- Install gputil for GPU system monitoring.
# Training iteration 0, Hyperparameter tuned = 0.5
# Training iteration 1, Hyperparameter tuned = 0.5
# Epoch 1: Policy Loss=-0.01460261838743463, Value Loss=8.576052414178848
# Training iteration 2, Hyperparameter tuned = 0.5
# Epoch 2: Policy Loss=-0.018045928897336125, Value Loss=7.901709147691727
# Training iteration 3, Hyperparameter tuned = 0.5
# Epoch 3: Policy Loss=-0.008433066755533219, Value Loss=9.28425986289978
# Training iteration 4, Hyperparameter tuned = 0.5
# Epoch 4: Policy Loss=-0.0160682402132079, Value Loss=8.103331300020217
# Training iteration 5, Hyperparameter tuned = 0.5
# Epoch 5: Policy Loss=-0.01549842543900013, Value Loss=8.585965558290482
# Training iteration 6, Hyperparameter tuned = 0.5
# Epoch 6: Policy Loss=-0.019988555633462964, Value Loss=9.05699252486229
# Training iteration 7, Hyperparameter tuned = 0.5
# Epoch 7: Policy Loss=-0.01332714281976223, Value Loss=8.693816930055618
# Training iteration 8, Hyperparameter tuned = 0.5
# Epoch 8: Policy Loss=-0.010765688270330429, Value Loss=9.45192843914032
# Training iteration 9, Hyperparameter tuned = 0.5
# Epoch 9: Policy Loss=-0.020786404013633727, Value Loss=9.047675347328186
# Training iteration 10, Hyperparameter tuned = 0.5
# Epoch 10: Policy Loss=-0.024148103538900612, Value Loss=9.599296264648437
# Training iteration 11, Hyperparameter tuned = 0.5
# Epoch 11: Policy Loss=-0.020823816210031508, Value Loss=9.217477118968963
# Training iteration 12, Hyperparameter tuned = 0.5
# Epoch 12: Policy Loss=-0.023766187578439714, Value Loss=9.296118979454041
# Training iteration 13, Hyperparameter tuned = 0.5
# Epoch 13: Policy Loss=-0.012227577734738588, Value Loss=9.218502149581909
# Training iteration 14, Hyperparameter tuned = 0.5
# Epoch 14: Policy Loss=-0.02801527239382267, Value Loss=8.548403344154359
# Training iteration 15, Hyperparameter tuned = 0.5
# Epoch 15: Policy Loss=-0.016968089751899243, Value Loss=9.102578933238982
# Training iteration 16, Hyperparameter tuned = 0.5
# Epoch 16: Policy Loss=-0.018821292519569398, Value Loss=8.764905877113343
# Training iteration 17, Hyperparameter tuned = 0.5
# Epoch 17: Policy Loss=-0.017458408987149596, Value Loss=8.564893304109573
# Training iteration 18, Hyperparameter tuned = 0.5
# Epoch 18: Policy Loss=-0.015292301960289478, Value Loss=7.893795959949493
# Training iteration 19, Hyperparameter tuned = 0.5
# Epoch 19: Policy Loss=-0.012359354877844453, Value Loss=8.062508643865586
# Training iteration 20, Hyperparameter tuned = 0.5
# Epoch 20: Policy Loss=-0.006910678474232554, Value Loss=8.648827064037324
# Training iteration 21, Hyperparameter tuned = 0.5
# Epoch 21: Policy Loss=-0.002296040877699852, Value Loss=7.573659039735794
# Training iteration 22, Hyperparameter tuned = 0.5
# Epoch 22: Policy Loss=-0.0009496386349201202, Value Loss=8.746398420333863
# Training iteration 23, Hyperparameter tuned = 0.5
# Epoch 23: Policy Loss=-0.004769409440923482, Value Loss=8.180140843391419
# Training iteration 24, Hyperparameter tuned = 0.5
# Epoch 24: Policy Loss=0.0062035823427140716, Value Loss=8.713263568878174
# Training iteration 25, Hyperparameter tuned = 0.5
# Epoch 25: Policy Loss=0.0015262778848409652, Value Loss=8.731999846696853
# Training iteration 26, Hyperparameter tuned = 0.5
# Epoch 26: Policy Loss=-0.003397830054163933, Value Loss=8.773544503450394
# Training iteration 27, Hyperparameter tuned = 0.5
# Epoch 27: Policy Loss=0.0024320764839649203, Value Loss=9.196993194818496
# Training iteration 28, Hyperparameter tuned = 0.5
# Epoch 28: Policy Loss=0.002248700789641589, Value Loss=9.1349121427536
# Training iteration 29, Hyperparameter tuned = 0.5
# Epoch 29: Policy Loss=-0.0016032707691192626, Value Loss=9.455778727531433
# Training iteration 30, Hyperparameter tuned = 0.5
# Epoch 30: Policy Loss=-0.0015630833804607391, Value Loss=9.06683324098587
# Training iteration 31, Hyperparameter tuned = 0.5
# Epoch 31: Policy Loss=-0.0009777348674833775, Value Loss=9.16708590745926
# Training iteration 32, Hyperparameter tuned = 0.5
# Epoch 32: Policy Loss=-0.009339257590472699, Value Loss=9.233471875190736
# Training iteration 33, Hyperparameter tuned = 0.5
# Epoch 33: Policy Loss=-0.0013133476674556733, Value Loss=9.266367020606994
# Training iteration 34, Hyperparameter tuned = 0.5
# Epoch 34: Policy Loss=-0.01413568813353777, Value Loss=9.264656918048859
# Training iteration 35, Hyperparameter tuned = 0.5
# Epoch 35: Policy Loss=-0.012764821331948041, Value Loss=8.868781485557555
# Training iteration 36, Hyperparameter tuned = 0.5
# Epoch 36: Policy Loss=-0.008278038650751114, Value Loss=9.190452756881713
# Training iteration 37, Hyperparameter tuned = 0.5
# Epoch 37: Policy Loss=-0.013029309473931789, Value Loss=9.442259731292724
# Training iteration 38, Hyperparameter tuned = 0.5
# Epoch 38: Policy Loss=-0.011537486244924367, Value Loss=9.295519416332246
# Training iteration 39, Hyperparameter tuned = 0.5
# Epoch 39: Policy Loss=-0.007245941460132599, Value Loss=9.350257000923158
# Training iteration 40, Hyperparameter tuned = 0.5
# Epoch 40: Policy Loss=-0.007357110604643822, Value Loss=9.134243896007538
# Training iteration 41, Hyperparameter tuned = 0.5
# Epoch 41: Policy Loss=-0.008716889955103398, Value Loss=8.9933939743042
# Training iteration 42, Hyperparameter tuned = 0.5
# Epoch 42: Policy Loss=-0.012979424446821214, Value Loss=9.509276382923126
# Training iteration 43, Hyperparameter tuned = 0.5
# Epoch 43: Policy Loss=-0.0101521972194314, Value Loss=9.283153295516968
# Training iteration 44, Hyperparameter tuned = 0.5
# Epoch 44: Policy Loss=-0.007204815614968539, Value Loss=9.559285862445831
# Training iteration 45, Hyperparameter tuned = 0.5
# Epoch 45: Policy Loss=-0.009037637263536452, Value Loss=9.51749641418457
# Training iteration 46, Hyperparameter tuned = 0.5
# Epoch 46: Policy Loss=-0.007611265741288662, Value Loss=9.285727527141571
# Training iteration 47, Hyperparameter tuned = 0.5
# Epoch 47: Policy Loss=-0.013486770316958427, Value Loss=8.89052183866501
# Training iteration 48, Hyperparameter tuned = 0.5
# Epoch 48: Policy Loss=-0.008006689697504043, Value Loss=9.427367279529571
# Training iteration 49, Hyperparameter tuned = 0.5
# Epoch 49: Policy Loss=-0.004276723116636277, Value Loss=9.264292509555817
# 2024-11-24 03:38:55,307	WARNING catalog.py:547 -- Custom ModelV2 should accept all custom options as **kwargs, instead of expecting them in config['custom_model_config']!
# 2024-11-24 03:38:55,347	INFO trainable.py:161 -- Trainable.setup took 16.301 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2024-11-24 03:38:55,349	WARNING util.py:61 -- Install gputil for GPU system monitoring.
# Training iteration 0, Hyperparameter tuned = 0.6
# Training iteration 1, Hyperparameter tuned = 0.6
# Epoch 1: Policy Loss=-0.005836177803575993, Value Loss=9.835684070587158
# Training iteration 2, Hyperparameter tuned = 0.6
# Epoch 2: Policy Loss=-0.013370498493313789, Value Loss=9.444554018974305
# Training iteration 3, Hyperparameter tuned = 0.6
# Epoch 3: Policy Loss=-0.006897195652127266, Value Loss=9.770695226192474
# Training iteration 4, Hyperparameter tuned = 0.6
# Epoch 4: Policy Loss=-0.01638596427626908, Value Loss=9.735419504642486
# Training iteration 5, Hyperparameter tuned = 0.6
# Epoch 5: Policy Loss=-0.013846501111984252, Value Loss=9.663845126628877
# Training iteration 6, Hyperparameter tuned = 0.6
# Epoch 6: Policy Loss=-0.021742190569639205, Value Loss=9.011059602499008
# Training iteration 7, Hyperparameter tuned = 0.6
# Epoch 7: Policy Loss=-0.009781904816627503, Value Loss=8.54782578110695
# Training iteration 8, Hyperparameter tuned = 0.6
# Epoch 8: Policy Loss=-0.021056673601269723, Value Loss=9.487269670963288
# Training iteration 9, Hyperparameter tuned = 0.6
# Epoch 9: Policy Loss=-0.018201434584334493, Value Loss=8.752387183904649
# Training iteration 10, Hyperparameter tuned = 0.6
# Epoch 10: Policy Loss=-0.02550581408664584, Value Loss=9.085764274597167
# Training iteration 11, Hyperparameter tuned = 0.6
# Epoch 11: Policy Loss=-0.023329002670943736, Value Loss=9.35440397977829
# Training iteration 12, Hyperparameter tuned = 0.6
# Epoch 12: Policy Loss=-0.025908707901835443, Value Loss=9.181861333847046
# Training iteration 13, Hyperparameter tuned = 0.6
# Epoch 13: Policy Loss=-0.01864796917885542, Value Loss=9.2744988656044
# Training iteration 14, Hyperparameter tuned = 0.6
# Epoch 14: Policy Loss=-0.013984468467533588, Value Loss=9.700056483745575
# Training iteration 15, Hyperparameter tuned = 0.6
# Epoch 15: Policy Loss=-0.02831258676946163, Value Loss=9.321260159015656
# Training iteration 16, Hyperparameter tuned = 0.6
# Epoch 16: Policy Loss=-0.01896744027733803, Value Loss=9.433762302398682
# Training iteration 17, Hyperparameter tuned = 0.6
# Epoch 17: Policy Loss=-0.022385767996311187, Value Loss=9.330739560127258
# Training iteration 18, Hyperparameter tuned = 0.6
# Epoch 18: Policy Loss=-0.01921352431178093, Value Loss=9.416720116138459
# Training iteration 19, Hyperparameter tuned = 0.6
# Epoch 19: Policy Loss=-0.02497423492372036, Value Loss=9.160635434389114
# Training iteration 20, Hyperparameter tuned = 0.6
# Epoch 20: Policy Loss=-0.016104130148887633, Value Loss=9.178158462047577
# Training iteration 21, Hyperparameter tuned = 0.6
# Epoch 21: Policy Loss=-0.03181368716061115, Value Loss=9.467228388786316
# Training iteration 22, Hyperparameter tuned = 0.6
# Epoch 22: Policy Loss=-0.01985933870077133, Value Loss=9.023146533966065
# Training iteration 23, Hyperparameter tuned = 0.6
# Epoch 23: Policy Loss=-0.01912611048668623, Value Loss=9.70574019908905
# Training iteration 24, Hyperparameter tuned = 0.6
# Epoch 24: Policy Loss=-0.010554622560739517, Value Loss=8.91323995232582
# Training iteration 25, Hyperparameter tuned = 0.6
# Epoch 25: Policy Loss=-0.025496734492480754, Value Loss=9.918505437374115
# Training iteration 26, Hyperparameter tuned = 0.6
# Epoch 26: Policy Loss=-0.011919488683342933, Value Loss=9.772129211425781
# Training iteration 27, Hyperparameter tuned = 0.6
# Epoch 27: Policy Loss=-0.01621257483959198, Value Loss=9.292020041942596
# Training iteration 28, Hyperparameter tuned = 0.6
# Epoch 28: Policy Loss=-0.021488199979066848, Value Loss=9.056377143859864
# Training iteration 29, Hyperparameter tuned = 0.6
# Epoch 29: Policy Loss=-0.012046115398406982, Value Loss=9.722333567142487
# Training iteration 30, Hyperparameter tuned = 0.6
# Epoch 30: Policy Loss=-0.022481139078736306, Value Loss=8.593095481395721
# Training iteration 31, Hyperparameter tuned = 0.6
# Epoch 31: Policy Loss=-0.01762719303369522, Value Loss=9.556477172374725
# Training iteration 32, Hyperparameter tuned = 0.6
# Epoch 32: Policy Loss=-0.01696763750165701, Value Loss=9.559506747722626
# Training iteration 33, Hyperparameter tuned = 0.6
# Epoch 33: Policy Loss=-0.0132643480040133, Value Loss=8.844851831197738
# Training iteration 34, Hyperparameter tuned = 0.6
# Epoch 34: Policy Loss=-0.01606066642329097, Value Loss=9.09915606021881
# Training iteration 35, Hyperparameter tuned = 0.6
# Epoch 35: Policy Loss=-0.015836594440042973, Value Loss=9.214705548286439
# Training iteration 36, Hyperparameter tuned = 0.6
# Epoch 36: Policy Loss=-0.02792421966791153, Value Loss=9.397702078819275
# Training iteration 37, Hyperparameter tuned = 0.6
# Epoch 37: Policy Loss=-0.016767780184745788, Value Loss=9.714068040847778
# Training iteration 38, Hyperparameter tuned = 0.6
# Epoch 38: Policy Loss=-0.019508993625640868, Value Loss=9.382447378635407
# Training iteration 39, Hyperparameter tuned = 0.6
# Epoch 39: Policy Loss=-0.014473383910953999, Value Loss=9.559324798583985
# Training iteration 40, Hyperparameter tuned = 0.6
# Epoch 40: Policy Loss=-0.012947555836290122, Value Loss=9.790225758552552
# Training iteration 41, Hyperparameter tuned = 0.6
# Epoch 41: Policy Loss=-0.019764915890991688, Value Loss=9.402593884468079
# Training iteration 42, Hyperparameter tuned = 0.6
# Epoch 42: Policy Loss=-0.01936309790238738, Value Loss=9.618938686847686
# Training iteration 43, Hyperparameter tuned = 0.6
# Epoch 43: Policy Loss=-0.02255017688497901, Value Loss=9.079319900274276
# Training iteration 44, Hyperparameter tuned = 0.6
# Epoch 44: Policy Loss=-0.010968992114067077, Value Loss=9.459136967658997
# Training iteration 45, Hyperparameter tuned = 0.6
# Epoch 45: Policy Loss=-0.017199115697294473, Value Loss=9.544380710124969
# Training iteration 46, Hyperparameter tuned = 0.6
# Epoch 46: Policy Loss=-0.023858724664896726, Value Loss=9.377369062900543
# Training iteration 47, Hyperparameter tuned = 0.6
# Epoch 47: Policy Loss=-0.038973632268607616, Value Loss=9.179657571315765
# Training iteration 48, Hyperparameter tuned = 0.6
# Epoch 48: Policy Loss=-0.02054310753941536, Value Loss=8.925115333795548
# Training iteration 49, Hyperparameter tuned = 0.6
# Epoch 49: Policy Loss=-0.01706158012151718, Value Loss=9.083233910799027
# 2024-11-24 04:31:59,686	WARNING catalog.py:547 -- Custom ModelV2 should accept all custom options as **kwargs, instead of expecting them in config['custom_model_config']!
# 2024-11-24 04:31:59,727	INFO trainable.py:161 -- Trainable.setup took 20.655 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2024-11-24 04:31:59,729	WARNING util.py:61 -- Install gputil for GPU system monitoring.
# Training iteration 0, Hyperparameter tuned = 0.7
# Training iteration 1, Hyperparameter tuned = 0.7
# Epoch 1: Policy Loss=-0.008361884076148272, Value Loss=9.867675030231476
# Training iteration 2, Hyperparameter tuned = 0.7
# Epoch 2: Policy Loss=-0.0194515673071146, Value Loss=9.847053935527802
# Training iteration 3, Hyperparameter tuned = 0.7
# Epoch 3: Policy Loss=-0.02213939657434821, Value Loss=9.435030589103699
# Training iteration 4, Hyperparameter tuned = 0.7
# Epoch 4: Policy Loss=-0.019628737159073352, Value Loss=9.753705420494079
# Training iteration 5, Hyperparameter tuned = 0.7
# Epoch 5: Policy Loss=-0.01662942623719573, Value Loss=10.0
# Training iteration 6, Hyperparameter tuned = 0.7
# Epoch 6: Policy Loss=-0.007560207992792129, Value Loss=9.701692733764649
# Training iteration 7, Hyperparameter tuned = 0.7
# Epoch 7: Policy Loss=-0.01673059230670333, Value Loss=9.838848795890808
# Training iteration 8, Hyperparameter tuned = 0.7
# Epoch 8: Policy Loss=-0.021415980383753776, Value Loss=9.798134446144104
# Training iteration 9, Hyperparameter tuned = 0.7
# Epoch 9: Policy Loss=-0.010041548758745194, Value Loss=9.705228083133697
# Training iteration 10, Hyperparameter tuned = 0.7
# Epoch 10: Policy Loss=-0.019331803377717734, Value Loss=9.780775351524353
# Training iteration 11, Hyperparameter tuned = 0.7
# Epoch 11: Policy Loss=-0.014202359169721603, Value Loss=9.769561018943786
# Training iteration 12, Hyperparameter tuned = 0.7
# Epoch 12: Policy Loss=-0.019483963660895824, Value Loss=9.681211309432983
# Training iteration 13, Hyperparameter tuned = 0.7
# Epoch 13: Policy Loss=-0.018354512453079223, Value Loss=9.793947801589965
# Training iteration 14, Hyperparameter tuned = 0.7
# Epoch 14: Policy Loss=-0.013990078561473638, Value Loss=9.83100487947464
# Training iteration 15, Hyperparameter tuned = 0.7
# Epoch 15: Policy Loss=-0.0226575399376452, Value Loss=9.825000247955323
# Training iteration 16, Hyperparameter tuned = 0.7
# Epoch 16: Policy Loss=-0.027012713216245175, Value Loss=9.725729060173034
# Training iteration 17, Hyperparameter tuned = 0.7
# Epoch 17: Policy Loss=-0.018531232513487338, Value Loss=9.680477643013
# Training iteration 18, Hyperparameter tuned = 0.7
# Epoch 18: Policy Loss=-0.020968921873718502, Value Loss=9.656684575080872
# Training iteration 19, Hyperparameter tuned = 0.7
# Epoch 19: Policy Loss=-0.018520013093948365, Value Loss=9.494091448783875
# Training iteration 20, Hyperparameter tuned = 0.7
# Epoch 20: Policy Loss=-0.017966324053704737, Value Loss=9.758535559177398
# Training iteration 21, Hyperparameter tuned = 0.7
# Epoch 21: Policy Loss=-0.024085578536614777, Value Loss=9.71511864900589
# Training iteration 22, Hyperparameter tuned = 0.7
# Epoch 22: Policy Loss=-0.0233537639118731, Value Loss=9.868810584545136
# Training iteration 23, Hyperparameter tuned = 0.7
# Epoch 23: Policy Loss=-0.012091732360422611, Value Loss=9.981852266788483
# Training iteration 24, Hyperparameter tuned = 0.7
# Epoch 24: Policy Loss=-0.021636938322335483, Value Loss=9.877865409851074
# Training iteration 25, Hyperparameter tuned = 0.7
# Epoch 25: Policy Loss=-0.01375874485820532, Value Loss=9.914176132678985
# Training iteration 26, Hyperparameter tuned = 0.7
# Epoch 26: Policy Loss=-0.025133561864495276, Value Loss=9.951043655872345
# Training iteration 27, Hyperparameter tuned = 0.7
# Epoch 27: Policy Loss=-0.011150038130581378, Value Loss=9.774109542369843
# Training iteration 28, Hyperparameter tuned = 0.7
# Epoch 28: Policy Loss=-0.014532789848744869, Value Loss=9.718505973815917
# Training iteration 29, Hyperparameter tuned = 0.7
# Epoch 29: Policy Loss=-0.015253857616335154, Value Loss=9.854182455539704
# Training iteration 30, Hyperparameter tuned = 0.7
# Epoch 30: Policy Loss=-0.02386471539735794, Value Loss=9.767272222042084
# Training iteration 31, Hyperparameter tuned = 0.7
# Epoch 31: Policy Loss=-0.015125244278460742, Value Loss=9.576860063076019
# Training iteration 32, Hyperparameter tuned = 0.7
# Epoch 32: Policy Loss=-0.01687109801918268, Value Loss=9.493965950012207
# Training iteration 33, Hyperparameter tuned = 0.7
# Epoch 33: Policy Loss=-0.012114912429824471, Value Loss=9.783336126804352
# Training iteration 34, Hyperparameter tuned = 0.7
# Epoch 34: Policy Loss=-0.0179155607894063, Value Loss=9.621510412693024
# Training iteration 35, Hyperparameter tuned = 0.7
# Epoch 35: Policy Loss=-0.018270663507282733, Value Loss=9.811819951534272
# Training iteration 36, Hyperparameter tuned = 0.7
# Epoch 36: Policy Loss=-0.021035584658384322, Value Loss=9.746942882537843
# Training iteration 37, Hyperparameter tuned = 0.7
# Epoch 37: Policy Loss=-0.01292738071642816, Value Loss=9.796611807346345
# Training iteration 38, Hyperparameter tuned = 0.7
# Epoch 38: Policy Loss=-0.016112825237214565, Value Loss=9.69026185274124
# Training iteration 39, Hyperparameter tuned = 0.7
# Epoch 39: Policy Loss=-0.027683265167288484, Value Loss=9.812077174186706
# Training iteration 40, Hyperparameter tuned = 0.7
# Epoch 40: Policy Loss=-0.027294636433944107, Value Loss=9.451718828678132
# Training iteration 41, Hyperparameter tuned = 0.7
# Epoch 41: Policy Loss=-0.011749322079122066, Value Loss=9.802047109603881
# Training iteration 42, Hyperparameter tuned = 0.7
# Epoch 42: Policy Loss=-0.01851999156177044, Value Loss=9.529881484508515
# Training iteration 43, Hyperparameter tuned = 0.7
# Epoch 43: Policy Loss=-0.009506210861727595, Value Loss=9.573972117900848
# Training iteration 44, Hyperparameter tuned = 0.7
# Epoch 44: Policy Loss=-0.020035623284056784, Value Loss=9.89638782978058
# Training iteration 45, Hyperparameter tuned = 0.7
# Epoch 45: Policy Loss=-0.020577461011707782, Value Loss=9.77796025276184
# Training iteration 46, Hyperparameter tuned = 0.7
# Epoch 46: Policy Loss=-0.016463195346295832, Value Loss=9.60355906009674
# Training iteration 47, Hyperparameter tuned = 0.7
# Epoch 47: Policy Loss=-0.010811516884714364, Value Loss=9.785416951179505
# Training iteration 48, Hyperparameter tuned = 0.7
# Epoch 48: Policy Loss=-0.01545289123430848, Value Loss=9.635592069625854
# Training iteration 49, Hyperparameter tuned = 0.7
# Epoch 49: Policy Loss=-0.027799253761768342, Value Loss=9.652108726501465
# 2024-11-24 05:25:13,758	WARNING catalog.py:547 -- Custom ModelV2 should accept all custom options as **kwargs, instead of expecting them in config['custom_model_config']!
# 2024-11-24 05:25:13,798	INFO trainable.py:161 -- Trainable.setup took 19.284 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2024-11-24 05:25:13,800	WARNING util.py:61 -- Install gputil for GPU system monitoring.
# Training iteration 0, Hyperparameter tuned = 0.8
# Training iteration 1, Hyperparameter tuned = 0.8
# Epoch 1: Policy Loss=-0.01105293121188879, Value Loss=9.909438769817353
# Training iteration 2, Hyperparameter tuned = 0.8
# Epoch 2: Policy Loss=-0.02520584560930729, Value Loss=9.890940673351288
# Training iteration 3, Hyperparameter tuned = 0.8
# Epoch 3: Policy Loss=-0.021190248653292654, Value Loss=9.968205199241638
# Training iteration 4, Hyperparameter tuned = 0.8
# Epoch 4: Policy Loss=-0.014006019178777933, Value Loss=9.954095327854157
# Training iteration 5, Hyperparameter tuned = 0.8
# Epoch 5: Policy Loss=-0.011931533745955675, Value Loss=9.959318294525147
# Training iteration 6, Hyperparameter tuned = 0.8
# Epoch 6: Policy Loss=-0.018148581087589263, Value Loss=9.911738867759704
# Training iteration 7, Hyperparameter tuned = 0.8
# Epoch 7: Policy Loss=-0.022495721019804477, Value Loss=9.865124144554137
# Training iteration 8, Hyperparameter tuned = 0.8
# Epoch 8: Policy Loss=-0.013580321744084358, Value Loss=9.752995958328247
# Training iteration 9, Hyperparameter tuned = 0.8
# Epoch 9: Policy Loss=-0.02274569820612669, Value Loss=9.996798622608186
# Training iteration 10, Hyperparameter tuned = 0.8
# Epoch 10: Policy Loss=-0.020392779633402823, Value Loss=9.918472647666931
# Training iteration 11, Hyperparameter tuned = 0.8
# Epoch 11: Policy Loss=-0.01573775716125965, Value Loss=9.969032452106475
# Training iteration 12, Hyperparameter tuned = 0.8
# Epoch 12: Policy Loss=-0.020611793845891953, Value Loss=9.935719513893128
# Training iteration 13, Hyperparameter tuned = 0.8
# Epoch 13: Policy Loss=-0.02388693630695343, Value Loss=9.92263491153717
# Training iteration 14, Hyperparameter tuned = 0.8
# Epoch 14: Policy Loss=-0.020651365667581557, Value Loss=9.877409155368804
# Training iteration 15, Hyperparameter tuned = 0.8
# Epoch 15: Policy Loss=-0.023529147282242775, Value Loss=10.0
# Training iteration 16, Hyperparameter tuned = 0.8
# Epoch 16: Policy Loss=-0.017292147940024732, Value Loss=9.98352914571762
# Training iteration 17, Hyperparameter tuned = 0.8
# Epoch 17: Policy Loss=-0.01712277352809906, Value Loss=9.910224575996398
# Training iteration 18, Hyperparameter tuned = 0.8
# Epoch 18: Policy Loss=-0.018350769206881522, Value Loss=9.745465545654296
# Training iteration 19, Hyperparameter tuned = 0.8
# Epoch 19: Policy Loss=-0.024437199160456658, Value Loss=9.968112545013428
# Training iteration 20, Hyperparameter tuned = 0.8
# Epoch 20: Policy Loss=-0.01271632082760334, Value Loss=9.989087812900543
# Training iteration 21, Hyperparameter tuned = 0.8
# Epoch 21: Policy Loss=-0.015006444230675698, Value Loss=9.791208674907685
# Training iteration 22, Hyperparameter tuned = 0.8
# Epoch 22: Policy Loss=-0.009652742333710194, Value Loss=9.95255217075348
# Training iteration 23, Hyperparameter tuned = 0.8
# Epoch 23: Policy Loss=-0.02022241458296776, Value Loss=10.0
# Training iteration 24, Hyperparameter tuned = 0.8
# Epoch 24: Policy Loss=-0.012231492027640343, Value Loss=9.980835394859314
# Training iteration 25, Hyperparameter tuned = 0.8
# Epoch 25: Policy Loss=-0.010520277991890908, Value Loss=9.908033912181855
# Training iteration 26, Hyperparameter tuned = 0.8
# Epoch 26: Policy Loss=-0.02877028752118349, Value Loss=9.94475276708603
# Training iteration 27, Hyperparameter tuned = 0.8
# Epoch 27: Policy Loss=-0.012737978100776672, Value Loss=9.902347843647004
# Training iteration 28, Hyperparameter tuned = 0.8
# Epoch 28: Policy Loss=-0.011546667413786054, Value Loss=9.984830391407012
# Training iteration 29, Hyperparameter tuned = 0.8
# Epoch 29: Policy Loss=-0.02038483500480652, Value Loss=9.858523354530334
# Training iteration 30, Hyperparameter tuned = 0.8
# Epoch 30: Policy Loss=-0.020478297076188028, Value Loss=9.843568680286408
# Training iteration 31, Hyperparameter tuned = 0.8
# Epoch 31: Policy Loss=-0.01132606429979205, Value Loss=9.914077906608581
# Training iteration 32, Hyperparameter tuned = 0.8
# Epoch 32: Policy Loss=-0.011196512952446938, Value Loss=9.85732382297516
# Training iteration 33, Hyperparameter tuned = 0.8
# Epoch 33: Policy Loss=-0.012785685621201992, Value Loss=10.0
# Training iteration 34, Hyperparameter tuned = 0.8
# Epoch 34: Policy Loss=-0.01848835527896881, Value Loss=10.0
# Training iteration 35, Hyperparameter tuned = 0.8
# Epoch 35: Policy Loss=-0.018613298758864402, Value Loss=9.914163210391997
# Training iteration 36, Hyperparameter tuned = 0.8
# Epoch 36: Policy Loss=-0.02139008939266205, Value Loss=9.890339076519012
# Training iteration 37, Hyperparameter tuned = 0.8
# Epoch 37: Policy Loss=-0.021663227677345277, Value Loss=9.909526901245117
# Training iteration 38, Hyperparameter tuned = 0.8
# Epoch 38: Policy Loss=-0.025154845640063286, Value Loss=9.957130608558655
# Training iteration 39, Hyperparameter tuned = 0.8
# Epoch 39: Policy Loss=-0.015936673507094382, Value Loss=9.868417210578919
# Training iteration 40, Hyperparameter tuned = 0.8
# Epoch 40: Policy Loss=-0.01370272308588028, Value Loss=9.9628701877594
# Training iteration 41, Hyperparameter tuned = 0.8
# Epoch 41: Policy Loss=-0.010677162129431962, Value Loss=9.94791716337204
# Training iteration 42, Hyperparameter tuned = 0.8
# Epoch 42: Policy Loss=-0.022155176415108144, Value Loss=9.993610451221466
# Training iteration 43, Hyperparameter tuned = 0.8
# Epoch 43: Policy Loss=-0.018979337066411972, Value Loss=9.834967062473297
# Training iteration 44, Hyperparameter tuned = 0.8
# Epoch 44: Policy Loss=-0.0223344074934721, Value Loss=9.881059610843659
# Training iteration 45, Hyperparameter tuned = 0.8
# Epoch 45: Policy Loss=-0.018071396313607692, Value Loss=9.864279329776764
# Training iteration 46, Hyperparameter tuned = 0.8
# Epoch 46: Policy Loss=-0.015119493901729585, Value Loss=9.994692044258118
# Training iteration 47, Hyperparameter tuned = 0.8
# Epoch 47: Policy Loss=-0.028530134316533805, Value Loss=9.866633672714233
# Training iteration 48, Hyperparameter tuned = 0.8
# Epoch 48: Policy Loss=-0.016343439151532947, Value Loss=9.818677215576171
# Training iteration 49, Hyperparameter tuned = 0.8
# Epoch 49: Policy Loss=-0.014110245890915394, Value Loss=9.845175960063933
# 2024-11-24 06:18:18,242	WARNING catalog.py:547 -- Custom ModelV2 should accept all custom options as **kwargs, instead of expecting them in config['custom_model_config']!
# 2024-11-24 06:18:18,282	INFO trainable.py:161 -- Trainable.setup took 18.358 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2024-11-24 06:18:18,285	WARNING util.py:61 -- Install gputil for GPU system monitoring.
# Training iteration 0, Hyperparameter tuned = 0.9
# Training iteration 1, Hyperparameter tuned = 0.9
# Epoch 1: Policy Loss=-0.014962736796587706, Value Loss=9.980554165840148
# Training iteration 2, Hyperparameter tuned = 0.9
# Epoch 2: Policy Loss=-0.014169022664427757, Value Loss=9.930001072883606
# Training iteration 3, Hyperparameter tuned = 0.9
# Epoch 3: Policy Loss=-0.009410678138956428, Value Loss=9.997337601184846
# Training iteration 4, Hyperparameter tuned = 0.9
# Epoch 4: Policy Loss=-0.012938966751098633, Value Loss=9.96618952035904
# Training iteration 5, Hyperparameter tuned = 0.9
# Epoch 5: Policy Loss=-0.011278200522065162, Value Loss=9.939348747730255
# Training iteration 6, Hyperparameter tuned = 0.9
# Epoch 6: Policy Loss=-0.020005373135209083, Value Loss=9.942514605522156
# Training iteration 7, Hyperparameter tuned = 0.9
# Epoch 7: Policy Loss=-0.01442433575168252, Value Loss=10.0
# Training iteration 8, Hyperparameter tuned = 0.9
# Epoch 8: Policy Loss=-0.013417332917451858, Value Loss=9.951807832717895
# Training iteration 9, Hyperparameter tuned = 0.9
# Epoch 9: Policy Loss=-0.014358950927853584, Value Loss=9.980861158370972
# Training iteration 10, Hyperparameter tuned = 0.9
# Epoch 10: Policy Loss=-0.024566154927015305, Value Loss=9.908055760860442
# Training iteration 11, Hyperparameter tuned = 0.9
# Epoch 11: Policy Loss=-0.015190235115587711, Value Loss=9.980267140865326
# Training iteration 12, Hyperparameter tuned = 0.9
# Epoch 12: Policy Loss=-0.024467964813811704, Value Loss=9.990515406131744
# Training iteration 13, Hyperparameter tuned = 0.9
# Epoch 13: Policy Loss=-0.014452179074287414, Value Loss=9.981196792125703
# Training iteration 14, Hyperparameter tuned = 0.9
# Epoch 14: Policy Loss=-0.01816791210323572, Value Loss=9.947532050609588
# Training iteration 15, Hyperparameter tuned = 0.9
# Epoch 15: Policy Loss=-0.015453436896204948, Value Loss=9.94176664829254
# Training iteration 16, Hyperparameter tuned = 0.9
# Epoch 16: Policy Loss=-0.027046803086996078, Value Loss=9.982559423446656
# Training iteration 17, Hyperparameter tuned = 0.9
# Epoch 17: Policy Loss=-0.008841480109840632, Value Loss=9.97392580986023
# Training iteration 18, Hyperparameter tuned = 0.9
# Epoch 18: Policy Loss=-0.014547401666641235, Value Loss=9.982523422241211
# Training iteration 19, Hyperparameter tuned = 0.9
# Epoch 19: Policy Loss=-0.01927803410682827, Value Loss=9.951826477050782
# Training iteration 20, Hyperparameter tuned = 0.9
# Epoch 20: Policy Loss=-0.019687520302832127, Value Loss=9.963029429912567
# Training iteration 21, Hyperparameter tuned = 0.9
# Epoch 21: Policy Loss=-0.011806868743151426, Value Loss=9.98055011510849
# Training iteration 22, Hyperparameter tuned = 0.9
# Epoch 22: Policy Loss=-0.019225918194279074, Value Loss=9.930172536373139
# Training iteration 23, Hyperparameter tuned = 0.9
# Epoch 23: Policy Loss=-0.016668353993445635, Value Loss=10.0
# Training iteration 24, Hyperparameter tuned = 0.9
# Epoch 24: Policy Loss=-0.014790287166833877, Value Loss=9.99302822828293
# Training iteration 25, Hyperparameter tuned = 0.9
# Epoch 25: Policy Loss=-0.014352090805768967, Value Loss=9.96147661447525
# Training iteration 26, Hyperparameter tuned = 0.9
# Epoch 26: Policy Loss=-0.015052824858576059, Value Loss=9.982636351585388
# Training iteration 27, Hyperparameter tuned = 0.9
# Epoch 27: Policy Loss=-0.018718151208013296, Value Loss=9.934833879470824
# Training iteration 28, Hyperparameter tuned = 0.9
# Epoch 28: Policy Loss=-0.022169523015618323, Value Loss=9.966123204231263
# Training iteration 29, Hyperparameter tuned = 0.9
# Epoch 29: Policy Loss=-0.026661752723157406, Value Loss=9.96769045829773
# Training iteration 30, Hyperparameter tuned = 0.9
# Epoch 30: Policy Loss=-0.010596194379031658, Value Loss=10.0
# Training iteration 31, Hyperparameter tuned = 0.9
# Epoch 31: Policy Loss=-0.019426301810890435, Value Loss=9.982910664081574
# Training iteration 32, Hyperparameter tuned = 0.9
# Epoch 32: Policy Loss=-0.016247815862298013, Value Loss=9.966246299743652
# Training iteration 33, Hyperparameter tuned = 0.9
# Epoch 33: Policy Loss=-0.01671947620809078, Value Loss=9.918539962768556
# Training iteration 34, Hyperparameter tuned = 0.9
# Epoch 34: Policy Loss=-0.014430861216969787, Value Loss=10.0
# Training iteration 35, Hyperparameter tuned = 0.9
# Epoch 35: Policy Loss=-0.019686214393004775, Value Loss=9.982623298168182
# Training iteration 36, Hyperparameter tuned = 0.9
# Epoch 36: Policy Loss=-0.023290354385972024, Value Loss=10.0
# Training iteration 37, Hyperparameter tuned = 0.9
# Epoch 37: Policy Loss=-0.016140681505203248, Value Loss=9.886088926792144
# Training iteration 38, Hyperparameter tuned = 0.9
# Epoch 38: Policy Loss=-0.014559623301029206, Value Loss=9.9712229013443
# Training iteration 39, Hyperparameter tuned = 0.9
# Epoch 39: Policy Loss=-0.01164711445569992, Value Loss=9.969592788219451
# Training iteration 40, Hyperparameter tuned = 0.9
# Epoch 40: Policy Loss=-0.008595925029367209, Value Loss=10.0
# Training iteration 41, Hyperparameter tuned = 0.9
# Epoch 41: Policy Loss=-0.030861323550343513, Value Loss=9.969735474586487
# Training iteration 42, Hyperparameter tuned = 0.9
# Epoch 42: Policy Loss=-0.0207116661965847, Value Loss=9.980677869319916
# Training iteration 43, Hyperparameter tuned = 0.9
# Epoch 43: Policy Loss=-0.009988071620464325, Value Loss=9.91330870628357
# Training iteration 44, Hyperparameter tuned = 0.9
# Epoch 44: Policy Loss=-0.01678851366043091, Value Loss=10.0
# Training iteration 45, Hyperparameter tuned = 0.9
# Epoch 45: Policy Loss=-0.015032222159206868, Value Loss=9.948151412010192
# Training iteration 46, Hyperparameter tuned = 0.9
# Epoch 46: Policy Loss=-0.019250478297472, Value Loss=9.89525226354599
# Training iteration 47, Hyperparameter tuned = 0.9
# Epoch 47: Policy Loss=-0.013469108268618584, Value Loss=10.0
# Training iteration 48, Hyperparameter tuned = 0.9
# Epoch 48: Policy Loss=-0.024244067333638666, Value Loss=9.954701464176178
# Training iteration 49, Hyperparameter tuned = 0.9
# Epoch 49: Policy Loss=-0.019515690580010413, Value Loss=9.907531785964967

# %% [markdown]
# Save the model

# %%
checkpoint_path = algo.save()
print(f"Checkpoint saved at: {checkpoint_path}")
# Out:
# Checkpoint saved at: TrainingResult(checkpoint=Checkpoint(filesystem=local, path=/tmp/tmp_inr14yc), metrics={'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'default_policy': {'custom_metrics': {}, 'learner_stats': {'cur_kl_coeff': 0.675, 'cur_lr': 0.00010000000000000002, 'total_loss': 9.896782217025757, 'policy_loss': -0.019515690580010413, 'vf_loss': 9.907531785964967, 'vf_explained_var': 1.227840781211853e-05, 'kl': 0.012986819887300953, 'entropy': 5.505807936191559, 'entropy_coeff': 0.0}, 'model': {}, 'num_grad_updates_lifetime': 19800.5, 'diff_num_grad_updates_vs_sampler_policy': 199.5}}, 'num_env_steps_sampled': 25600, 'num_env_steps_trained': 25600, 'num_agent_steps_sampled': 25600, 'num_agent_steps_trained': 25600}, 'env_runners': {'episode_reward_max': 5783738.927481829, 'episode_reward_min': -1096824.738822885, 'episode_reward_mean': 45472.59175733694, 'episode_len_mean': 237.0, 'episode_media': {}, 'episodes_timesteps_total': 23700, 'policy_reward_min': {'default_policy': -1096824.738822885}, 'policy_reward_max': {'default_policy': 5783738.927481829}, 'policy_reward_mean': {'default_policy': 45472.59175733694}, 'custom_metrics': {'final_net_price_mean': 10579.821, 'final_net_price_min': 7846.188, 'final_net_price_max': 15689.324}, 'hist_stats': {'episode_reward': [-4176.034061898662, 31755.786858533047, -4169.868822576467, -30258.306301294448, -1097.5735901185797, -18885.257180308818, 19487.16823344024, -62625.5131003765, -92243.20322609131, -6971.837803824495, -2731.16109940286, -33161.41328534489, 44858.5476398269, 73281.09489784564, -14148.09476251862, -13011.380453830856, 4288.120811605661, 6414.39364676829, -9598.593528743242, -3028.2409598843124, -359523.89358800574, -14300.508372277991, -13130.930313868821, -9382.210573629958, -15822.52190630648, -22086.129725695027, -31274.85566101778, -76850.29938815888, -9122.329265527806, -30456.963299533294, -4764.972892443885, -95172.0065400543, -12506.115861630202, 13044.446693006907, 65071.132337544535, -103250.13224277276, 17970.584895237247, 16368.352826076942, 8453.10515355827, -66876.78648812066, -10365.263369153994, -9803.327758434083, -5235.341227996306, -10512.828428183071, 984.8604889978989, -2153.8959905496295, -62160.45417396653, -40762.07981783387, -11248.218219083245, -32262.43028580356, 29349.511328555087, -16660.533652213344, -8895.42408259511, 18461.218238494963, -1132.7603973348296, 17883.22856762041, 3754.5346895839984, -28152.12884083147, 2255.815740542957, -18593.51361174569, 15558.188636799587, -662.8332716288692, -11798.184689498283, -9388.733379038731, -98768.83393380365, 91262.89154525369, -52439.51733979056, 1469.0700229590311, -47882.707205456165, -13523.15657703011, 1002158.9489557914, 10226.910636029488, 11136.245271417703, 2804.6146609867974, -10663.927393528462, 9082.274112950212, -22393.631891372228, 19457.296069903572, 10679.415989388333, -48047.971673013344, -1493.5748896360947, -13420.619113023195, -43597.91949184247, -1096824.738822885, -2190.2386031587143, 342.8112924712723, -4135.828365008114, 1656.5879593501734, 33197.87889053592, 5180.872399308422, -5933.471207786001, -14159.740296961301, -21354.70290337948, 5783738.927481829, 6331.636862179592, -6464.588852842801, -2613.4412967652406, -6680.509158676979, 116888.80753358596, 5408.09887282329], 'episode_lengths': [237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237], 'policy_default_policy_reward': [-4176.034061898662, 31755.786858533047, -4169.868822576467, -30258.306301294448, -1097.5735901185797, -18885.257180308818, 19487.1 ...
