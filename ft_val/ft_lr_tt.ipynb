# %%
# !pip install tushare
import tushare as ts
# !pip install alpha_vantage
from alpha_vantage.timeseries import TimeSeries
import requests
import pandas as pd
#!pip install -U "ray[default]"
# !pip install gymnasium
#!pip install 'ray[rllib]'
# !pip install 'ray[all]'
import gymnasium
from gymnasium import spaces
import ray
from ray import tune
from ray.rllib.algorithms.ppo import PPO
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
from ray.rllib.models.torch.torch_modelv2 import TorchModelV2
from ray.rllib.models.modelv2 import ModelV2
from ray.rllib.utils.annotations import override
from ray.rllib.models import ModelCatalog
from ray.rllib.models.torch.misc import SlimFC
import math
from collections import deque
from datetime import datetime, timedelta
from os import close
from ray.rllib.algorithms import ppo
from ray.rllib.algorithms.ppo import PPO  # Import PPOTrainer
from ray.rllib.algorithms.ppo import PPOConfig
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import ray
from ray import tune
from ray.rllib.algorithms.ppo import PPO
from ray.rllib.models.torch.torch_modelv2 import TorchModelV2
from ray.rllib.models.modelv2 import ModelV2
from ray.rllib.utils.annotations import override
from ray.rllib.models import ModelCatalog
from ray.rllib.models.torch.misc import SlimFC
from ray.rllib.algorithms import ppo
from ray.rllib.algorithms.ppo import PPO
from ray.rllib.algorithms.ppo import PPOConfig
from ray.rllib.algorithms.callbacks import DefaultCallbacks
from ray.rllib.env import EnvContext
from ray.tune.registry import register_env
np.random.seed(135)
torch.manual_seed(135)
# Out:
# Collecting tushare
#   Downloading tushare-1.4.13-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from tushare) (2.2.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from tushare) (2.32.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from tushare) (5.3.0)
# Collecting simplejson (from tushare)
#   Downloading simplejson-3.19.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.2 kB)
# Collecting bs4 (from tushare)
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Requirement already satisfied: websocket-client>=0.57.0 in /usr/local/lib/python3.10/dist-packages (from tushare) (1.8.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from tushare) (4.66.6)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4->tushare) (4.12.3)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas->tushare) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->tushare) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->tushare) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->tushare) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->tushare) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->tushare) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->tushare) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->tushare) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->tushare) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4->tushare) (2.6)
# Downloading tushare-1.4.13-py3-none-any.whl (142 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.1/142.1 kB 10.1 MB/s eta 0:00:00
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Downloading simplejson-3.19.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (137 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 kB 13.3 MB/s eta 0:00:00
# Installing collected packages: simplejson, bs4, tushare
# Successfully installed bs4-0.0.2 simplejson-3.19.3 tushare-1.4.13
# Collecting alpha_vantage
#   Downloading alpha_vantage-3.0.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from alpha_vantage) (3.11.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from alpha_vantage) (2.32.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->alpha_vantage) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->alpha_vantage) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->alpha_vantage) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->alpha_vantage) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->alpha_vantage) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->alpha_vantage) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->alpha_vantage) (1.17.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->alpha_vantage) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->alpha_vantage) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->alpha_vantage) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->alpha_vantage) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->alpha_vantage) (2024.8.30)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from multidict<7.0,>=4.5->aiohttp->alpha_vantage) (4.12.2)
# Downloading alpha_vantage-3.0.0-py3-none-any.whl (35 kB)
# Installing collected packages: alpha_vantage
# Successfully installed alpha_vantage-3.0.0
# Collecting gymnasium
#   Downloading gymnasium-1.0.0-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (3.1.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (4.12.2)
# Collecting farama-notifications>=0.0.1 (from gymnasium)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl.metadata (558 bytes)
# Downloading gymnasium-1.0.0-py3-none-any.whl (958 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 958.1/958.1 kB 22.8 MB/s eta 0:00:00
# Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Installing collected packages: farama-notifications, gymnasium
# Successfully installed farama-notifications-0.0.4 gymnasium-1.0.0
# Collecting ray[all]
#   Downloading ray-2.39.0-cp310-cp310-manylinux2014_x86_64.whl.metadata (17 kB)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from ray[all]) (8.1.7)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from ray[all]) (3.16.1)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from ray[all]) (4.23.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ray[all]) (1.1.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from ray[all]) (24.2)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /usr/local/lib/python3.10/dist-packages (from ray[all]) (4.25.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from ray[all]) (6.0.2)
# Requirement already satisfied: aiosignal in /usr/local/lib/python3.10/dist-packages (from ray[all]) (1.3.1)
# Requirement already satisfied: frozenlist in /usr/local/lib/python3.10/dist-packages (from ray[all]) (1.5.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from ray[all]) (2.32.3)
# Requirement already satisfied: grpcio in /usr/local/lib/python3.10/dist-packages (from ray[all]) (1.68.0)
# Collecting opentelemetry-exporter-otlp (from ray[all])
#   Downloading opentelemetry_exporter_otlp-1.28.2-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: prometheus-client>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from ray[all]) (0.21.0)
# Requirement already satisfied: opentelemetry-api in /usr/local/lib/python3.10/dist-packages (from ray[all]) (1.28.2)
# Requirement already satisfied: typer in /usr/local/lib/python3.10/dist-packages (from ray[all]) (0.13.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from ray[all]) (13.9.4)
# Requirement already satisfied: gymnasium==1.0.0 in /usr/local/lib/python3.10/dist-packages (from ray[all]) (1.0.0)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.10/dist-packages (from ray[all]) (0.1.8)
# Requirement already satisfied: opentelemetry-sdk in /usr/local/lib/python3.10/dist-packages (from ray[all]) (1.28.2)
# Requirement already satisfied: aiohttp>=3.7 in /usr/local/lib/python3.10/dist-packages (from ray[all]) (3.11.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from ray[all]) (2024.10.0)
# Requirement already satisfied: pyOpenSSL in /usr/local/lib/python3.10/dist-packages (from ray[all]) (24.2.1)
# Collecting lz4 (from ray[all])
#   Downloading lz4-4.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.7 kB)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from ray[all]) (0.24.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from ray[all]) (2.2.2)
# Collecting fastapi (from ray[all])
#   Downloading fastapi-0.115.5-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: smart-open in /usr/local/lib/python3.10/dist-packages (from ray[all]) (7.0.5)
# Collecting py-spy>=0.2.0 (from ray[all])
#   Downloading py_spy-0.4.0-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (16 kB)
# Collecting virtualenv!=20.21.1,>=20.0.24 (from ray[all])
#   Downloading virtualenv-20.27.1-py3-none-any.whl.metadata (4.5 kB)
# Collecting colorful (from ray[all])
#   Downloading colorful-0.5.6-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: pyarrow>=6.0.1 in /usr/local/lib/python3.10/dist-packages (from ray[all]) (17.0.0)
# Requirement already satisfied: pydantic!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,<3 in /usr/local/lib/python3.10/dist-packages (from ray[all]) (2.9.2)
# Collecting aiohttp-cors (from ray[all])
#   Downloading aiohttp_cors-0.7.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from ray[all]) (1.13.1)
# Collecting tensorboardX>=1.9 (from ray[all])
#   Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from ray[all]) (1.26.4)
# Collecting opencensus (from ray[all])
#   Downloading opencensus-0.11.4-py2.py3-none-any.whl.metadata (12 kB)
# Collecting starlette (from ray[all])
#   Downloading starlette-0.41.3-py3-none-any.whl.metadata (6.0 kB)
# Collecting watchfiles (from ray[all])
#   Downloading watchfiles-1.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting uvicorn[standard] (from ray[all])
#   Downloading uvicorn-0.32.1-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: cupy-cuda12x in /usr/local/lib/python3.10/dist-packages (from ray[all]) (12.2.0)
# Collecting memray (from ray[all])
#   Downloading memray-1.14.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium==1.0.0->ray[all]) (3.1.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium==1.0.0->ray[all]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium==1.0.0->ray[all]) (0.0.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.7->ray[all]) (2.4.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.7->ray[all]) (24.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.7->ray[all]) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.7->ray[all]) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.7->ray[all]) (1.17.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.7->ray[all]) (4.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->ray[all]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->ray[all]) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->ray[all]) (2024.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,<3->ray[all]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,<3->ray[all]) (2.23.4)
# Collecting distlib<1,>=0.3.7 (from virtualenv!=20.21.1,>=20.0.24->ray[all])
#   Downloading distlib-0.3.9-py2.py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in /usr/local/lib/python3.10/dist-packages (from virtualenv!=20.21.1,>=20.0.24->ray[all]) (4.3.6)
# Requirement already satisfied: fastrlock>=0.5 in /usr/local/lib/python3.10/dist-packages (from cupy-cuda12x->ray[all]) (0.8.2)
# Requirement already satisfied: anyio<5,>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from starlette->ray[all]) (3.7.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray[all]) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray[all]) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray[all]) (0.21.0)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from memray->ray[all]) (3.1.4)
# Collecting textual>=0.41.0 (from memray->ray[all])
#   Downloading textual-0.87.1-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->ray[all]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->ray[all]) (2.18.0)
# Collecting opencensus-context>=0.1.3 (from opencensus->ray[all])
#   Downloading opencensus_context-0.1.3-py2.py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: six~=1.16 in /usr/local/lib/python3.10/dist-packages (from opencensus->ray[all]) (1.16.0)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from opencensus->ray[all]) (2.19.2)
# Requirement already satisfied: deprecated>=1.2.6 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-api->ray[all]) (1.2.15)
# Requirement already satisfied: importlib-metadata<=8.5.0,>=6.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-api->ray[all]) (8.5.0)
# Collecting opentelemetry-exporter-otlp-proto-grpc==1.28.2 (from opentelemetry-exporter-otlp->ray[all])
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.28.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting opentelemetry-exporter-otlp-proto-http==1.28.2 (from opentelemetry-exporter-otlp->ray[all])
#   Downloading opentelemetry_exporter_otlp_proto_http-1.28.2-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-grpc==1.28.2->opentelemetry-exporter-otlp->ray[all]) (1.66.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.28.2 (from opentelemetry-exporter-otlp-proto-grpc==1.28.2->opentelemetry-exporter-otlp->ray[all])
#   Downloading opentelemetry_exporter_otlp_proto_common-1.28.2-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.28.2 (from opentelemetry-exporter-otlp-proto-grpc==1.28.2->opentelemetry-exporter-otlp->ray[all])
#   Downloading opentelemetry_proto-1.28.2-py3-none-any.whl.metadata (2.3 kB)
# Collecting protobuf!=3.19.5,>=3.15.3 (from ray[all])
#   Downloading protobuf-5.28.3-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.49b2 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-sdk->ray[all]) (0.49b2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->ray[all]) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->ray[all]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->ray[all]) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->ray[all]) (2024.8.30)
# Requirement already satisfied: cryptography<44,>=41.0.5 in /usr/local/lib/python3.10/dist-packages (from pyOpenSSL->ray[all]) (43.0.3)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.10/dist-packages (from scikit-image->ray[all]) (3.4.2)
# Requirement already satisfied: pillow>=9.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->ray[all]) (11.0.0)
# Requirement already satisfied: imageio>=2.33 in /usr/local/lib/python3.10/dist-packages (from scikit-image->ray[all]) (2.36.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image->ray[all]) (2024.9.20)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image->ray[all]) (0.4)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open->ray[all]) (1.16.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer->ray[all]) (1.5.4)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]; extra == "all"->ray[all]) (0.14.0)
# Collecting httptools>=0.6.3 (from uvicorn[standard]; extra == "all"->ray[all])
#   Downloading httptools-0.6.4-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Collecting python-dotenv>=0.13 (from uvicorn[standard]; extra == "all"->ray[all])
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]; extra == "all"->ray[all])
#   Downloading uvloop-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]; extra == "all"->ray[all])
#   Downloading websockets-14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette->ray[all]) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette->ray[all]) (1.2.2)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography<44,>=41.0.5->pyOpenSSL->ray[all]) (1.17.1)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[all]) (1.25.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in /usr/local/lib/python3.10/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[all]) (2.27.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata<=8.5.0,>=6.0->opentelemetry-api->ray[all]) (3.21.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9->memray->ray[all]) (3.0.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->ray[all]) (0.1.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography<44,>=41.0.5->pyOpenSSL->ray[all]) (2.22)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[all]) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[all]) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[all]) (4.9)
# Requirement already satisfied: mdit-py-plugins in /usr/local/lib/python3.10/dist-packages (from markdown-it-py[linkify,plugins]>=2.1.0->textual>=0.41.0->memray->ray[all]) (0.4.2)
# Requirement already satisfied: linkify-it-py<3,>=1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py[linkify,plugins]>=2.1.0->textual>=0.41.0->memray->ray[all]) (2.0.3)
# Requirement already satisfied: uc-micro-py in /usr/local/lib/python3.10/dist-packages (from linkify-it-py<3,>=1->markdown-it-py[linkify,plugins]>=2.1.0->textual>=0.41.0->memray->ray[all]) (1.0.3)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[all]) (0.6.1)
# Downloading py_spy-0.4.0-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 55.9 MB/s eta 0:00:00
# Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 10.6 MB/s eta 0:00:00
# Downloading virtualenv-20.27.1-py3-none-any.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 75.4 MB/s eta 0:00:00
# Downloading aiohttp_cors-0.7.0-py3-none-any.whl (27 kB)
# Downloading colorful-0.5.6-py2.py3-none-any.whl (201 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.4/201.4 kB 20.9 MB/s eta 0:00:00
# Downloading fastapi-0.115.5-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.9/94.9 kB 9.5 MB/s eta 0:00:00
# Downloading starlette-0.41.3-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 7.9 MB/s eta 0:00:00
# Downloading lz4-4.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 39.9 MB/s eta 0:00:00
# Downloading memray-1.14.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (8.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 43.7 MB/s eta 0:00:00
# Downloading opencensus-0.11.4-py2.py3-none-any.whl (128 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 kB 13.5 MB/s eta 0:00:00
# Downloading opentelemetry_exporter_otlp-1.28.2-py3-none-any.whl (7.0 kB)
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.28.2-py3-none-any.whl (18 kB)
# Downloading opentelemetry_exporter_otlp_proto_http-1.28.2-py3-none-any.whl (17 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.28.2-py3-none-any.whl (18 kB)
# Downloading opentelemetry_proto-1.28.2-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 6.0 MB/s eta 0:00:00
# Downloading protobuf-5.28.3-cp38-abi3-manylinux2014_x86_64.whl (316 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.6/316.6 kB 30.3 MB/s eta 0:00:00
# Downloading ray-2.39.0-cp310-cp310-manylinux2014_x86_64.whl (66.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.3/66.3 MB 10.6 MB/s eta 0:00:00
# Downloading watchfiles-1.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (442 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.6/442.6 kB 38.5 MB/s eta 0:00:00
# Downloading distlib-0.3.9-py2.py3-none-any.whl (468 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 41.2 MB/s eta 0:00:00
# Downloading httptools-0.6.4-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (442 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.1/442.1 kB 36.3 MB/s eta 0:00:00
# Downloading opencensus_context-0.1.3-py2.py3-none-any.whl (5.1 kB)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading textual-0.87.1-py3-none-any.whl (654 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 654.7/654.7 kB 45.1 MB/s eta 0:00:00
# Downloading uvloop-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 100.2 MB/s eta 0:00:00
# Downloading websockets-14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (168 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.2/168.2 kB 18.5 MB/s eta 0:00:00
# Downloading uvicorn-0.32.1-py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.8/63.8 kB 7.2 MB/s eta 0:00:00
# Installing collected packages: py-spy, opencensus-context, distlib, colorful, websockets, virtualenv, uvloop, uvicorn, python-dotenv, protobuf, lz4, httptools, watchfiles, tensorboardX, starlette, opentelemetry-proto, opentelemetry-exporter-otlp-proto-common, fastapi, textual, ray, opencensus, aiohttp-cors, opentelemetry-exporter-otlp-proto-http, opentelemetry-exporter-otlp-proto-grpc, memray, opentelemetry-exporter-otlp
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.5
#     Uninstalling protobuf-4.25.5:
#       Successfully uninstalled protobuf-4.25.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.17.1 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 5.28.3 which is incompatible.
# tensorflow-metadata 1.13.1 requires protobuf<5,>=3.20.3, but you have protobuf 5.28.3 which is incompatible.
# Successfully installed aiohttp-cors-0.7.0 colorful-0.5.6 distlib-0.3.9 fastapi-0.115.5 httptools-0.6.4 lz4-4.3.3 memray-1.14.0 opencensus-0.11.4 opencensus-context-0.1.3 opentelemetry-exporter-otlp-1.28.2 opentelemetry-exporter-otlp-proto-common-1.28.2 opentelemetry-exporter-otlp-proto-grpc-1.28.2 opentelemetry-exporter-otlp-proto-http-1.28.2 opentelemetry-proto-1.28.2 protobuf-5.28.3 py-spy-0.4.0 python-dotenv-1.0.1 ray-2.39.0 starlette-0.41.3 tensorboardX-2.6.2.2 textual-0.87.1 uvicorn-0.32.1 uvloop-0.21.0 virtualenv-20.27.1 watchfiles-1.0.0 websockets-14.1

# %% [markdown]
# Setup Env

# %%
class PortfolioOptimizationEnv(gymnasium.Env):
    '''
    Environment setting with OpenAI

    Assumptions:
    1. In this case, the team has loose the constrain of 24 hours holding period. Once a person buy in the stock, the person can sell it immediately
    2. We have simplified the buy order mechanism so that stocks can be bought at the closing price of the day in this environment.

    State: A stack of stock price data, stock index data, current stock volums, current cash amount
    Observation: Same with state but in a 365 trading days duration
    Action: A float list with a length of N (number of stocks chosen) which elements are within range (-1,1). When positive -> buy Ni * cash amount of stock i. When negtive -> sell Ni present of stocki's volume

    '''

    def __init__(self,env_config):
        super(PortfolioOptimizationEnv, self).__init__()
        try:
            self.history_length = env_config['history_length']
            self.start = env_config['start']                        #define start date
            self.end = env_config['end']                            #define end date
            self.market = env_config['market']                      #define market -> currently only China
            self.n_stock = env_config['n_stock']                    #define the number of stock chosen
            self.cash = env_config['cash']                          #define the initial cash we take into the market
            self.smoothing_factor = env_config['smoothing_factor']  #define smooth for the DSR reward function

            self.market_data = self.load_market_data(self.start, self.end, self.market)         #Initialize market data during the start to end -> execute once to shorten running time
            self.close_data = self.load_full_close_data(self.start, self.end, self.market)      #Initialize close data

            self.stock_tensor_length = self.market_data.shape[1] - 1                                    #See observation_space
            self.date_list = self.load_trading_days(self.start, self.end, self.market)                  #Filter trading days from the period
            self.action_space = spaces.Box(low=-1, high=1, shape=(self.n_stock,), dtype=np.float32)     #define action space, please see 'Action' in the class comment for detail
            self.observation_space = spaces.Box(                                                        #define observation space as required by Rllib, the observation space have to be a flattened np list
                low=-np.inf, high=np.inf,                                                               #Thus the dimension is calcualted as shape
                shape=(self.history_length * (self.stock_tensor_length + self.n_stock + 1 + self.n_stock + 1),),
                dtype=np.float32
            )

            self.state_buffer = deque(maxlen=self.history_length)           #define state deque
            self.initial_cash = np.float32(self.cash)                       #define cash buffer
            self.stock_volume = np.zeros(self.n_stock, dtype=np.float32)    #define stock volume recorder

            self.A_t = np.float32(0.0)
            self.B_t = np.float32(0.0)
            self.Previous_A_t = np.float32(0.0)
            self.Previous_B_t = np.float32(0.0)                             #define reward parameters
            self.net_price = np.array([], dtype=np.float32)                 #define net price loader
            self.current_step = 0                                           #define step recorder

        except Exception as e:
            print("Error during initialization:", e)
            raise


    def step(self, action):
        '''
        Step function, step forward according to policy model's return
        '''

        self.current_step += 1
        next_date = self.date_list[self.current_step]
        action = self.normalize_action(action)
        reward = self.calculate_reward(action, next_date)

        next_state = self.get_state(self.current_step, action,  reward, next_date)
        stacked_state = np.array(self.state_buffer).flatten().astype(np.float32)
        stacked_state = np.nan_to_num(stacked_state, nan=1e-8, posinf=999999, neginf=-999999)

        done = self.net_price[-1] <= 0
        turncated = self.current_step >= len(self.date_list) - 1
        info = {
                "net_price": self.net_price[-1],  # Pass the current net price
                "cash": self.cash,  # Example: Pass cash if needed
            }

        '''log monitoring -> comment back when needed
        if self.current_step % 100 == 0:
          print('-------------------------------------------------')
          print(f'The net price is: {self.net_price[-1]}')
          print(f'The current step is: {self.current_step}')
          print(f'The cash is :{self.cash}')
          print(f'The stock volume is :{self.stock_volume}')
          print(f'The actions are: {action}')
        '''


        return stacked_state, reward, done, turncated, info




    def reset(self, seed = None, options = None):
        '''
        Reset function, reset the environment when an episode is done
        '''
        if seed is not None:
          np.random.seed(seed)
          torch.manual_seed(seed)
        self.state_buffer = deque(maxlen=self.history_length)
        self.cash = self.initial_cash
        self.stock_volume = np.zeros_like(self.stock_volume)
        self.A_t = np.float32(0.0)
        self.B_t = np.float32(0.0)
        self.Previous_A_t = np.float32(0.0)
        self.Previous_B_t = np.float32(0.0)
        self.net_price = np.zeros(self.history_length, dtype=np.float32)
        self.current_step = self.history_length

        self.date_list = self.load_trading_days(self.start, self.end, self.market)
        first_365_days = self.date_list[:self.history_length]

        for idx, date in enumerate(first_365_days):
            dummy_action = np.zeros(self.action_space.shape, dtype=np.float32)
            dummy_reward = 0.0
            next_state = self.get_state(idx, dummy_action, dummy_reward, date)

        stacked_state = np.array(self.state_buffer).flatten()
        stacked_state = stacked_state.astype(np.float32)
        stacked_state = np.nan_to_num(stacked_state, nan=1e-8, posinf=999999, neginf=-999999)
        return stacked_state, {}




    def get_state(self, idx, action, reward, date):
        '''
        Obtain state and return to step function
        '''
        stock_data_current = self.market_data[self.market_data['trade_date'] == date].iloc[0].drop(['trade_date']).values
        reward_array = np.array([reward], dtype=np.float32)
        net_price_current = np.array([self.net_price[self.current_step-1]], dtype=np.float32)
        full_state = np.concatenate([stock_data_current, action, reward_array, self.stock_volume, net_price_current])
        date_encodings = self.calculate_date_encoding(idx, full_state.shape[0])
        full_state_with_encoding = full_state + date_encodings
        self.state_buffer.append(full_state_with_encoding)
        return full_state_with_encoding



    def load_trading_days(self, start, end, market):
        '''
        Filter trading days
        '''
        if market == 'CHINA':
            ts.set_token('28b2dbb3562598167a7ae7929457748793ba2c1fb2f47d4542ac6b8b')
            pro = ts.pro_api()
            trade_cal = pro.trade_cal(exchange = '',start_date = start, end_date = end)
            trade_cal = trade_cal[trade_cal['is_open'] == 1]
            trading_dates = trade_cal['cal_date'].tolist()
            return trading_dates
        elif market == 'US':
            raise ValueError('Not support yet')
        else:
            raise ValueError('Invalid market type')




    def load_full_close_data(self, start, end, market='CHINA'):
        '''
        Load close price , the close price is loaded separately for calculating cumulative return and net price
        The close price in the "load_market_data" function has been normalized; thus need to load separately
        '''
        if market == 'CHINA':
            ts.set_token('28b2dbb3562598167a7ae7929457748793ba2c1fb2f47d4542ac6b8b')
            pro = ts.pro_api()
            stock_codes = ['601318.SH', '601398.SH', '600519.SH', '000001.SZ', '601857.SH']
            df_close = pd.DataFrame()

            for code in stock_codes:
                df = pro.daily(ts_code=code, start_date=start, end_date=end)
                df = df[['trade_date', 'close']]
                df_renamed = df.rename(columns={'close': f"close_{code.split('.')[0]}"})

                if df_close.empty:
                    df_close = df_renamed
                else:
                    df_close = pd.merge(df_close, df_renamed, on='trade_date', how='outer')

            df_close.sort_values('trade_date', inplace=True)
            return df_close

        elif market == 'US':
            raise ValueError('Not support yet')
        else:
            raise ValueError('Invalid market type')



    def load_close_data(self, date):
            '''
            Load close price for a specific day
            '''
            data_on_date = self.close_data[self.close_data['trade_date'] == date]
            close_columns = [col for col in data_on_date.columns if 'close_' in col]
            close_array = data_on_date[close_columns].values.flatten().astype(np.float32)
            return close_array



    def load_market_data(self, start, end, market='CHINA'):
        '''
        Load the market data and normalize it
        '''
        if market == 'CHINA':
            ts.set_token('28b2dbb3562598167a7ae7929457748793ba2c1fb2f47d4542ac6b8b')
            pro = ts.pro_api()

            stock_codes = ['601318.SH', '601398.SH', '600519.SH', '000001.SZ', '601857.SH']
            Full_CHINA_STOCK_df = pd.DataFrame()

            for code in stock_codes:
                df = pro.daily(ts_code=code, start_date=start, end_date=end)
                adj_factors = pro.adj_factor(ts_code=code, start_date=start, end_date=end)
                daily_basic = pro.daily_basic(ts_code=code, start_date=start, end_date=end)
                daily_basic = daily_basic.drop(columns=['close'])

                df = pd.merge(df, adj_factors[['trade_date', 'adj_factor']], on='trade_date', how='left')
                df['close_adj'] = df['close'] / df['adj_factor']
                df['open_adj'] = df['open'] / df['adj_factor']
                df['high_adj'] = df['high'] / df['adj_factor']
                df['low_adj'] = df['low'] / df['adj_factor']
                df['close_price'] = df['close']
                df = pd.merge(df, daily_basic, on='trade_date', how='left')
                df = df.drop(columns=['adj_factor', 'ts_code_x','ts_code_y','close'])
                df_renamed = df.rename(columns=lambda x: f"{x}_{code.split('.')[0]}" if x != 'trade_date' else x)

                if Full_CHINA_STOCK_df.empty:
                    Full_CHINA_STOCK_df = df_renamed
                else:
                    Full_CHINA_STOCK_df = pd.merge(Full_CHINA_STOCK_df, df_renamed, on='trade_date', how='outer')

            Full_CHINA_STOCK_df.sort_values('trade_date', inplace=True)
            columns_to_normalize = [col for col in Full_CHINA_STOCK_df.columns if col != 'trade_date']
            scaler = MinMaxScaler()
            Full_CHINA_STOCK_df[columns_to_normalize] = scaler.fit_transform(Full_CHINA_STOCK_df[columns_to_normalize])

            return Full_CHINA_STOCK_df

        elif market == 'US':
            raise ValueError('Not support yet')
        else:
            raise ValueError('Invalid market type')



    def calculate_date_encoding(self, idx, embedding_dimension):
        '''
        Add date encoding to the data according to the paper "Attention is all you need" by Vaswani et al.
        But somehow it also works on our value function which is a LSTM setting in this case. Need further investigate

        Also. there are two possible method to implement this embedding, one put it here follow the instruction in 'attention is all you need',
        two you can put it within the model to make it trainable parameters, we will investigate on this
        '''
        encoding = []
        for i in range(embedding_dimension):
            if i % 2 == 0:
                value = np.sin(idx / (10000 ** (i / embedding_dimension)))
            else:
                value = np.cos(idx / (10000 ** (i / embedding_dimension)))
            encoding.append(value)
        return np.array(encoding, dtype=np.float32)




    def calculate_reward(self, action, date):
        '''
        Implement Differencial Sharpe Ratio (DSR) as the reward function to take in consideration of the risk
        '''

        portfolio_return = self.get_portfolio_return(action, date)
        self.Previous_A_t = self.A_t.copy()
        self.Previous_B_t = self.B_t.copy()
        self.A_t = (1 - self.smoothing_factor) * self.A_t + self.smoothing_factor * portfolio_return
        self.B_t = (1 - self.smoothing_factor) * self.B_t + self.smoothing_factor * (portfolio_return ** 2)

        delta_A_t = self.A_t - self.Previous_A_t
        delta_B_t = self.B_t - self.Previous_B_t

        if self.Previous_B_t - (self.Previous_A_t ** 2) > 0:
            denom = (self.Previous_B_t - (self.Previous_A_t ** 2)) ** 1.5
            numer = self.Previous_B_t * delta_A_t - 0.5 * self.Previous_A_t * delta_B_t
            DSR = numer / denom
        else:
            DSR = 0
        return DSR



    def calculate_net_price(self, action, date):
        '''
        Calcualte the net price for a day
        '''
        close_values = self.load_close_data(date)
        for idx, act in enumerate(action):
            if act > 0:
                self.stock_volume[idx] += (self.cash * act) / close_values[idx]
                self.cash -= self.cash * act
            elif act < 0:
                self.cash += (-act) * self.stock_volume[idx] * close_values[idx]
                self.stock_volume[idx] += self.stock_volume[idx] * act
        net_price_value = self.cash + np.sum(self.stock_volume * close_values)
        self.net_price = np.append(self.net_price, net_price_value)
        return net_price_value



    def get_portfolio_return(self, action, date):
        '''
        Calcualte the return for a day
        '''
        current_price = self.calculate_net_price(action, date)
        last_day = self.current_step - 2
        previous_price = self.net_price[last_day]
        return np.float32(current_price - previous_price)



    def normalize_action(self, action):
        '''
        Since the positive action sampled from the policy model does not always sum up to 1 which represent over 100% of the cash, thus we needs to normalize it
        '''
        positive_mask = (action >= 0).astype(np.float32)
        positive_action = action * positive_mask
        positive_sum = np.sum(positive_action)
        if positive_sum > 1:
            positive_action = positive_action / positive_sum
        action = action * (1 - positive_mask) + positive_action

        for i, a in enumerate(action):
            if a < 0:
              if self.stock_volume[i] > 0:
                continue
              else:
                action[i] = 0
        return action

# %% [markdown]
# Build Transformer Actor and Critic

# %%
#Code Reference: University of Toronto ECE1786 Assignment3 Author: Jonathan Rose
class NewGELU(nn.Module):
    """
    Implementation of the GELU activation function currently in Google BERT repo (identical to OpenAI GPT).
    Reference: Gaussian Error Linear Units (GELU) paper: https://arxiv.org/abs/1606.08415
    """
    def forward(self, x):
        return 0.5 * x * (1.0 + torch.tanh(math.sqrt(2.0 / math.pi) * (x + 0.044715 * torch.pow(x, 3.0))))

class CausalSelfAttention(nn.Module):
    """
    A vanilla multi-head masked self-attention layer with a projection at the end.
    It is possible to use torch.nn.MultiheadAttention here but I am including an
    explicit implementation here to show that there is nothing too scary here.
    """


    def __init__(self, model_config):
        super().__init__()
        assert model_config['n_embd'] % model_config['n_head'] == 0
        # key, query, value projections for all heads, but in a batch
        self.c_attn = nn.Linear(model_config['n_embd'], 3 * model_config['n_embd'])
        # output projection
        self.c_proj = nn.Linear(model_config['n_embd'], model_config['n_embd'])
        # regularization
        self.attn_dropout = nn.Dropout(model_config['attn_pdrop'])
        self.resid_dropout = nn.Dropout(model_config['resid_pdrop'])
        # causal mask to ensure that attention is only applied to the left in the input sequence
        self.register_buffer("bias", torch.tril(torch.ones(model_config['block_size'], model_config['block_size']))
                                     .view(1, 1, model_config['block_size'], model_config['block_size']))
        self.n_head = model_config['n_head']
        self.n_embd = model_config['n_embd']



    def forward(self, x):
        B, T, C = x.size() # batch size, sequence length, embedding dimensionality (n_embd)

        # calculate query, key, values for all heads in batch and move head forward to be the batch dim
        q, k ,v  = self.c_attn(x).split(self.n_embd, dim=2)
        k = k.view(B, T, self.n_head, C // self.n_head).transpose(1, 2) # (B, nh, T, hs)
        q = q.view(B, T, self.n_head, C // self.n_head).transpose(1, 2) # (B, nh, T, hs)
        v = v.view(B, T, self.n_head, C // self.n_head).transpose(1, 2) # (B, nh, T, hs)

        # causal self-attention; Self-attend: (B, nh, T, hs) x (B, nh, hs, T) -> (B, nh, T, T)
        att = (q @ k.transpose(-2, -1)) * (1.0 / math.sqrt(k.size(-1)))
        att = att.masked_fill(self.bias[:,:,:T,:T] == 0, float('-inf'))
        att = F.softmax(att, dim=-1)
        att = self.attn_dropout(att)
        y = att @ v # (B, nh, T, T) x (B, nh, T, hs) -> (B, nh, T, hs)
        y = y.transpose(1, 2).contiguous().view(B, T, C) # re-assemble all head outputs side by side

        # output projection
        y = self.resid_dropout(self.c_proj(y))
        return y



class Block(nn.Module):
    """ an unassuming Transformer block """
    def __init__(self, model_config):
        super().__init__()
        self.ln_1 = nn.LayerNorm(model_config['n_embd'])
        self.attn = CausalSelfAttention(model_config)
        self.ln_2 = nn.LayerNorm(model_config['n_embd'])
        self.mlp = nn.ModuleDict(dict(
            c_fc    = nn.Linear(model_config['n_embd'], 4 * model_config['n_embd']),
            c_proj  = nn.Linear(4 * model_config['n_embd'], model_config['n_embd']),
            act     = NewGELU(),
            dropout = nn.Dropout(model_config['resid_pdrop']),
        ))
        m = self.mlp
        self.mlpf = lambda x: m.dropout(m.c_proj(m.act(m.c_fc(x)))) # MLP forward



    def forward(self, x):
        x = x + self.attn(self.ln_1(x))
        x = x + self.mlpf(self.ln_2(x))
        return x



# This actor model is responsible for choosing the actions for cash allocation
class CustomActorCriticModel(TorchModelV2, nn.Module):
    def __init__(self, obs_space, action_space, num_outputs, model_config, name):
        TorchModelV2.__init__(self, obs_space, action_space, num_outputs, model_config, name)
        nn.Module.__init__(self)
        custom_model_config = model_config['custom_model_config']
        self.n_embd = custom_model_config['n_embd']
        self.n_layer = custom_model_config['n_layer']
        self.n_head = custom_model_config['n_head']
        self.block_size = custom_model_config['block_size']
        self.embd_pdrop = custom_model_config['embd_pdrop']
        self.resid_pdrop = custom_model_config['resid_pdrop']
        self.attn_pdrop = custom_model_config['attn_pdrop']

        self.transformer = nn.ModuleDict({
            'drop': nn.Dropout(self.embd_pdrop),
            'h': nn.ModuleList([Block(custom_model_config) for _ in range(self.n_layer)]),
            'ln_f': nn.LayerNorm(self.n_embd),
        })

        self.policy_head = nn.Linear(self.n_embd, num_outputs)
        self.value_head = nn.Linear(self.n_embd, 1)
        self.apply(self._init_weights)

        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        self.to(self.device)



    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)
            if module.bias is not None:
                torch.nn.init.zeros_(module.bias)
        elif isinstance(module, nn.Embedding):
            torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)
        elif isinstance(module, nn.LayerNorm):
            torch.nn.init.zeros_(module.bias)
            torch.nn.init.ones_(module.weight)



    def forward(self, input_dict, state, seq_lens):

        if isinstance(input_dict['obs'], np.ndarray):
            obs = torch.tensor(input_dict['obs'], dtype=torch.float32).to(self.device)
        else:
            obs = input_dict['obs'].to(self.device)

        batch_size = obs.size(0)
        orig = obs.size(1)
        obs = obs.view(batch_size, orig//self.n_embd, self.n_embd )
        x = self.transformer.drop(obs)
        for block in self.transformer.h:
            x = block(x)
        x = self.transformer.ln_f(x)
        last_hidden_state = x[:, -1, :]

        policy = self.policy_head(last_hidden_state)
        value = self.value_head(last_hidden_state)      #no need in this LSTM value function case
        self._value_out = self.value_head(last_hidden_state).squeeze(-1)
        return policy, state

    def value_function(self):       #no need in this LSTM value function case
        return self._value_out

ModelCatalog.register_custom_model('custom_actor_critic_model',CustomActorCriticModel)

# %%
class CustomValueModel(TorchModelV2, nn.Module):
    def __init__(self, obs_space, action_space, num_outputs, model_config, name):
        TorchModelV2.__init__(self, obs_space, action_space, num_outputs, model_config, name)
        nn.Module.__init__(self)
        custom_model_config = model_config['custom_model_config']
        self.n_embd = custom_model_config['n_embd']
        self.n_layer = custom_model_config['n_layer']
        self.n_head = custom_model_config['n_head']
        self.block_size = custom_model_config['block_size']
        self.embd_pdrop = custom_model_config['embd_pdrop']
        self.resid_pdrop = custom_model_config['resid_pdrop']
        self.attn_pdrop = custom_model_config['attn_pdrop']

        self.transformer = nn.ModuleDict({
            'drop': nn.Dropout(self.embd_pdrop),
            'h': nn.ModuleList([Block(custom_model_config) for _ in range(self.n_layer)]),
            'ln_f': nn.LayerNorm(self.n_embd),
        })

        self.policy_head = nn.Linear(self.n_embd, num_outputs)
        self.value_head = nn.Linear(self.n_embd, 1)
        self.apply(self._init_weights)

        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        self.to(self.device)



    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)
            if module.bias is not None:
                torch.nn.init.zeros_(module.bias)
        elif isinstance(module, nn.Embedding):
            torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)
        elif isinstance(module, nn.LayerNorm):
            torch.nn.init.zeros_(module.bias)
            torch.nn.init.ones_(module.weight)



    def forward(self, input_dict, state, seq_lens):

        if isinstance(input_dict['obs'], np.ndarray):
            obs = torch.tensor(input_dict['obs'], dtype=torch.float32).to(self.device)
        else:
            obs = input_dict['obs'].to(self.device)

        batch_size = obs.size(0)
        orig = obs.size(1)
        obs = obs.view(batch_size, orig//self.n_embd, self.n_embd )
        x = self.transformer.drop(obs)
        for block in self.transformer.h:
            x = block(x)
        x = self.transformer.ln_f(x)
        last_hidden_state = x[:, -1, :]

        value = self.value_head(last_hidden_state)
        self._value_out = self.value_head(last_hidden_state).squeeze(-1)
        return None, state

    def value_function(self):
        return self._value_out


ModelCatalog.register_custom_model('custom_value_model', CustomValueModel)

# %%
class CustomMetricsCallback(DefaultCallbacks):
    '''
    Custom call back class to monitor the net price
    '''
    def on_episode_end(self, *, worker, base_env, policies, episode, **kwargs):
        #print(f"The episode is {episode}")
        env = base_env.get_sub_environments()[0]
        final_net_price = env.net_price[-1] if len(env.net_price) > 0 else None
        if final_net_price is not None:
            episode.custom_metrics["final_net_price"] = final_net_price

# %%
config = {
    'env': 'my_portfolio_env',
    'num_workers': 0,
    'num_gpus': 1,
    'framework': 'torch',
    'env_config': {
        'n_stock': 5,
        'cash': 10000,
        'history_length': 365,
        'market': 'CHINA',
        'start': '20210101',
        'end': '20230631',
        'smoothing_factor': 0.5
    },
    'val_env_config': {
        'n_stock': 5,
        'cash': 10000,
        'history_length': 100,
        'market': 'CHINA',
        'start': '20230701',
        'end': '20231231',
        'smoothing_factor': 0.5
    },
    'model': {
        'custom_model': 'custom_actor_critic_model',
        'custom_action_dist': None,
        'vf_share_layers': True,
        'custom_model_config': {
            'n_embd': 152,
            'n_layer': 2,
            'n_head': 2,
            'block_size': 512,
            'embd_pdrop': 0.1,
            'resid_pdrop': 0.1,
            'attn_pdrop': 0.1
        }
    },

    'lr': 5e-5, #change 4
    'train_batch_size': 512,
    'sgd_minibatch_size': 16,
    'num_epochs': 100,
    'callbacks': CustomMetricsCallback,
}

# %%
ray.init(ignore_reinit_error=True)

def env_creator(env_config):
    return PortfolioOptimizationEnv(env_config)

register_env('my_portfolio_env', env_creator)

learning_rate_list = [5e-3, 1e-3, 5e-4, 1e-4]
#learning_rate_list = [5e-3, 1e-3]

eval_rewards = {}
eval_net_prices = {}

def evaluate(trainer, env, num_episodes=10):
    all_rewards = []
    net_prices = []

    for episode in range(num_episodes):
        episode_reward = 0
        done = False
        truncated = False
        obs = env.reset()

        while not done and not truncated:
            if isinstance(obs, tuple):
                obs_input = obs[0]
            elif isinstance(obs, dict):
                obs_input = obs["obs"]
            else:
                obs_input = obs

            action = trainer.compute_single_action(obs_input, explore=False)
            obs, reward, done, truncated, info = env.step(action)
            episode_reward += reward

        all_rewards.append(episode_reward)
        net_price = env.net_price[-1]
        net_prices.append(net_price)

    return all_rewards, net_prices

for lr in learning_rate_list:
    config['lr'] = lr

    algo = (
        PPOConfig()
        .environment('my_portfolio_env', env_config=config['env_config'])
        .framework('torch')
        .resources(num_gpus=1)
        .env_runners(num_env_runners=config['num_workers'])
        .training(
            model=config['model'],
            lr=config['lr'],
            train_batch_size=config['train_batch_size'],
            num_epochs=config['num_epochs']
        )
        .api_stack(
            enable_rl_module_and_learner=False,
            enable_env_runner_and_connector_v2=False
        )
        .rollouts(sample_timeout_s=300)
        .callbacks(CustomMetricsCallback)
        .build()
    )

    num_epochs = 50
    epoch_net_values = []
    epoch_policy_loss = []
    epoch_value_loss = []

    for i in range(num_epochs):
        print(f"Training iteration {i}, Hyperparameter tuned = {lr}")
        result = algo.train()
        if i != 0:
            policy_loss = result["info"]["learner"]["default_policy"]["learner_stats"]["policy_loss"]
            value_loss = result["info"]["learner"]["default_policy"]["learner_stats"]["vf_loss"]
            net_value = result["env_runners"]["custom_metrics"]["final_net_price_mean"]
            epoch_policy_loss.append(policy_loss)
            epoch_value_loss.append(value_loss)
            epoch_net_values.append(net_value)
            print(f"Epoch {i}: Policy Loss={policy_loss}, Value Loss={value_loss}")
            torch.cuda.empty_cache()

    epochs = range(1, len(epoch_policy_loss) + 1)
    epochs = np.array(epochs)
    epoch_net_values = np.array(epoch_net_values)

    coefficients = np.polyfit(epochs, epoch_net_values, deg=1)
    trendline = np.polyval(coefficients, epochs)

    plt.figure(figsize=(10, 6))
    plt.plot(epochs, epoch_net_values, marker='o', label='Net Value')
    plt.plot(epochs, trendline, color='red', linestyle='--', label='Trendline')

    plt.title(f'Net Value with Trendline')
    plt.xlabel('Epoch')
    plt.ylabel('Metric Value')
    plt.legend()
    plt.grid()
    plt.show()



    plt.figure(figsize=(10, 6))
    plt.plot(epochs, epoch_policy_loss, marker='o', label='Policy Loss')
    plt.title(f'Policy Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Metric Value')
    plt.legend()
    plt.grid()
    plt.show()

    plt.figure(figsize=(10, 6))
    plt.plot(epochs, epoch_value_loss, marker='o', label='Value Loss')
    plt.title(f'Value Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Metric Value')
    plt.legend()
    plt.grid()
    plt.show()


    evaluation_env = PortfolioOptimizationEnv(config['val_env_config'])
    all_rewards, net_prices = evaluate(algo, evaluation_env, num_episodes=10)
    evaluation_env.close()

    eval_rewards[lr] = all_rewards
    eval_net_prices[lr] = net_prices

plt.figure(figsize=(12, 6))
for lr, rewards in eval_rewards.items():
    episodes = range(1, len(rewards) + 1)
    plt.plot(episodes, rewards, marker='o', linestyle='-', label=f'LR={lr}')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.title('Episode Rewards for Different Learning Rates')
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(12, 6))
for lr, net_prices in eval_net_prices.items():
    episodes = range(1, len(net_prices) + 1)
    plt.plot(episodes, net_prices, marker='x', linestyle='--', label=f'LR={lr}')
plt.xlabel('Episode')
plt.ylabel('Net Price')
plt.title('Episode Net Prices for Different Learning Rates')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 2024-11-25 04:16:33,935	INFO worker.py:1810 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# 2024-11-25 04:16:37,069	WARNING deprecation.py:50 -- DeprecationWarning: `rollouts` has been deprecated. Use `AlgorithmConfig.env_runners(..)` instead. This will raise an error in the future!
# 2024-11-25 04:16:56,856	WARNING catalog.py:547 -- Custom ModelV2 should accept all custom options as **kwargs, instead of expecting them in config['custom_model_config']!
# 2024-11-25 04:17:03,574	INFO trainable.py:161 -- Trainable.setup took 26.434 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2024-11-25 04:17:03,580	WARNING util.py:61 -- Install gputil for GPU system monitoring.
# Training iteration 0, Hyperparameter tuned = 0.005
# 2024-11-25 04:17:20,119	WARNING deprecation.py:50 -- DeprecationWarning: `ray.rllib.execution.train_ops.multi_gpu_train_one_step` has been deprecated. This will raise an error in the future!
# Training iteration 1, Hyperparameter tuned = 0.005
# Epoch 1: Policy Loss=-0.02321606008335948, Value Loss=8.098450344800948
# Training iteration 2, Hyperparameter tuned = 0.005
# Epoch 2: Policy Loss=-0.026265825694426894, Value Loss=8.48333645939827
# Training iteration 3, Hyperparameter tuned = 0.005
# Epoch 3: Policy Loss=-0.01702880945056677, Value Loss=8.011489614248276
# Training iteration 4, Hyperparameter tuned = 0.005
# Epoch 4: Policy Loss=-0.0021920257434248926, Value Loss=9.071338343620301
# Training iteration 5, Hyperparameter tuned = 0.005
# Epoch 5: Policy Loss=-0.007318933447822929, Value Loss=7.724369220733642
# Training iteration 6, Hyperparameter tuned = 0.005
# Epoch 6: Policy Loss=-0.010285431817173958, Value Loss=8.932841126918794
# Training iteration 7, Hyperparameter tuned = 0.005
# Epoch 7: Policy Loss=-0.0030999118834733963, Value Loss=9.186686798334122
# Training iteration 8, Hyperparameter tuned = 0.005
# Epoch 8: Policy Loss=-0.0024185875803232194, Value Loss=8.585103479623795
# Training iteration 9, Hyperparameter tuned = 0.005
# Epoch 9: Policy Loss=-0.005408850312232971, Value Loss=8.686685197353363
# Training iteration 10, Hyperparameter tuned = 0.005
# Epoch 10: Policy Loss=-0.008903889954090118, Value Loss=8.559327598810196
# Training iteration 11, Hyperparameter tuned = 0.005
# Epoch 11: Policy Loss=-0.007952557727694511, Value Loss=8.07271438717842
# Training iteration 12, Hyperparameter tuned = 0.005
# Epoch 12: Policy Loss=-0.004095140285789967, Value Loss=8.681385256052017
# Training iteration 13, Hyperparameter tuned = 0.005
# Epoch 13: Policy Loss=-0.0036328372359275816, Value Loss=8.462743524312973
# Training iteration 14, Hyperparameter tuned = 0.005
# Epoch 14: Policy Loss=-0.0031574022024869917, Value Loss=8.71910617351532
# Training iteration 15, Hyperparameter tuned = 0.005
# Epoch 15: Policy Loss=-0.018845182359218598, Value Loss=8.917588022947312
# Training iteration 16, Hyperparameter tuned = 0.005
# Epoch 16: Policy Loss=-0.02272537548560649, Value Loss=8.983305685520172
# Training iteration 17, Hyperparameter tuned = 0.005
# Epoch 17: Policy Loss=-0.012703923992812633, Value Loss=8.335725966691971
# Training iteration 18, Hyperparameter tuned = 0.005
# Epoch 18: Policy Loss=0.0011159509420394897, Value Loss=8.80541042804718
# Training iteration 19, Hyperparameter tuned = 0.005
# Epoch 19: Policy Loss=-0.002853273153305054, Value Loss=8.582612862586975
# Training iteration 20, Hyperparameter tuned = 0.005
# Epoch 20: Policy Loss=-0.017049452178180217, Value Loss=9.011579142808914
# Training iteration 21, Hyperparameter tuned = 0.005
# Epoch 21: Policy Loss=-0.008348214030265809, Value Loss=9.367061145305634
# Training iteration 22, Hyperparameter tuned = 0.005
# Epoch 22: Policy Loss=-0.014061123803257943, Value Loss=8.433175363540649
# Training iteration 23, Hyperparameter tuned = 0.005
# Epoch 23: Policy Loss=-0.020987524800002575, Value Loss=8.06363252043724
# Training iteration 24, Hyperparameter tuned = 0.005
# Epoch 24: Policy Loss=-0.020619728192687033, Value Loss=9.214829227924348
# Training iteration 25, Hyperparameter tuned = 0.005
# Epoch 25: Policy Loss=-0.015925312936306, Value Loss=9.082056818008423
# Training iteration 26, Hyperparameter tuned = 0.005
# Epoch 26: Policy Loss=-0.004160378761589527, Value Loss=8.893639664649964
# Training iteration 27, Hyperparameter tuned = 0.005
# Epoch 27: Policy Loss=-0.00847404457628727, Value Loss=8.394011855125427
# Training iteration 28, Hyperparameter tuned = 0.005
# Epoch 28: Policy Loss=-0.014195167571306228, Value Loss=8.402496277093887
# Training iteration 29, Hyperparameter tuned = 0.005
# Epoch 29: Policy Loss=-0.007763677937909961, Value Loss=8.859555449485779
# Training iteration 30, Hyperparameter tuned = 0.005
# Epoch 30: Policy Loss=-0.014672658368945123, Value Loss=8.849495997428894
# Training iteration 31, Hyperparameter tuned = 0.005
# Epoch 31: Policy Loss=-0.011662427000701428, Value Loss=8.550899640321731
# Training iteration 32, Hyperparameter tuned = 0.005
# Epoch 32: Policy Loss=-0.0065040014404803516, Value Loss=8.35871377468109
# Training iteration 33, Hyperparameter tuned = 0.005
# Epoch 33: Policy Loss=-0.004272040314972401, Value Loss=8.12813270330429
# Training iteration 34, Hyperparameter tuned = 0.005
# Epoch 34: Policy Loss=-0.006244765967130661, Value Loss=8.81741449713707
# Training iteration 35, Hyperparameter tuned = 0.005
# Epoch 35: Policy Loss=-0.0013729038462042809, Value Loss=8.473454031944275
# Training iteration 36, Hyperparameter tuned = 0.005
# Epoch 36: Policy Loss=-0.005779359638690949, Value Loss=8.62094036579132
# Training iteration 37, Hyperparameter tuned = 0.005
# Epoch 37: Policy Loss=-0.009823164343833924, Value Loss=8.175114833116531
# Training iteration 38, Hyperparameter tuned = 0.005
# Epoch 38: Policy Loss=-0.0037867648899555205, Value Loss=8.44950068950653
# Training iteration 39, Hyperparameter tuned = 0.005
# Epoch 39: Policy Loss=-0.009695181287825108, Value Loss=9.054223486185073
# Training iteration 40, Hyperparameter tuned = 0.005
# Epoch 40: Policy Loss=-0.005264234319329261, Value Loss=7.864102213382721
# Training iteration 41, Hyperparameter tuned = 0.005
# Epoch 41: Policy Loss=-0.0067506559193134304, Value Loss=8.679582003355026
# Training iteration 42, Hyperparameter tuned = 0.005
# Epoch 42: Policy Loss=-0.009303417820483446, Value Loss=7.923486465215683
# Training iteration 43, Hyperparameter tuned = 0.005
# Epoch 43: Policy Loss=-0.007289366957265884, Value Loss=8.093904262781143
# Training iteration 44, Hyperparameter tuned = 0.005
# Epoch 44: Policy Loss=-0.016577148418873547, Value Loss=8.894323480129241
# Training iteration 45, Hyperparameter tuned = 0.005
# Epoch 45: Policy Loss=-0.02210282975807786, Value Loss=8.215223225355148
# Training iteration 46, Hyperparameter tuned = 0.005
# Epoch 46: Policy Loss=-0.011054706368595362, Value Loss=8.338946610689163
# Training iteration 47, Hyperparameter tuned = 0.005
# Epoch 47: Policy Loss=-0.01355826634913683, Value Loss=7.930177570581436
# Training iteration 48, Hyperparameter tuned = 0.005
# Epoch 48: Policy Loss=-0.014742125198245049, Value Loss=8.480095199346543
# Training iteration 49, Hyperparameter tuned = 0.005
# Epoch 49: Policy Loss=0.00037682607769966124, Value Loss=8.10845254421234
# 2024-11-25 05:21:25,248	WARNING catalog.py:547 -- Custom ModelV2 should accept all custom options as **kwargs, instead of expecting them in config['custom_model_config']!
# 2024-11-25 05:21:25,315	INFO trainable.py:161 -- Trainable.setup took 23.538 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2024-11-25 05:21:25,317	WARNING util.py:61 -- Install gputil for GPU system monitoring.
# Training iteration 0, Hyperparameter tuned = 0.001
# Training iteration 1, Hyperparameter tuned = 0.001
# Epoch 1: Policy Loss=-0.01065717451274395, Value Loss=9.015834922790527
# Training iteration 2, Hyperparameter tuned = 0.001
# Epoch 2: Policy Loss=-0.02412299647927284, Value Loss=9.499232702255249
# Training iteration 3, Hyperparameter tuned = 0.001
# Epoch 3: Policy Loss=-0.0037222665548324583, Value Loss=9.163440248966218
# Training iteration 4, Hyperparameter tuned = 0.001
# Epoch 4: Policy Loss=-0.011254897583276033, Value Loss=8.604902638196945
# Training iteration 5, Hyperparameter tuned = 0.001
# Epoch 5: Policy Loss=-0.003303562365472317, Value Loss=9.07949637413025
# Training iteration 6, Hyperparameter tuned = 0.001
# Epoch 6: Policy Loss=-0.011571393124759197, Value Loss=8.016924723386765
# Training iteration 7, Hyperparameter tuned = 0.001
# Epoch 7: Policy Loss=-0.011477191434241831, Value Loss=8.692069733142853
# Training iteration 8, Hyperparameter tuned = 0.001
# Epoch 8: Policy Loss=-0.01503479632548988, Value Loss=9.32479991197586
# Training iteration 9, Hyperparameter tuned = 0.001
# Epoch 9: Policy Loss=-0.016678331419825554, Value Loss=9.523826966285705
# Training iteration 10, Hyperparameter tuned = 0.001
# Epoch 10: Policy Loss=-0.011059631109237671, Value Loss=9.316301100254059
# Training iteration 11, Hyperparameter tuned = 0.001
# Epoch 11: Policy Loss=-0.009125419445335865, Value Loss=9.004934400320053
# Training iteration 12, Hyperparameter tuned = 0.001
# Epoch 12: Policy Loss=-0.013995001018047333, Value Loss=8.828622120618821
# Training iteration 13, Hyperparameter tuned = 0.001
# Epoch 13: Policy Loss=-0.008471911512315274, Value Loss=8.788175728321075
# Training iteration 14, Hyperparameter tuned = 0.001
# Epoch 14: Policy Loss=-0.006543508917093277, Value Loss=8.348923019170762
# Training iteration 15, Hyperparameter tuned = 0.001
# Epoch 15: Policy Loss=-0.014096700176596642, Value Loss=8.96713751912117
# Training iteration 16, Hyperparameter tuned = 0.001
# Epoch 16: Policy Loss=-0.008052371107041836, Value Loss=9.095024279356004
# Training iteration 17, Hyperparameter tuned = 0.001
# Epoch 17: Policy Loss=-0.007446214659139514, Value Loss=9.164841978549957
# Training iteration 18, Hyperparameter tuned = 0.001
# Epoch 18: Policy Loss=-0.023568487763404845, Value Loss=8.672622669935226
# Training iteration 19, Hyperparameter tuned = 0.001
# Epoch 19: Policy Loss=-0.010023704897612333, Value Loss=8.956653209924697
# Training iteration 20, Hyperparameter tuned = 0.001
# Epoch 20: Policy Loss=-0.015394343286752701, Value Loss=8.865529894828796
# Training iteration 21, Hyperparameter tuned = 0.001
# Epoch 21: Policy Loss=-0.010493790805339813, Value Loss=8.677046868801117
# Training iteration 22, Hyperparameter tuned = 0.001
# Epoch 22: Policy Loss=-0.014306592270731926, Value Loss=8.908951432704926
# Training iteration 23, Hyperparameter tuned = 0.001
# Epoch 23: Policy Loss=-0.01240226924419403, Value Loss=8.557832652330399
# Training iteration 24, Hyperparameter tuned = 0.001
# Epoch 24: Policy Loss=-0.010640979576855898, Value Loss=8.457789109945297
# Training iteration 25, Hyperparameter tuned = 0.001
# Epoch 25: Policy Loss=-0.013125974126160145, Value Loss=7.9531709468364715
# Training iteration 26, Hyperparameter tuned = 0.001
# Epoch 26: Policy Loss=-0.019906462766230107, Value Loss=8.493465200662612
# Training iteration 27, Hyperparameter tuned = 0.001
# Epoch 27: Policy Loss=-0.019135598726570606, Value Loss=9.042082349061966
# Training iteration 28, Hyperparameter tuned = 0.001
# Epoch 28: Policy Loss=-0.01131813868880272, Value Loss=8.782718434333802
# Training iteration 29, Hyperparameter tuned = 0.001
# Epoch 29: Policy Loss=-0.014862650688737631, Value Loss=8.417792658805848
# Training iteration 30, Hyperparameter tuned = 0.001
# Epoch 30: Policy Loss=-0.017593529261648654, Value Loss=8.409211263656616
# Training iteration 31, Hyperparameter tuned = 0.001
# Epoch 31: Policy Loss=-0.01204304702579975, Value Loss=8.52622519135475
# Training iteration 32, Hyperparameter tuned = 0.001
# Epoch 32: Policy Loss=-0.018581561911851167, Value Loss=7.8243291521072384
# Training iteration 33, Hyperparameter tuned = 0.001
# Epoch 33: Policy Loss=-0.005148855987936258, Value Loss=8.64473835349083
# Training iteration 34, Hyperparameter tuned = 0.001
# Epoch 34: Policy Loss=-0.013009699620306492, Value Loss=8.635324208736419
# Training iteration 35, Hyperparameter tuned = 0.001
# Epoch 35: Policy Loss=-0.014030765334609896, Value Loss=8.326441195011139
# Training iteration 36, Hyperparameter tuned = 0.001
# Epoch 36: Policy Loss=-0.0074611114710569386, Value Loss=8.678772548437118
# Training iteration 37, Hyperparameter tuned = 0.001
# Epoch 37: Policy Loss=-0.00721444817725569, Value Loss=8.851304852962494
# Training iteration 38, Hyperparameter tuned = 0.001
# Epoch 38: Policy Loss=-0.008545881360769272, Value Loss=8.953327538967132
# Training iteration 39, Hyperparameter tuned = 0.001
# Epoch 39: Policy Loss=-0.01412998415529728, Value Loss=7.97761244893074
# Training iteration 40, Hyperparameter tuned = 0.001
# Epoch 40: Policy Loss=-0.01587932977825403, Value Loss=8.7165252494812
# Training iteration 41, Hyperparameter tuned = 0.001
# Epoch 41: Policy Loss=-0.012030937820672988, Value Loss=8.606020545959472
# Training iteration 42, Hyperparameter tuned = 0.001
# Epoch 42: Policy Loss=-0.005501197203993797, Value Loss=8.26680274963379
# Training iteration 43, Hyperparameter tuned = 0.001
# Epoch 43: Policy Loss=-0.020160040855407714, Value Loss=8.95187772989273
# Training iteration 44, Hyperparameter tuned = 0.001
# Epoch 44: Policy Loss=-0.013243637550622224, Value Loss=9.176335773468018
# Training iteration 45, Hyperparameter tuned = 0.001
# Epoch 45: Policy Loss=-0.01590595141518861, Value Loss=8.900436741113662
# Training iteration 46, Hyperparameter tuned = 0.001
# Epoch 46: Policy Loss=-0.010481797114480287, Value Loss=8.688672387599945
# Training iteration 47, Hyperparameter tuned = 0.001
# Epoch 47: Policy Loss=-0.015997984735295175, Value Loss=8.546730748414994
# Training iteration 48, Hyperparameter tuned = 0.001
# Epoch 48: Policy Loss=-0.01929904593154788, Value Loss=8.761491388082504
# Training iteration 49, Hyperparameter tuned = 0.001
# Epoch 49: Policy Loss=-0.015356462858617305, Value Loss=8.453686517477035
# 2024-11-25 06:27:03,270	WARNING catalog.py:547 -- Custom ModelV2 should accept all custom options as **kwargs, instead of expecting them in config['custom_model_config']!
# 2024-11-25 06:27:03,338	INFO trainable.py:161 -- Trainable.setup took 17.921 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2024-11-25 06:27:03,340	WARNING util.py:61 -- Install gputil for GPU system monitoring.
# Training iteration 0, Hyperparameter tuned = 0.0005
# Training iteration 1, Hyperparameter tuned = 0.0005
# Epoch 1: Policy Loss=-0.01937362689524889, Value Loss=9.11296021103859
# Training iteration 2, Hyperparameter tuned = 0.0005
# Epoch 2: Policy Loss=-0.01413933463394642, Value Loss=8.38927143573761
# Training iteration 3, Hyperparameter tuned = 0.0005
# Epoch 3: Policy Loss=-0.01598782517015934, Value Loss=9.248705570697785
# Training iteration 4, Hyperparameter tuned = 0.0005
# Epoch 4: Policy Loss=-0.021503558829426766, Value Loss=8.304106068611144
# Training iteration 5, Hyperparameter tuned = 0.0005
# Epoch 5: Policy Loss=-0.017502768486738204, Value Loss=8.585722799301147
# Training iteration 6, Hyperparameter tuned = 0.0005
# Epoch 6: Policy Loss=-0.01080040544271469, Value Loss=8.4191144490242
# Training iteration 7, Hyperparameter tuned = 0.0005
# Epoch 7: Policy Loss=-0.02053361989557743, Value Loss=9.13857096195221
# Training iteration 8, Hyperparameter tuned = 0.0005
# Epoch 8: Policy Loss=-0.019424829902127384, Value Loss=8.17356883406639
# Training iteration 9, Hyperparameter tuned = 0.0005
# Epoch 9: Policy Loss=-0.01082217287272215, Value Loss=7.651917154788971
# Training iteration 10, Hyperparameter tuned = 0.0005
# Epoch 10: Policy Loss=-0.013832420706748963, Value Loss=7.008608745336533
# Training iteration 11, Hyperparameter tuned = 0.0005
# Epoch 11: Policy Loss=-0.015754616940394043, Value Loss=7.889959794282913
# Training iteration 12, Hyperparameter tuned = 0.0005
# Epoch 12: Policy Loss=-0.0061919594556093215, Value Loss=7.083940746784211
# Training iteration 13, Hyperparameter tuned = 0.0005
# Epoch 13: Policy Loss=-0.016337965056300162, Value Loss=9.113079923391343
# Training iteration 14, Hyperparameter tuned = 0.0005
# Epoch 14: Policy Loss=-0.015384701937437057, Value Loss=7.43754328250885
# Training iteration 15, Hyperparameter tuned = 0.0005
# Epoch 15: Policy Loss=-0.01760909743607044, Value Loss=7.214811673760414
# Training iteration 16, Hyperparameter tuned = 0.0005
# Epoch 16: Policy Loss=-0.01698112566024065, Value Loss=6.989159725904464
# Training iteration 17, Hyperparameter tuned = 0.0005
# Epoch 17: Policy Loss=-0.020234583858400584, Value Loss=7.3956105625629425
# Training iteration 18, Hyperparameter tuned = 0.0005
# Epoch 18: Policy Loss=-0.007944730694871395, Value Loss=7.907601352930069
# Training iteration 19, Hyperparameter tuned = 0.0005
# Epoch 19: Policy Loss=-0.021573305297642946, Value Loss=7.427633876800537
# Training iteration 20, Hyperparameter tuned = 0.0005
# Epoch 20: Policy Loss=-0.008932386040687561, Value Loss=8.150909090042115
# Training iteration 21, Hyperparameter tuned = 0.0005
# Epoch 21: Policy Loss=-0.011982594132423401, Value Loss=7.503878523111343
# Training iteration 22, Hyperparameter tuned = 0.0005
# Epoch 22: Policy Loss=-0.016155813261866568, Value Loss=7.657347754240036
# Training iteration 23, Hyperparameter tuned = 0.0005
# Epoch 23: Policy Loss=-0.02021895912475884, Value Loss=7.564138833284378
# Training iteration 24, Hyperparameter tuned = 0.0005
# Epoch 24: Policy Loss=-0.01926137290894985, Value Loss=6.903123474121093
# Training iteration 25, Hyperparameter tuned = 0.0005
# Epoch 25: Policy Loss=-0.023025809628888963, Value Loss=8.16575226187706
# Training iteration 26, Hyperparameter tuned = 0.0005
# Epoch 26: Policy Loss=-0.028054893277585508, Value Loss=8.320066037178039
# Training iteration 27, Hyperparameter tuned = 0.0005
# Epoch 27: Policy Loss=-0.020852949917316437, Value Loss=7.139382381439209
# Training iteration 28, Hyperparameter tuned = 0.0005
# Epoch 28: Policy Loss=-0.02327744223177433, Value Loss=6.480015470385552
# Training iteration 29, Hyperparameter tuned = 0.0005
# Epoch 29: Policy Loss=-0.024867940433323382, Value Loss=7.722858906984329
# Training iteration 30, Hyperparameter tuned = 0.0005
# Epoch 30: Policy Loss=-0.011805805820040404, Value Loss=6.691921583414078
# Training iteration 31, Hyperparameter tuned = 0.0005
# Epoch 31: Policy Loss=-0.018816931508481502, Value Loss=6.968819577097893
# Training iteration 32, Hyperparameter tuned = 0.0005
# Epoch 32: Policy Loss=-0.02227572467178106, Value Loss=7.124810967445374
# Training iteration 33, Hyperparameter tuned = 0.0005
# Epoch 33: Policy Loss=-0.013441679812967778, Value Loss=7.708148888349533
# Training iteration 34, Hyperparameter tuned = 0.0005
# Epoch 34: Policy Loss=-0.028653906360268593, Value Loss=7.772692668437958
# Training iteration 35, Hyperparameter tuned = 0.0005
# Epoch 35: Policy Loss=-0.027180859893560408, Value Loss=8.648060703277588
# Training iteration 36, Hyperparameter tuned = 0.0005
# Epoch 36: Policy Loss=-0.016659397296607495, Value Loss=8.530654715299606
# Training iteration 37, Hyperparameter tuned = 0.0005
# Epoch 37: Policy Loss=-0.019808884132653474, Value Loss=6.807274281978607
# Training iteration 38, Hyperparameter tuned = 0.0005
# Epoch 38: Policy Loss=-0.011498241312801838, Value Loss=8.120260112285614
# Training iteration 39, Hyperparameter tuned = 0.0005
# Epoch 39: Policy Loss=-0.0228132551535964, Value Loss=8.395346530675887
# Training iteration 40, Hyperparameter tuned = 0.0005
# Epoch 40: Policy Loss=-0.02268430366180837, Value Loss=7.205619461536408
# Training iteration 41, Hyperparameter tuned = 0.0005
# Epoch 41: Policy Loss=-0.017112225629389285, Value Loss=7.83070590019226
# Training iteration 42, Hyperparameter tuned = 0.0005
# Epoch 42: Policy Loss=-0.013426385037600994, Value Loss=7.249600195884705
# Training iteration 43, Hyperparameter tuned = 0.0005
# Epoch 43: Policy Loss=-0.01702991433441639, Value Loss=7.865742720365525
# Training iteration 44, Hyperparameter tuned = 0.0005
# Epoch 44: Policy Loss=-0.01275405876338482, Value Loss=7.775378510951996
# Training iteration 45, Hyperparameter tuned = 0.0005
# Epoch 45: Policy Loss=-0.018152611944824457, Value Loss=8.10904305934906
# Training iteration 46, Hyperparameter tuned = 0.0005
# Epoch 46: Policy Loss=-0.021556292288005353, Value Loss=7.491878592967987
# Training iteration 47, Hyperparameter tuned = 0.0005
# Epoch 47: Policy Loss=-0.018317241286858917, Value Loss=7.681164593696594
# Training iteration 48, Hyperparameter tuned = 0.0005
# Epoch 48: Policy Loss=-0.01577103093266487, Value Loss=7.161756129264831
# Training iteration 49, Hyperparameter tuned = 0.0005
# Epoch 49: Policy Loss=-0.0192090948484838, Value Loss=7.475421551465988
# 2024-11-25 07:33:08,886	WARNING catalog.py:547 -- Custom ModelV2 should accept all custom options as **kwargs, instead of expecting them in config['custom_model_config']!
# 2024-11-25 07:33:08,951	INFO trainable.py:161 -- Trainable.setup took 19.392 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2024-11-25 07:33:08,954	WARNING util.py:61 -- Install gputil for GPU system monitoring.
# Training iteration 0, Hyperparameter tuned = 0.0001
# Training iteration 1, Hyperparameter tuned = 0.0001
# Epoch 1: Policy Loss=-0.01302847681567073, Value Loss=9.415617973804475
# Training iteration 2, Hyperparameter tuned = 0.0001
# Epoch 2: Policy Loss=-0.019107904704287648, Value Loss=8.375719000101089
# Training iteration 3, Hyperparameter tuned = 0.0001
# Epoch 3: Policy Loss=-0.013687052559107541, Value Loss=7.9727670550346375
# Training iteration 4, Hyperparameter tuned = 0.0001
# Epoch 4: Policy Loss=-0.017801132909953596, Value Loss=9.038828686475753
# Training iteration 5, Hyperparameter tuned = 0.0001
# Epoch 5: Policy Loss=-0.01252414844930172, Value Loss=9.243866667747497
# Training iteration 6, Hyperparameter tuned = 0.0001
# Epoch 6: Policy Loss=-0.017185730217024683, Value Loss=8.583238335847854
# Training iteration 7, Hyperparameter tuned = 0.0001
# Epoch 7: Policy Loss=-0.018084672689437867, Value Loss=8.971562876701356
# Training iteration 8, Hyperparameter tuned = 0.0001
# Epoch 8: Policy Loss=-0.009715445190668106, Value Loss=8.874228066205978
# Training iteration 9, Hyperparameter tuned = 0.0001
# Epoch 9: Policy Loss=-0.0166139704734087, Value Loss=8.403053650856018
# Training iteration 10, Hyperparameter tuned = 0.0001
# Epoch 10: Policy Loss=-0.026763698123395442, Value Loss=8.936927906274796
# Training iteration 11, Hyperparameter tuned = 0.0001
# Epoch 11: Policy Loss=-0.013520253794267774, Value Loss=9.249974520206452
# Training iteration 12, Hyperparameter tuned = 0.0001
# Epoch 12: Policy Loss=-0.01937334697227925, Value Loss=9.064500623941422
# Training iteration 13, Hyperparameter tuned = 0.0001
# Epoch 13: Policy Loss=-0.022780697047710418, Value Loss=9.12401392698288
# Training iteration 14, Hyperparameter tuned = 0.0001
# Epoch 14: Policy Loss=-0.02460939471842721, Value Loss=8.402603791952133
# Training iteration 15, Hyperparameter tuned = 0.0001
# Epoch 15: Policy Loss=-0.012340896502137185, Value Loss=8.31804803609848
# Training iteration 16, Hyperparameter tuned = 0.0001
# Epoch 16: Policy Loss=-0.008437389805912972, Value Loss=8.599513372182846
# Training iteration 17, Hyperparameter tuned = 0.0001
# Epoch 17: Policy Loss=-0.019209769386798144, Value Loss=8.39314541220665
# Training iteration 18, Hyperparameter tuned = 0.0001
# Epoch 18: Policy Loss=-0.020027718618512155, Value Loss=8.242179865837096
# Training iteration 19, Hyperparameter tuned = 0.0001
# Epoch 19: Policy Loss=-0.008516527605243027, Value Loss=8.360291986465453
# Training iteration 20, Hyperparameter tuned = 0.0001
# Epoch 20: Policy Loss=-0.009306469336152076, Value Loss=8.300424150228501
# Training iteration 21, Hyperparameter tuned = 0.0001
# Epoch 21: Policy Loss=-0.025383401587605478, Value Loss=7.920812582969665
# Training iteration 22, Hyperparameter tuned = 0.0001
# Epoch 22: Policy Loss=-0.00525647334754467, Value Loss=8.840797029733658
# Training iteration 23, Hyperparameter tuned = 0.0001
# Epoch 23: Policy Loss=-0.008992531650001183, Value Loss=8.486182951927185
# Training iteration 24, Hyperparameter tuned = 0.0001
# Epoch 24: Policy Loss=-0.00904798023402691, Value Loss=9.04511864066124
# Training iteration 25, Hyperparameter tuned = 0.0001
# Epoch 25: Policy Loss=-0.0010242704674601555, Value Loss=8.53133679509163
# Training iteration 26, Hyperparameter tuned = 0.0001
# Epoch 26: Policy Loss=-0.00976017452776432, Value Loss=7.272713193893432
# Training iteration 27, Hyperparameter tuned = 0.0001
# Epoch 27: Policy Loss=-0.010236246436834335, Value Loss=6.983201709389687
# Training iteration 28, Hyperparameter tuned = 0.0001
# Epoch 28: Policy Loss=-0.006833056285977364, Value Loss=7.134045540094376
# Training iteration 29, Hyperparameter tuned = 0.0001
# Epoch 29: Policy Loss=-0.009558299407362938, Value Loss=8.975345818996429
# Training iteration 30, Hyperparameter tuned = 0.0001
# Epoch 30: Policy Loss=-0.004517193119972944, Value Loss=7.5900874519348145
# Training iteration 31, Hyperparameter tuned = 0.0001
# Epoch 31: Policy Loss=-0.009032595492899418, Value Loss=6.830050722360611
# Training iteration 32, Hyperparameter tuned = 0.0001
# Epoch 32: Policy Loss=-0.015463630966842175, Value Loss=7.917007261514664
# Training iteration 33, Hyperparameter tuned = 0.0001
# Epoch 33: Policy Loss=-0.012367083951830863, Value Loss=9.118980453014373
# Training iteration 34, Hyperparameter tuned = 0.0001
# Epoch 34: Policy Loss=-0.012334231287240982, Value Loss=7.6458463937044145
# Training iteration 35, Hyperparameter tuned = 0.0001
# Epoch 35: Policy Loss=-0.020042639849707486, Value Loss=8.768602466583252
# Training iteration 36, Hyperparameter tuned = 0.0001
# Epoch 36: Policy Loss=-0.007283894717693329, Value Loss=8.759562456607819
# Training iteration 37, Hyperparameter tuned = 0.0001
# Epoch 37: Policy Loss=-0.010801520682871341, Value Loss=7.929217991828918
# Training iteration 38, Hyperparameter tuned = 0.0001
# Epoch 38: Policy Loss=0.0034187483880668878, Value Loss=8.73488733291626
# Training iteration 39, Hyperparameter tuned = 0.0001
# Epoch 39: Policy Loss=-0.01595306654460728, Value Loss=8.564099414348602
# Training iteration 40, Hyperparameter tuned = 0.0001
# Epoch 40: Policy Loss=-0.015120117627084255, Value Loss=8.471617817878723
# Training iteration 41, Hyperparameter tuned = 0.0001
# Epoch 41: Policy Loss=0.0009631343558430672, Value Loss=8.293990310430527
# Training iteration 42, Hyperparameter tuned = 0.0001
# Epoch 42: Policy Loss=-0.009931544810533523, Value Loss=8.19047134399414
# Training iteration 43, Hyperparameter tuned = 0.0001
# Epoch 43: Policy Loss=-0.004806541576981544, Value Loss=7.957902038097382
# Training iteration 44, Hyperparameter tuned = 0.0001
# Epoch 44: Policy Loss=-0.0016517413780093193, Value Loss=8.496085370779037
# Training iteration 45, Hyperparameter tuned = 0.0001
# Epoch 45: Policy Loss=-0.006098021641373634, Value Loss=8.255325534343719
# Training iteration 46, Hyperparameter tuned = 0.0001
# Epoch 46: Policy Loss=-0.007882778123021126, Value Loss=8.486029320955277
# Training iteration 47, Hyperparameter tuned = 0.0001
# Epoch 47: Policy Loss=-0.004150569811463356, Value Loss=8.157082403898238
# Training iteration 48, Hyperparameter tuned = 0.0001
# Epoch 48: Policy Loss=0.0023003487288951875, Value Loss=7.671766209602356
# Training iteration 49, Hyperparameter tuned = 0.0001
# Epoch 49: Policy Loss=0.006343974433839321, Value Loss=7.5188586711883545

# %% [markdown]
# Save the model

# %%
checkpoint_path = algo.save()
print(f"Checkpoint saved at: {checkpoint_path}")
# Out:
# Checkpoint saved at: TrainingResult(checkpoint=Checkpoint(filesystem=local, path=/tmp/tmpdqmkq12n), metrics={'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'default_policy': {'custom_metrics': {}, 'learner_stats': {'cur_kl_coeff': 5.125781250000001, 'cur_lr': 0.00010000000000000002, 'total_loss': 7.626126673221588, 'policy_loss': 0.006343974433839321, 'vf_loss': 7.5188586711883545, 'vf_explained_var': 0.7433889356255531, 'kl': 0.019689488463336603, 'entropy': 7.057022197246551, 'entropy_coeff': 0.0}, 'model': {}, 'num_grad_updates_lifetime': 19800.5, 'diff_num_grad_updates_vs_sampler_policy': 199.5}}, 'num_env_steps_sampled': 25600, 'num_env_steps_trained': 25600, 'num_agent_steps_sampled': 25600, 'num_agent_steps_trained': 25600}, 'env_runners': {'episode_reward_max': 119.34456627212874, 'episode_reward_min': -730.8346616622218, 'episode_reward_mean': -85.21920222602768, 'episode_len_mean': 237.0, 'episode_media': {}, 'episodes_timesteps_total': 23700, 'policy_reward_min': {'default_policy': -730.8346616622218}, 'policy_reward_max': {'default_policy': 119.34456627212874}, 'policy_reward_mean': {'default_policy': -85.21920222602768}, 'custom_metrics': {'final_net_price_mean': 9750.187, 'final_net_price_min': 7116.6953, 'final_net_price_max': 13337.944}, 'hist_stats': {'episode_reward': [-52.98957149715145, -150.13425185759243, -269.63231180323044, -118.55305943309497, -45.910258889360016, -83.55489374075353, -48.71842289898839, -57.23825150088855, -730.8346616622218, -89.27619758648886, -52.943847789392095, -84.36956726020928, -64.11535269512689, -155.43951170105248, -87.34515137498316, -94.1155525190842, -140.48753006101774, -147.5633563757329, -167.13268845861438, -41.14952183777948, -54.82048195370653, 5.400859280679394, -41.912428322531554, -77.67482703332497, -47.056916378251856, -78.51892761633923, -63.105216493031584, -49.27202968128399, -16.33695517211507, -123.92712055047748, -55.48011575300103, -19.332366210830294, -86.85084426751635, -32.24942405538187, -119.56371967706929, -42.35352835438198, -184.83766100599544, -61.57607581618288, -44.1692368186988, -266.355132807749, -86.29341322618255, -105.57341785561154, -101.59630997349396, -125.20819318455791, -86.49732933055716, -92.60929234636707, -88.39913257663996, 119.34456627212874, -63.6888952163755, -87.03011627974071, -241.82818932024776, -44.561885244109135, -72.79666106255175, -61.46812265905529, -102.13648225346311, -107.31061093677997, 29.152205447724906, -60.82256662941088, -63.796670245746434, -165.76042536489786, -26.96441506701136, -117.80503376109016, -110.71560204538433, -37.97989911754996, -114.93002090592523, -71.51194416922415, -33.62170021508557, -49.196038940601625, -30.54892621673823, -81.0595953654251, -136.3073752792498, -56.441227415155346, -81.57499006897348, -58.90613996812497, -101.74734677166221, -45.03995408028749, -107.65574988621289, -93.01277961977513, -23.981845761451005, -39.73476625830956, -233.40125974168322, -63.96772176014827, -3.779307343888151, -51.0055077519671, 53.12924205745567, -152.06598739936095, -47.58996658200963, -43.75357655897891, 0.284546522913943, -61.09832435329607, -76.2740406549788, -50.52548565822212, -132.40831883880378, -61.88495487509504, -52.395554214071645, -61.73396577051515, -82.03299082225352, -89.56111264761387, -68.70190719786972, -74.04162648325416], 'episode_lengths': [237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237, 237], 'policy_default_policy_reward': [-52.98957149715145, -150.13425185759243, -269.63231180323044, -118.55305943309497, -45.9102588 ...
