# %%
'''
system import
'''
import math
from collections import deque
from datetime import datetime, timedelta
from os import close

'''
stock API import
'''
import tushare as ts


'''
data processing import
'''
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt


'''
gymnasium import
'''
import gymnasium
from gymnasium import spaces


'''
pytorch import
'''
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.cuda.amp import autocast, GradScaler


'''
ray import
'''
import ray
from ray import tune
from ray.rllib.algorithms.ppo import PPO
from ray.rllib.models.torch.torch_modelv2 import TorchModelV2
from ray.rllib.models.modelv2 import ModelV2
from ray.rllib.utils.annotations import override
from ray.rllib.models import ModelCatalog
from ray.rllib.models.torch.misc import SlimFC
from ray.rllib.algorithms import ppo
from ray.rllib.algorithms.ppo import PPO
from ray.rllib.algorithms.ppo import PPOConfig
from ray.rllib.algorithms.callbacks import DefaultCallbacks
from ray.rllib.env import EnvContext
from ray.tune.registry import register_env


'''
fix seed
'''
np.random.seed(135)
torch.manual_seed(135)
# Out:
# Collecting tushare
#   Downloading tushare-1.4.13-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from tushare) (2.2.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from tushare) (2.32.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from tushare) (5.3.0)
# Collecting simplejson (from tushare)
#   Downloading simplejson-3.19.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.2 kB)
# Collecting bs4 (from tushare)
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Requirement already satisfied: websocket-client>=0.57.0 in /usr/local/lib/python3.10/dist-packages (from tushare) (1.8.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from tushare) (4.66.6)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4->tushare) (4.12.3)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas->tushare) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->tushare) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->tushare) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->tushare) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->tushare) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->tushare) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->tushare) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->tushare) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->tushare) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4->tushare) (2.6)
# Downloading tushare-1.4.13-py3-none-any.whl (142 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.1/142.1 kB 11.1 MB/s eta 0:00:00
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Downloading simplejson-3.19.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (137 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 kB 11.9 MB/s eta 0:00:00
# Installing collected packages: simplejson, bs4, tushare
# Successfully installed bs4-0.0.2 simplejson-3.19.3 tushare-1.4.13
# Collecting alpha_vantage
#   Downloading alpha_vantage-3.0.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from alpha_vantage) (3.11.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from alpha_vantage) (2.32.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->alpha_vantage) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->alpha_vantage) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->alpha_vantage) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->alpha_vantage) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->alpha_vantage) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->alpha_vantage) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->alpha_vantage) (1.17.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->alpha_vantage) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->alpha_vantage) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->alpha_vantage) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->alpha_vantage) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->alpha_vantage) (2024.8.30)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from multidict<7.0,>=4.5->aiohttp->alpha_vantage) (4.12.2)
# Downloading alpha_vantage-3.0.0-py3-none-any.whl (35 kB)
# Installing collected packages: alpha_vantage
# Successfully installed alpha_vantage-3.0.0
# Collecting gymnasium
#   Downloading gymnasium-1.0.0-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (3.1.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (4.12.2)
# Collecting farama-notifications>=0.0.1 (from gymnasium)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl.metadata (558 bytes)
# Downloading gymnasium-1.0.0-py3-none-any.whl (958 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 958.1/958.1 kB 45.1 MB/s eta 0:00:00
# Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Installing collected packages: farama-notifications, gymnasium
# Successfully installed farama-notifications-0.0.4 gymnasium-1.0.0
# Collecting ray[all]
#   Downloading ray-2.39.0-cp310-cp310-manylinux2014_x86_64.whl.metadata (17 kB)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from ray[all]) (8.1.7)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from ray[all]) (3.16.1)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from ray[all]) (4.23.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ray[all]) (1.1.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from ray[all]) (24.2)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /usr/local/lib/python3.10/dist-packages (from ray[all]) (4.25.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from ray[all]) (6.0.2)
# Requirement already satisfied: aiosignal in /usr/local/lib/python3.10/dist-packages (from ray[all]) (1.3.1)
# Requirement already satisfied: frozenlist in /usr/local/lib/python3.10/dist-packages (from ray[all]) (1.5.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from ray[all]) (2.32.3)
# Requirement already satisfied: grpcio in /usr/local/lib/python3.10/dist-packages (from ray[all]) (1.68.0)
# Collecting opentelemetry-exporter-otlp (from ray[all])
#   Downloading opentelemetry_exporter_otlp-1.28.2-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: prometheus-client>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from ray[all]) (0.21.0)
# Requirement already satisfied: opentelemetry-api in /usr/local/lib/python3.10/dist-packages (from ray[all]) (1.28.2)
# Requirement already satisfied: typer in /usr/local/lib/python3.10/dist-packages (from ray[all]) (0.13.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from ray[all]) (13.9.4)
# Requirement already satisfied: gymnasium==1.0.0 in /usr/local/lib/python3.10/dist-packages (from ray[all]) (1.0.0)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.10/dist-packages (from ray[all]) (0.1.8)
# Requirement already satisfied: opentelemetry-sdk in /usr/local/lib/python3.10/dist-packages (from ray[all]) (1.28.2)
# Requirement already satisfied: aiohttp>=3.7 in /usr/local/lib/python3.10/dist-packages (from ray[all]) (3.11.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from ray[all]) (2024.10.0)
# Requirement already satisfied: pyOpenSSL in /usr/local/lib/python3.10/dist-packages (from ray[all]) (24.2.1)
# Collecting lz4 (from ray[all])
#   Downloading lz4-4.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.7 kB)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from ray[all]) (0.24.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from ray[all]) (2.2.2)
# Collecting fastapi (from ray[all])
#   Downloading fastapi-0.115.5-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: smart-open in /usr/local/lib/python3.10/dist-packages (from ray[all]) (7.0.5)
# Collecting py-spy>=0.2.0 (from ray[all])
#   Downloading py_spy-0.4.0-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (16 kB)
# Collecting virtualenv!=20.21.1,>=20.0.24 (from ray[all])
#   Downloading virtualenv-20.27.1-py3-none-any.whl.metadata (4.5 kB)
# Collecting colorful (from ray[all])
#   Downloading colorful-0.5.6-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: pyarrow>=6.0.1 in /usr/local/lib/python3.10/dist-packages (from ray[all]) (17.0.0)
# Requirement already satisfied: pydantic!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,<3 in /usr/local/lib/python3.10/dist-packages (from ray[all]) (2.9.2)
# Collecting aiohttp-cors (from ray[all])
#   Downloading aiohttp_cors-0.7.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from ray[all]) (1.13.1)
# Collecting tensorboardX>=1.9 (from ray[all])
#   Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from ray[all]) (1.26.4)
# Collecting opencensus (from ray[all])
#   Downloading opencensus-0.11.4-py2.py3-none-any.whl.metadata (12 kB)
# Collecting starlette (from ray[all])
#   Downloading starlette-0.41.3-py3-none-any.whl.metadata (6.0 kB)
# Collecting watchfiles (from ray[all])
#   Downloading watchfiles-1.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting uvicorn[standard] (from ray[all])
#   Downloading uvicorn-0.32.1-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: cupy-cuda12x in /usr/local/lib/python3.10/dist-packages (from ray[all]) (12.2.0)
# Collecting memray (from ray[all])
#   Downloading memray-1.14.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium==1.0.0->ray[all]) (3.1.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium==1.0.0->ray[all]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium==1.0.0->ray[all]) (0.0.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.7->ray[all]) (2.4.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.7->ray[all]) (24.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.7->ray[all]) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.7->ray[all]) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.7->ray[all]) (1.17.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.7->ray[all]) (4.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->ray[all]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->ray[all]) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->ray[all]) (2024.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,<3->ray[all]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,<3->ray[all]) (2.23.4)
# Collecting distlib<1,>=0.3.7 (from virtualenv!=20.21.1,>=20.0.24->ray[all])
#   Downloading distlib-0.3.9-py2.py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in /usr/local/lib/python3.10/dist-packages (from virtualenv!=20.21.1,>=20.0.24->ray[all]) (4.3.6)
# Requirement already satisfied: fastrlock>=0.5 in /usr/local/lib/python3.10/dist-packages (from cupy-cuda12x->ray[all]) (0.8.2)
# Requirement already satisfied: anyio<5,>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from starlette->ray[all]) (3.7.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray[all]) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray[all]) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray[all]) (0.21.0)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from memray->ray[all]) (3.1.4)
# Collecting textual>=0.41.0 (from memray->ray[all])
#   Downloading textual-0.87.1-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->ray[all]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->ray[all]) (2.18.0)
# Collecting opencensus-context>=0.1.3 (from opencensus->ray[all])
#   Downloading opencensus_context-0.1.3-py2.py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: six~=1.16 in /usr/local/lib/python3.10/dist-packages (from opencensus->ray[all]) (1.16.0)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from opencensus->ray[all]) (2.19.2)
# Requirement already satisfied: deprecated>=1.2.6 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-api->ray[all]) (1.2.15)
# Requirement already satisfied: importlib-metadata<=8.5.0,>=6.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-api->ray[all]) (8.5.0)
# Collecting opentelemetry-exporter-otlp-proto-grpc==1.28.2 (from opentelemetry-exporter-otlp->ray[all])
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.28.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting opentelemetry-exporter-otlp-proto-http==1.28.2 (from opentelemetry-exporter-otlp->ray[all])
#   Downloading opentelemetry_exporter_otlp_proto_http-1.28.2-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-grpc==1.28.2->opentelemetry-exporter-otlp->ray[all]) (1.66.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.28.2 (from opentelemetry-exporter-otlp-proto-grpc==1.28.2->opentelemetry-exporter-otlp->ray[all])
#   Downloading opentelemetry_exporter_otlp_proto_common-1.28.2-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.28.2 (from opentelemetry-exporter-otlp-proto-grpc==1.28.2->opentelemetry-exporter-otlp->ray[all])
#   Downloading opentelemetry_proto-1.28.2-py3-none-any.whl.metadata (2.3 kB)
# Collecting protobuf!=3.19.5,>=3.15.3 (from ray[all])
#   Downloading protobuf-5.28.3-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.49b2 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-sdk->ray[all]) (0.49b2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->ray[all]) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->ray[all]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->ray[all]) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->ray[all]) (2024.8.30)
# Requirement already satisfied: cryptography<44,>=41.0.5 in /usr/local/lib/python3.10/dist-packages (from pyOpenSSL->ray[all]) (43.0.3)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.10/dist-packages (from scikit-image->ray[all]) (3.4.2)
# Requirement already satisfied: pillow>=9.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->ray[all]) (11.0.0)
# Requirement already satisfied: imageio>=2.33 in /usr/local/lib/python3.10/dist-packages (from scikit-image->ray[all]) (2.36.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image->ray[all]) (2024.9.20)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image->ray[all]) (0.4)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open->ray[all]) (1.16.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer->ray[all]) (1.5.4)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]; extra == "all"->ray[all]) (0.14.0)
# Collecting httptools>=0.6.3 (from uvicorn[standard]; extra == "all"->ray[all])
#   Downloading httptools-0.6.4-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Collecting python-dotenv>=0.13 (from uvicorn[standard]; extra == "all"->ray[all])
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]; extra == "all"->ray[all])
#   Downloading uvloop-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]; extra == "all"->ray[all])
#   Downloading websockets-14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette->ray[all]) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette->ray[all]) (1.2.2)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography<44,>=41.0.5->pyOpenSSL->ray[all]) (1.17.1)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[all]) (1.25.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in /usr/local/lib/python3.10/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[all]) (2.27.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata<=8.5.0,>=6.0->opentelemetry-api->ray[all]) (3.21.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9->memray->ray[all]) (3.0.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->ray[all]) (0.1.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography<44,>=41.0.5->pyOpenSSL->ray[all]) (2.22)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[all]) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[all]) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[all]) (4.9)
# Requirement already satisfied: mdit-py-plugins in /usr/local/lib/python3.10/dist-packages (from markdown-it-py[linkify,plugins]>=2.1.0->textual>=0.41.0->memray->ray[all]) (0.4.2)
# Requirement already satisfied: linkify-it-py<3,>=1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py[linkify,plugins]>=2.1.0->textual>=0.41.0->memray->ray[all]) (2.0.3)
# Requirement already satisfied: uc-micro-py in /usr/local/lib/python3.10/dist-packages (from linkify-it-py<3,>=1->markdown-it-py[linkify,plugins]>=2.1.0->textual>=0.41.0->memray->ray[all]) (1.0.3)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[all]) (0.6.1)
# Downloading py_spy-0.4.0-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 32.1 MB/s eta 0:00:00
# Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 9.4 MB/s eta 0:00:00
# Downloading virtualenv-20.27.1-py3-none-any.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 93.2 MB/s eta 0:00:00
# Downloading aiohttp_cors-0.7.0-py3-none-any.whl (27 kB)
# Downloading colorful-0.5.6-py2.py3-none-any.whl (201 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.4/201.4 kB 19.8 MB/s eta 0:00:00
# Downloading fastapi-0.115.5-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.9/94.9 kB 9.8 MB/s eta 0:00:00
# Downloading starlette-0.41.3-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 6.8 MB/s eta 0:00:00
# Downloading lz4-4.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 32.9 MB/s eta 0:00:00
# Downloading memray-1.14.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (8.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 61.1 MB/s eta 0:00:00
# Downloading opencensus-0.11.4-py2.py3-none-any.whl (128 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 kB 12.0 MB/s eta 0:00:00
# Downloading opentelemetry_exporter_otlp-1.28.2-py3-none-any.whl (7.0 kB)
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.28.2-py3-none-any.whl (18 kB)
# Downloading opentelemetry_exporter_otlp_proto_http-1.28.2-py3-none-any.whl (17 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.28.2-py3-none-any.whl (18 kB)
# Downloading opentelemetry_proto-1.28.2-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 5.1 MB/s eta 0:00:00
# Downloading protobuf-5.28.3-cp38-abi3-manylinux2014_x86_64.whl (316 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.6/316.6 kB 27.3 MB/s eta 0:00:00
# Downloading ray-2.39.0-cp310-cp310-manylinux2014_x86_64.whl (66.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.3/66.3 MB 10.9 MB/s eta 0:00:00
# Downloading watchfiles-1.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (442 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.6/442.6 kB 33.7 MB/s eta 0:00:00
# Downloading distlib-0.3.9-py2.py3-none-any.whl (468 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 35.0 MB/s eta 0:00:00
# Downloading httptools-0.6.4-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (442 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.1/442.1 kB 35.3 MB/s eta 0:00:00
# Downloading opencensus_context-0.1.3-py2.py3-none-any.whl (5.1 kB)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading textual-0.87.1-py3-none-any.whl (654 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 654.7/654.7 kB 43.5 MB/s eta 0:00:00
# Downloading uvloop-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 62.4 MB/s eta 0:00:00
# Downloading websockets-14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (168 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.2/168.2 kB 15.4 MB/s eta 0:00:00
# Downloading uvicorn-0.32.1-py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.8/63.8 kB 6.0 MB/s eta 0:00:00
# Installing collected packages: py-spy, opencensus-context, distlib, colorful, websockets, virtualenv, uvloop, uvicorn, python-dotenv, protobuf, lz4, httptools, watchfiles, tensorboardX, starlette, opentelemetry-proto, opentelemetry-exporter-otlp-proto-common, fastapi, textual, ray, opencensus, aiohttp-cors, opentelemetry-exporter-otlp-proto-http, opentelemetry-exporter-otlp-proto-grpc, memray, opentelemetry-exporter-otlp
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.5
#     Uninstalling protobuf-4.25.5:
#       Successfully uninstalled protobuf-4.25.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.17.1 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 5.28.3 which is incompatible.
# tensorflow-metadata 1.13.1 requires protobuf<5,>=3.20.3, but you have protobuf 5.28.3 which is incompatible.
# Successfully installed aiohttp-cors-0.7.0 colorful-0.5.6 distlib-0.3.9 fastapi-0.115.5 httptools-0.6.4 lz4-4.3.3 memray-1.14.0 opencensus-0.11.4 opencensus-context-0.1.3 opentelemetry-exporter-otlp-1.28.2 opentelemetry-exporter-otlp-proto-common-1.28.2 opentelemetry-exporter-otlp-proto-grpc-1.28.2 opentelemetry-exporter-otlp-proto-http-1.28.2 opentelemetry-proto-1.28.2 protobuf-5.28.3 py-spy-0.4.0 python-dotenv-1.0.1 ray-2.39.0 starlette-0.41.3 tensorboardX-2.6.2.2 textual-0.87.1 uvicorn-0.32.1 uvloop-0.21.0 virtualenv-20.27.1 watchfiles-1.0.0 websockets-14.1

# %% [markdown]
# Setup Env

# %%
class PortfolioOptimizationEnv(gymnasium.Env):
    '''
    Environment setting with OpenAI

    Assumptions:
    1. In this case, the team has loose the constrain of 24 hours holding period. Once a person buy in the stock, the person can sell it immediately
    2. We have simplified the buy order mechanism so that stocks can be bought at the closing price of the day in this environment.

    State: A stack of stock price data, stock index data, current stock volums, current cash amount
    Observation: Same with state but in a 365 trading days duration
    Action: A float list with a length of N (number of stocks chosen) which elements are within range (-1,1). When positive -> buy Ni * cash amount of stock i. When negtive -> sell Ni present of stocki's volume

    '''

    def __init__(self,env_config):
        super(PortfolioOptimizationEnv, self).__init__()
        try:
            self.history_length = env_config['history_length']
            self.start = env_config['start']                        #define start date
            self.end = env_config['end']                            #define end date
            self.market = env_config['market']                      #define market -> currently only China
            self.n_stock = env_config['n_stock']                    #define the number of stock chosen
            self.cash = env_config['cash']                          #define the initial cash we take into the market
            self.smoothing_factor = env_config['smoothing_factor']  #define smooth for the DSR reward function

            self.market_data = self.load_market_data(self.start, self.end, self.market)         #Initialize market data during the start to end -> execute once to shorten running time
            self.close_data = self.load_full_close_data(self.start, self.end, self.market)      #Initialize close data

            self.stock_tensor_length = self.market_data.shape[1] - 1                                    #See observation_space
            self.date_list = self.load_trading_days(self.start, self.end, self.market)                  #Filter trading days from the period
            self.action_space = spaces.Box(low=-1, high=1, shape=(self.n_stock,), dtype=np.float32)     #define action space, please see 'Action' in the class comment for detail
            self.observation_space = spaces.Box(                                                        #define observation space as required by Rllib, the observation space have to be a flattened np list
                low=-np.inf, high=np.inf,                                                               #Thus the dimension is calcualted as shape
                shape=(self.history_length * (self.stock_tensor_length + self.n_stock + 1 + self.n_stock + 1),),
                dtype=np.float32
            )

            self.state_buffer = deque(maxlen=self.history_length)           #define state deque
            self.initial_cash = np.float32(self.cash)                       #define cash buffer
            self.stock_volume = np.zeros(self.n_stock, dtype=np.float32)    #define stock volume recorder

            self.A_t = np.float32(0.0)
            self.B_t = np.float32(0.0)
            self.Previous_A_t = np.float32(0.0)
            self.Previous_B_t = np.float32(0.0)                             #define reward parameters
            self.net_price = np.array([], dtype=np.float32)                 #define net price loader
            self.current_step = 0                                           #define step recorder

        except Exception as e:
            print("Error during initialization:", e)
            raise


    def step(self, action):
        '''
        Step function, step forward according to policy model's return
        '''

        self.current_step += 1
        next_date = self.date_list[self.current_step]
        action = self.normalize_action(action)
        reward = self.calculate_reward(action, next_date)

        next_state = self.get_state(self.current_step, action,  reward, next_date)
        stacked_state = np.array(self.state_buffer).flatten().astype(np.float32)
        stacked_state = np.nan_to_num(stacked_state, nan=1e-8, posinf=999999, neginf=-999999)

        done = self.net_price[-1] <= 0
        turncated = self.current_step >= len(self.date_list) - 1
        info = {
                "net_price": self.net_price[-1],  # Pass the current net price
                "cash": self.cash,  # Example: Pass cash if needed
            }

        '''log monitoring -> comment back when needed
        if self.current_step % 100 == 0:
          print('-------------------------------------------------')
          print(f'The net price is: {self.net_price[-1]}')
          print(f'The current step is: {self.current_step}')
          print(f'The cash is :{self.cash}')
          print(f'The stock volume is :{self.stock_volume}')
          print(f'The actions are: {action}')
        '''


        return stacked_state, reward, done, turncated, info




    def reset(self, seed = None, options = None):
        '''
        Reset function, reset the environment when an episode is done
        '''
        if seed is not None:
          np.random.seed(seed)
          torch.manual_seed(seed)
        self.state_buffer = deque(maxlen=self.history_length)
        self.cash = self.initial_cash
        self.stock_volume = np.zeros_like(self.stock_volume)
        self.A_t = np.float32(0.0)
        self.B_t = np.float32(0.0)
        self.Previous_A_t = np.float32(0.0)
        self.Previous_B_t = np.float32(0.0)
        self.net_price = np.zeros(self.history_length, dtype=np.float32)
        self.current_step = self.history_length

        self.date_list = self.load_trading_days(self.start, self.end, self.market)
        first_365_days = self.date_list[:self.history_length]

        for idx, date in enumerate(first_365_days):
            dummy_action = np.zeros(self.action_space.shape, dtype=np.float32)
            dummy_reward = 0.0
            next_state = self.get_state(idx, dummy_action, dummy_reward, date)

        stacked_state = np.array(self.state_buffer).flatten()
        stacked_state = stacked_state.astype(np.float32)
        stacked_state = np.nan_to_num(stacked_state, nan=1e-8, posinf=999999, neginf=-999999)
        return stacked_state, {}




    def get_state(self, idx, action, reward, date):
        '''
        Obtain state and return to step function
        '''
        stock_data_current = self.market_data[self.market_data['trade_date'] == date].iloc[0].drop(['trade_date']).values
        reward_array = np.array([reward], dtype=np.float32)
        net_price_current = np.array([self.net_price[self.current_step-1]], dtype=np.float32)
        full_state = np.concatenate([stock_data_current, action, reward_array, self.stock_volume, net_price_current])
        date_encodings = self.calculate_date_encoding(idx, full_state.shape[0])
        full_state_with_encoding = full_state + date_encodings
        self.state_buffer.append(full_state_with_encoding)
        return full_state_with_encoding



    def load_trading_days(self, start, end, market):
        '''
        Filter trading days
        '''
        if market == 'CHINA':
            ts.set_token('28b2dbb3562598167a7ae7929457748793ba2c1fb2f47d4542ac6b8b')
            pro = ts.pro_api()
            trade_cal = pro.trade_cal(exchange = '',start_date = start, end_date = end)
            trade_cal = trade_cal[trade_cal['is_open'] == 1]
            trading_dates = trade_cal['cal_date'].tolist()
            return trading_dates
        elif market == 'US':
            raise ValueError('Not support yet')
        else:
            raise ValueError('Invalid market type')




    def load_full_close_data(self, start, end, market='CHINA'):
        '''
        Load close price , the close price is loaded separately for calculating cumulative return and net price
        The close price in the "load_market_data" function has been normalized; thus need to load separately
        '''
        if market == 'CHINA':
            ts.set_token('28b2dbb3562598167a7ae7929457748793ba2c1fb2f47d4542ac6b8b')
            pro = ts.pro_api()
            stock_codes = ['601318.SH', '601398.SH', '600519.SH', '000001.SZ', '601857.SH']
            df_close = pd.DataFrame()

            for code in stock_codes:
                df = pro.daily(ts_code=code, start_date=start, end_date=end)
                df = df[['trade_date', 'close']]
                df_renamed = df.rename(columns={'close': f"close_{code.split('.')[0]}"})

                if df_close.empty:
                    df_close = df_renamed
                else:
                    df_close = pd.merge(df_close, df_renamed, on='trade_date', how='outer')

            df_close.sort_values('trade_date', inplace=True)
            return df_close

        elif market == 'US':
            raise ValueError('Not support yet')
        else:
            raise ValueError('Invalid market type')



    def load_close_data(self, date):
            '''
            Load close price for a specific day
            '''
            data_on_date = self.close_data[self.close_data['trade_date'] == date]
            close_columns = [col for col in data_on_date.columns if 'close_' in col]
            close_array = data_on_date[close_columns].values.flatten().astype(np.float32)
            return close_array



    def load_market_data(self, start, end, market='CHINA'):
        '''
        Load the market data and normalize it
        '''
        if market == 'CHINA':
            ts.set_token('28b2dbb3562598167a7ae7929457748793ba2c1fb2f47d4542ac6b8b')
            pro = ts.pro_api()

            stock_codes = ['601318.SH', '601398.SH', '600519.SH', '000001.SZ', '601857.SH']
            Full_CHINA_STOCK_df = pd.DataFrame()

            for code in stock_codes:
                df = pro.daily(ts_code=code, start_date=start, end_date=end)
                adj_factors = pro.adj_factor(ts_code=code, start_date=start, end_date=end)
                daily_basic = pro.daily_basic(ts_code=code, start_date=start, end_date=end)
                daily_basic = daily_basic.drop(columns=['close'])

                df = pd.merge(df, adj_factors[['trade_date', 'adj_factor']], on='trade_date', how='left')
                df['close_adj'] = df['close'] / df['adj_factor']
                df['open_adj'] = df['open'] / df['adj_factor']
                df['high_adj'] = df['high'] / df['adj_factor']
                df['low_adj'] = df['low'] / df['adj_factor']
                df['close_price'] = df['close']
                df = pd.merge(df, daily_basic, on='trade_date', how='left')
                df = df.drop(columns=['adj_factor', 'ts_code_x','ts_code_y','close'])
                df_renamed = df.rename(columns=lambda x: f"{x}_{code.split('.')[0]}" if x != 'trade_date' else x)

                if Full_CHINA_STOCK_df.empty:
                    Full_CHINA_STOCK_df = df_renamed
                else:
                    Full_CHINA_STOCK_df = pd.merge(Full_CHINA_STOCK_df, df_renamed, on='trade_date', how='outer')

            Full_CHINA_STOCK_df.sort_values('trade_date', inplace=True)
            columns_to_normalize = [col for col in Full_CHINA_STOCK_df.columns if col != 'trade_date']
            scaler = MinMaxScaler()
            Full_CHINA_STOCK_df[columns_to_normalize] = scaler.fit_transform(Full_CHINA_STOCK_df[columns_to_normalize])

            return Full_CHINA_STOCK_df

        elif market == 'US':
            raise ValueError('Not support yet')
        else:
            raise ValueError('Invalid market type')



    def calculate_date_encoding(self, idx, embedding_dimension):
        '''
        Add date encoding to the data according to the paper "Attention is all you need" by Vaswani et al.
        But somehow it also works on our value function which is a LSTM setting in this case. Need further investigate

        Also. there are two possible method to implement this embedding, one put it here follow the instruction in 'attention is all you need',
        two you can put it within the model to make it trainable parameters, we will investigate on this
        '''
        encoding = []
        for i in range(embedding_dimension):
            if i % 2 == 0:
                value = np.sin(idx / (10000 ** (i / embedding_dimension)))
            else:
                value = np.cos(idx / (10000 ** (i / embedding_dimension)))
            encoding.append(value)
        return np.array(encoding, dtype=np.float32)




    def calculate_reward(self, action, date):
        '''
        Implement Differencial Sharpe Ratio (DSR) as the reward function to take in consideration of the risk
        '''

        portfolio_return = self.get_portfolio_return(action, date)
        self.Previous_A_t = self.A_t.copy()
        self.Previous_B_t = self.B_t.copy()
        self.A_t = (1 - self.smoothing_factor) * self.A_t + self.smoothing_factor * portfolio_return
        self.B_t = (1 - self.smoothing_factor) * self.B_t + self.smoothing_factor * (portfolio_return ** 2)

        delta_A_t = self.A_t - self.Previous_A_t
        delta_B_t = self.B_t - self.Previous_B_t

        if self.Previous_B_t - (self.Previous_A_t ** 2) > 0:
            denom = (self.Previous_B_t - (self.Previous_A_t ** 2)) ** 1.5
            numer = self.Previous_B_t * delta_A_t - 0.5 * self.Previous_A_t * delta_B_t
            DSR = numer / denom
        else:
            DSR = 0
        return DSR



    def calculate_net_price(self, action, date):
        '''
        Calcualte the net price for a day
        '''
        close_values = self.load_close_data(date)
        for idx, act in enumerate(action):
            if act > 0:
                self.stock_volume[idx] += (self.cash * act) / close_values[idx]
                self.cash -= self.cash * act
            elif act < 0:
                self.cash += (-act) * self.stock_volume[idx] * close_values[idx]
                self.stock_volume[idx] += self.stock_volume[idx] * act
        net_price_value = self.cash + np.sum(self.stock_volume * close_values)
        self.net_price = np.append(self.net_price, net_price_value)
        return net_price_value



    def get_portfolio_return(self, action, date):
        '''
        Calcualte the return for a day
        '''
        current_price = self.calculate_net_price(action, date)
        last_day = self.current_step - 2
        previous_price = self.net_price[last_day]
        return np.float32(current_price - previous_price)



    def normalize_action(self, action):
        '''
        Since the positive action sampled from the policy model does not always sum up to 1 which represent over 100% of the cash, thus we needs to normalize it
        '''
        positive_mask = (action >= 0).astype(np.float32)
        positive_action = action * positive_mask
        positive_sum = np.sum(positive_action)
        if positive_sum > 1:
            positive_action = positive_action / positive_sum
        action = action * (1 - positive_mask) + positive_action

        for i, a in enumerate(action):
            if a < 0:
              if self.stock_volume[i] > 0:
                continue
              else:
                action[i] = 0
        return action

# %% [markdown]
# Build Transformer Actor and Critic

# %%
#Code Reference: University of Toronto ECE1786 Assignment3 Author: Jonathan Rose
class NewGELU(nn.Module):
    """
    Implementation of the GELU activation function currently in Google BERT repo (identical to OpenAI GPT).
    Reference: Gaussian Error Linear Units (GELU) paper: https://arxiv.org/abs/1606.08415
    """
    def forward(self, x):
        return 0.5 * x * (1.0 + torch.tanh(math.sqrt(2.0 / math.pi) * (x + 0.044715 * torch.pow(x, 3.0))))

class CausalSelfAttention(nn.Module):
    """
    A vanilla multi-head masked self-attention layer with a projection at the end.
    It is possible to use torch.nn.MultiheadAttention here but I am including an
    explicit implementation here to show that there is nothing too scary here.
    """


    def __init__(self, model_config):
        super().__init__()
        assert model_config['n_embd'] % model_config['n_head'] == 0
        # key, query, value projections for all heads, but in a batch
        self.c_attn = nn.Linear(model_config['n_embd'], 3 * model_config['n_embd'])
        # output projection
        self.c_proj = nn.Linear(model_config['n_embd'], model_config['n_embd'])
        # regularization
        self.attn_dropout = nn.Dropout(model_config['attn_pdrop'])
        self.resid_dropout = nn.Dropout(model_config['resid_pdrop'])
        # causal mask to ensure that attention is only applied to the left in the input sequence
        self.register_buffer("bias", torch.tril(torch.ones(model_config['block_size'], model_config['block_size']))
                                     .view(1, 1, model_config['block_size'], model_config['block_size']))
        self.n_head = model_config['n_head']
        self.n_embd = model_config['n_embd']



    def forward(self, x):
        B, T, C = x.size() # batch size, sequence length, embedding dimensionality (n_embd)

        # calculate query, key, values for all heads in batch and move head forward to be the batch dim
        q, k ,v  = self.c_attn(x).split(self.n_embd, dim=2)
        k = k.view(B, T, self.n_head, C // self.n_head).transpose(1, 2) # (B, nh, T, hs)
        q = q.view(B, T, self.n_head, C // self.n_head).transpose(1, 2) # (B, nh, T, hs)
        v = v.view(B, T, self.n_head, C // self.n_head).transpose(1, 2) # (B, nh, T, hs)

        # causal self-attention; Self-attend: (B, nh, T, hs) x (B, nh, hs, T) -> (B, nh, T, T)
        att = (q @ k.transpose(-2, -1)) * (1.0 / math.sqrt(k.size(-1)))
        att = att.masked_fill(self.bias[:,:,:T,:T] == 0, float('-inf'))
        att = F.softmax(att, dim=-1)
        att = self.attn_dropout(att)
        y = att @ v # (B, nh, T, T) x (B, nh, T, hs) -> (B, nh, T, hs)
        y = y.transpose(1, 2).contiguous().view(B, T, C) # re-assemble all head outputs side by side

        # output projection
        y = self.resid_dropout(self.c_proj(y))
        return y



class Block(nn.Module):
    """ an unassuming Transformer block """
    def __init__(self, model_config):
        super().__init__()
        self.ln_1 = nn.LayerNorm(model_config['n_embd'])
        self.attn = CausalSelfAttention(model_config)
        self.ln_2 = nn.LayerNorm(model_config['n_embd'])
        self.mlp = nn.ModuleDict(dict(
            c_fc    = nn.Linear(model_config['n_embd'], 4 * model_config['n_embd']),
            c_proj  = nn.Linear(4 * model_config['n_embd'], model_config['n_embd']),
            act     = NewGELU(),
            dropout = nn.Dropout(model_config['resid_pdrop']),
        ))
        m = self.mlp
        self.mlpf = lambda x: m.dropout(m.c_proj(m.act(m.c_fc(x)))) # MLP forward



    def forward(self, x):
        x = x + self.attn(self.ln_1(x))
        x = x + self.mlpf(self.ln_2(x))
        return x



# This actor model is responsible for choosing the actions for cash allocation
class CustomActorCriticModel(TorchModelV2, nn.Module):
    def __init__(self, obs_space, action_space, num_outputs, model_config, name):
        TorchModelV2.__init__(self, obs_space, action_space, num_outputs, model_config, name)
        nn.Module.__init__(self)
        custom_model_config = model_config['custom_model_config']
        self.n_embd = custom_model_config['n_embd']
        self.n_layer = custom_model_config['n_layer']
        self.n_head = custom_model_config['n_head']
        self.block_size = custom_model_config['block_size']
        self.embd_pdrop = custom_model_config['embd_pdrop']
        self.resid_pdrop = custom_model_config['resid_pdrop']
        self.attn_pdrop = custom_model_config['attn_pdrop']

        self.transformer = nn.ModuleDict({
            'drop': nn.Dropout(self.embd_pdrop),
            'h': nn.ModuleList([Block(custom_model_config) for _ in range(self.n_layer)]),
            'ln_f': nn.LayerNorm(self.n_embd),
        })

        self.policy_head = nn.Linear(self.n_embd, num_outputs)
        self.value_head = nn.Linear(self.n_embd, 1)
        self.apply(self._init_weights)

        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        self.to(self.device)



    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)
            if module.bias is not None:
                torch.nn.init.zeros_(module.bias)
        elif isinstance(module, nn.Embedding):
            torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)
        elif isinstance(module, nn.LayerNorm):
            torch.nn.init.zeros_(module.bias)
            torch.nn.init.ones_(module.weight)



    def forward(self, input_dict, state, seq_lens):

        if isinstance(input_dict['obs'], np.ndarray):
            obs = torch.tensor(input_dict['obs'], dtype=torch.float32).to(self.device)
        else:
            obs = input_dict['obs'].to(self.device)

        batch_size = obs.size(0)
        orig = obs.size(1)
        obs = obs.view(batch_size, orig//self.n_embd, self.n_embd )
        x = self.transformer.drop(obs)
        for block in self.transformer.h:
            x = block(x)
        x = self.transformer.ln_f(x)
        last_hidden_state = x[:, -1, :]

        policy = self.policy_head(last_hidden_state)
        value = self.value_head(last_hidden_state)      #no need in this LSTM value function case
        self._value_out = self.value_head(last_hidden_state).squeeze(-1)
        return policy, state

    def value_function(self):       #no need in this LSTM value function case
        return self._value_out

ModelCatalog.register_custom_model('custom_actor_critic_model',CustomActorCriticModel)

# %%
class CustomValueModel(TorchModelV2, nn.Module):
    def __init__(self, obs_space, action_space, num_outputs, model_config, name):
        TorchModelV2.__init__(self, obs_space, action_space, num_outputs, model_config, name)
        nn.Module.__init__(self)
        custom_model_config = model_config['custom_model_config']
        self.n_embd = custom_model_config['n_embd']
        self.n_layer = custom_model_config['n_layer']
        self.n_head = custom_model_config['n_head']
        self.block_size = custom_model_config['block_size']
        self.embd_pdrop = custom_model_config['embd_pdrop']
        self.resid_pdrop = custom_model_config['resid_pdrop']
        self.attn_pdrop = custom_model_config['attn_pdrop']

        self.transformer = nn.ModuleDict({
            'drop': nn.Dropout(self.embd_pdrop),
            'h': nn.ModuleList([Block(custom_model_config) for _ in range(self.n_layer)]),
            'ln_f': nn.LayerNorm(self.n_embd),
        })

        self.policy_head = nn.Linear(self.n_embd, num_outputs)
        self.value_head = nn.Linear(self.n_embd, 1)
        self.apply(self._init_weights)

        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        self.to(self.device)



    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)
            if module.bias is not None:
                torch.nn.init.zeros_(module.bias)
        elif isinstance(module, nn.Embedding):
            torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)
        elif isinstance(module, nn.LayerNorm):
            torch.nn.init.zeros_(module.bias)
            torch.nn.init.ones_(module.weight)



    def forward(self, input_dict, state, seq_lens):

        if isinstance(input_dict['obs'], np.ndarray):
            obs = torch.tensor(input_dict['obs'], dtype=torch.float32).to(self.device)
        else:
            obs = input_dict['obs'].to(self.device)

        batch_size = obs.size(0)
        orig = obs.size(1)
        obs = obs.view(batch_size, orig//self.n_embd, self.n_embd )
        x = self.transformer.drop(obs)
        for block in self.transformer.h:
            x = block(x)
        x = self.transformer.ln_f(x)
        last_hidden_state = x[:, -1, :]

        value = self.value_head(last_hidden_state)
        self._value_out = self.value_head(last_hidden_state).squeeze(-1)
        return None, state

    def value_function(self):
        return self._value_out


ModelCatalog.register_custom_model('custom_value_model', CustomValueModel)

# %%
class CustomMetricsCallback(DefaultCallbacks):
    '''
    Custom call back class to monitor the net price
    '''
    def on_episode_end(self, *, worker, base_env, policies, episode, **kwargs):
        #print(f"The episode is {episode}")
        env = base_env.get_sub_environments()[0]
        final_net_price = env.net_price[-1] if len(env.net_price) > 0 else None
        if final_net_price is not None:
            episode.custom_metrics["final_net_price"] = final_net_price

# %%
config = {
    'env': 'my_portfolio_env',
    'num_workers': 0,
    'num_gpus': 1,
    'framework': 'torch',
    'env_config': {
        'n_stock': 5,
        'cash': 10000,
        'history_length': 365,
        'market': 'CHINA',
        'start': '20210101',
        'end': '20230631',
        'smoothing_factor': 0.1
    },
    'val_env_config': {
        'n_stock': 5,
        'cash': 10000,
        'history_length': 100,
        'market': 'CHINA',
        'start': '20230701',
        'end': '20231231',
        'smoothing_factor': 0.1
    },
    'model': {
        'custom_model': 'custom_actor_critic_model',
        'custom_action_dist': None,
        'vf_share_layers': True,
        'custom_model_config': {
            'n_embd': 152,
            'n_layer': 2,
            'n_head': 2,
            'block_size': 512,
            'embd_pdrop': 0.1,
            'resid_pdrop': 0.1,
            'attn_pdrop': 0.1
        }
    },

    'lr': 5e-3, #change 4
    'train_batch_size': 512,
    'sgd_minibatch_size': 16,
    'num_epochs': 100,
    'callbacks': CustomMetricsCallback,
}

# %%
ray.init(ignore_reinit_error=True)

def env_creator(env_config):
    return PortfolioOptimizationEnv(env_config)

register_env('my_portfolio_env', env_creator)

history_length_list = [20,50,100,200,300,400]

eval_rewards = {}
eval_net_prices = {}

def evaluate(trainer, env, num_episodes=10):
    all_rewards = []
    net_prices = []

    for episode in range(num_episodes):
        episode_reward = 0
        done = False
        truncated = False
        obs = env.reset()

        while not done and not truncated:
            if isinstance(obs, tuple):
                obs_input = obs[0]
            elif isinstance(obs, dict):
                obs_input = obs["obs"]
            else:
                obs_input = obs

            action = trainer.compute_single_action(obs_input, explore=False)
            obs, reward, done, truncated, info = env.step(action)
            episode_reward += reward

        all_rewards.append(episode_reward)
        net_price = env.net_price[-1]
        net_prices.append(net_price)

    return all_rewards, net_prices

for history in history_length_list:
    config['env_config']['history_length'] = history

    algo = (
        PPOConfig()
        .environment('my_portfolio_env', env_config=config['env_config'])
        .framework('torch')
        .resources(num_gpus=1)
        .env_runners(num_env_runners=config['num_workers'])
        .training(
            model=config['model'],
            lr=config['lr'],
            train_batch_size=config['train_batch_size'],
            num_epochs=config['num_epochs']
        )
        .api_stack(
            enable_rl_module_and_learner=False,
            enable_env_runner_and_connector_v2=False
        )
        .rollouts(sample_timeout_s=300)
        .callbacks(CustomMetricsCallback)
        .build()
    )

    num_epochs = 50
    epoch_net_values = []
    epoch_policy_loss = []
    epoch_value_loss = []

    for i in range(num_epochs):
        print(f"Training iteration {i}, Hyperparameter tuned = {history}")
        result = algo.train()
        if i != 0:
            policy_loss = result["info"]["learner"]["default_policy"]["learner_stats"]["policy_loss"]
            value_loss = result["info"]["learner"]["default_policy"]["learner_stats"]["vf_loss"]
            net_value = result["env_runners"]["custom_metrics"]["final_net_price_mean"]
            epoch_policy_loss.append(policy_loss)
            epoch_value_loss.append(value_loss)
            epoch_net_values.append(net_value)
            print(f"Epoch {i}: Policy Loss={policy_loss}, Value Loss={value_loss}")
            torch.cuda.empty_cache()

    epochs = range(1, len(epoch_policy_loss) + 1)
    epochs = np.array(epochs)
    epoch_net_values = np.array(epoch_net_values)

    coefficients = np.polyfit(epochs, epoch_net_values, deg=1)
    trendline = np.polyval(coefficients, epochs)

    plt.figure(figsize=(10, 6))
    plt.plot(epochs, epoch_net_values, marker='o', label='Net Value')
    plt.plot(epochs, trendline, color='red', linestyle='--', label='Trendline')

    plt.title(f'Net Value with Trendline')
    plt.xlabel('Epoch')
    plt.ylabel('Metric Value')
    plt.legend()
    plt.grid()
    plt.show()



    plt.figure(figsize=(10, 6))
    plt.plot(epochs, epoch_policy_loss, marker='o', label='Policy Loss')
    plt.title(f'Policy Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Metric Value')
    plt.legend()
    plt.grid()
    plt.show()

    plt.figure(figsize=(10, 6))
    plt.plot(epochs, epoch_value_loss, marker='o', label='Value Loss')
    plt.title(f'Value Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Metric Value')
    plt.legend()
    plt.grid()
    plt.show()


    evaluation_env = PortfolioOptimizationEnv(config['val_env_config'])
    all_rewards, net_prices = evaluate(algo, evaluation_env, num_episodes=10)
    evaluation_env.close()

    eval_rewards[history] = all_rewards
    eval_net_prices[history] = net_prices

plt.figure(figsize=(12, 6))
for history, rewards in eval_rewards.items():
    episodes = range(1, len(rewards) + 1)
    plt.plot(episodes, rewards, marker='o', linestyle='-', label=f'history={history}')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.title('Episode Rewards for Different Learning Rates')
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(12, 6))
for history, net_prices in eval_net_prices.items():
    episodes = range(1, len(net_prices) + 1)
    plt.plot(episodes, net_prices, marker='x', linestyle='--', label=f'history={history}')
plt.xlabel('Episode')
plt.ylabel('Net Price')
plt.title('Episode Net Prices for Different Learning Rates')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 2024-11-25 15:21:02,167	INFO worker.py:1810 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# 2024-11-25 15:21:04,660	WARNING deprecation.py:50 -- DeprecationWarning: `rollouts` has been deprecated. Use `AlgorithmConfig.env_runners(..)` instead. This will raise an error in the future!
# 2024-11-25 15:21:22,065	WARNING catalog.py:547 -- Custom ModelV2 should accept all custom options as **kwargs, instead of expecting them in config['custom_model_config']!
# 2024-11-25 15:21:28,274	INFO trainable.py:161 -- Trainable.setup took 23.557 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2024-11-25 15:21:28,276	WARNING util.py:61 -- Install gputil for GPU system monitoring.
# Training iteration 0, Hyperparameter tuned = 20
# 2024-11-25 15:21:33,802	WARNING deprecation.py:50 -- DeprecationWarning: `ray.rllib.execution.train_ops.multi_gpu_train_one_step` has been deprecated. This will raise an error in the future!
# Training iteration 1, Hyperparameter tuned = 20
# Epoch 1: Policy Loss=-0.024051540568470954, Value Loss=0.15094124232418835
# Training iteration 2, Hyperparameter tuned = 20
# Epoch 2: Policy Loss=-0.021967088468372822, Value Loss=0.11696413460187614
# Training iteration 3, Hyperparameter tuned = 20
# Epoch 3: Policy Loss=-0.0168450124328956, Value Loss=0.08373806236311793
# Training iteration 4, Hyperparameter tuned = 20
# Epoch 4: Policy Loss=-0.02143204540014267, Value Loss=0.12417210835032165
# Training iteration 5, Hyperparameter tuned = 20
# Epoch 5: Policy Loss=-0.02154312767088413, Value Loss=0.14223367425613107
# Training iteration 6, Hyperparameter tuned = 20
# Epoch 6: Policy Loss=-0.011108936499804259, Value Loss=0.1032015779800713
# Training iteration 7, Hyperparameter tuned = 20
# Epoch 7: Policy Loss=-0.028303014896810055, Value Loss=0.11685692404396832
# Training iteration 8, Hyperparameter tuned = 20
# Epoch 8: Policy Loss=-0.017581849247217177, Value Loss=0.16383148709312081
# Training iteration 9, Hyperparameter tuned = 20
# Epoch 9: Policy Loss=-0.03623835567384958, Value Loss=0.08737280131317675
# Training iteration 10, Hyperparameter tuned = 20
# Epoch 10: Policy Loss=-0.02695273667573929, Value Loss=0.06428775930777192
# Training iteration 11, Hyperparameter tuned = 20
# Epoch 11: Policy Loss=-0.02290181815624237, Value Loss=0.08071396169718355
# Training iteration 12, Hyperparameter tuned = 20
# Epoch 12: Policy Loss=-0.0201821924187243, Value Loss=0.07369287225417792
# Training iteration 13, Hyperparameter tuned = 20
# Epoch 13: Policy Loss=-0.024973967000842093, Value Loss=0.10191408934071661
# Training iteration 14, Hyperparameter tuned = 20
# Epoch 14: Policy Loss=-0.01789328632876277, Value Loss=0.0929785990808159
# Training iteration 15, Hyperparameter tuned = 20
# Epoch 15: Policy Loss=-0.01652486015111208, Value Loss=0.1078439606539905
# Training iteration 16, Hyperparameter tuned = 20
# Epoch 16: Policy Loss=-0.013969346284866332, Value Loss=0.11075121400877834
# Training iteration 17, Hyperparameter tuned = 20
# Epoch 17: Policy Loss=-0.02557775791734457, Value Loss=0.21216006930917503
# Training iteration 18, Hyperparameter tuned = 20
# Epoch 18: Policy Loss=-0.021224233377724885, Value Loss=0.08536762469448149
# Training iteration 19, Hyperparameter tuned = 20
# Epoch 19: Policy Loss=-0.021219342178665102, Value Loss=0.09738438745960593
# Training iteration 20, Hyperparameter tuned = 20
# Epoch 20: Policy Loss=-0.01941474761813879, Value Loss=0.09165174530819059
# Training iteration 21, Hyperparameter tuned = 20
# Epoch 21: Policy Loss=-0.021447189785540104, Value Loss=0.13151588373817502
# Training iteration 22, Hyperparameter tuned = 20
# Epoch 22: Policy Loss=-0.016114635467529295, Value Loss=0.09399526251479984
# Training iteration 23, Hyperparameter tuned = 20
# Epoch 23: Policy Loss=-0.033284242022782566, Value Loss=0.11197759587317706
# Training iteration 24, Hyperparameter tuned = 20
# Epoch 24: Policy Loss=-0.01938733068294823, Value Loss=0.08143179338425398
# Training iteration 25, Hyperparameter tuned = 20
# Epoch 25: Policy Loss=-0.026695650024339556, Value Loss=0.09507385129574686
# Training iteration 26, Hyperparameter tuned = 20
# Epoch 26: Policy Loss=-0.02636301811784506, Value Loss=0.12118049363605678
# Training iteration 27, Hyperparameter tuned = 20
# Epoch 27: Policy Loss=-0.022100864611566066, Value Loss=0.06334977771621197
# Training iteration 28, Hyperparameter tuned = 20
# Epoch 28: Policy Loss=-0.02586601845920086, Value Loss=0.08575896797701717
# Training iteration 29, Hyperparameter tuned = 20
# Epoch 29: Policy Loss=-0.01926341149955988, Value Loss=0.11784158159047366
# Training iteration 30, Hyperparameter tuned = 20
# Epoch 30: Policy Loss=-0.02525901439599693, Value Loss=0.057294207364320754
# Training iteration 31, Hyperparameter tuned = 20
# Epoch 31: Policy Loss=-0.016265183263458313, Value Loss=0.07830723624676467
# Training iteration 32, Hyperparameter tuned = 20
# Epoch 32: Policy Loss=-0.025798711758106947, Value Loss=0.07073785843327642
# Training iteration 33, Hyperparameter tuned = 20
# Epoch 33: Policy Loss=-0.02041077656671405, Value Loss=0.08104965779930354
# Training iteration 34, Hyperparameter tuned = 20
# Epoch 34: Policy Loss=-0.02750655058771372, Value Loss=0.09033479945268481
# Training iteration 35, Hyperparameter tuned = 20
# Epoch 35: Policy Loss=-0.023806279059499502, Value Loss=0.06930238995235413
# Training iteration 36, Hyperparameter tuned = 20
# Epoch 36: Policy Loss=-0.03445440731942653, Value Loss=0.060825943779200316
# Training iteration 37, Hyperparameter tuned = 20
# Epoch 37: Policy Loss=-0.017222551088780166, Value Loss=0.053965421309694644
# Training iteration 38, Hyperparameter tuned = 20
# Epoch 38: Policy Loss=-0.03808597336988896, Value Loss=0.06286833882331848
# Training iteration 39, Hyperparameter tuned = 20
# Epoch 39: Policy Loss=-0.026230223327875137, Value Loss=0.07232094227802008
# Training iteration 40, Hyperparameter tuned = 20
# Epoch 40: Policy Loss=-0.03665593776851892, Value Loss=0.05814235092140734
# Training iteration 41, Hyperparameter tuned = 20
# Epoch 41: Policy Loss=-0.03626322924159467, Value Loss=0.05970029707532376
# Training iteration 42, Hyperparameter tuned = 20
# Epoch 42: Policy Loss=-0.028396573774516584, Value Loss=0.0474906593398191
# Training iteration 43, Hyperparameter tuned = 20
# Epoch 43: Policy Loss=-0.03147611729800701, Value Loss=0.10817381548695267
# Training iteration 44, Hyperparameter tuned = 20
# Epoch 44: Policy Loss=-0.029290096005424857, Value Loss=0.06118560269474983
# Training iteration 45, Hyperparameter tuned = 20
# Epoch 45: Policy Loss=-0.03587978044524789, Value Loss=0.09112228304147721
# Training iteration 46, Hyperparameter tuned = 20
# Epoch 46: Policy Loss=-0.0349210237339139, Value Loss=0.05760760297998786
# Training iteration 47, Hyperparameter tuned = 20
# Epoch 47: Policy Loss=-0.02519558310508728, Value Loss=0.06779608160257339
# Training iteration 48, Hyperparameter tuned = 20
# Epoch 48: Policy Loss=-0.02842760119587183, Value Loss=0.069023293312639
# Training iteration 49, Hyperparameter tuned = 20
# Epoch 49: Policy Loss=-0.03661122865974903, Value Loss=0.05527169074863195
# 2024-11-25 15:31:28,673	WARNING catalog.py:547 -- Custom ModelV2 should accept all custom options as **kwargs, instead of expecting them in config['custom_model_config']!
# 2024-11-25 15:31:28,701	INFO trainable.py:161 -- Trainable.setup took 12.730 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2024-11-25 15:31:28,703	WARNING util.py:61 -- Install gputil for GPU system monitoring.
# Training iteration 0, Hyperparameter tuned = 50
# Training iteration 1, Hyperparameter tuned = 50
# Epoch 1: Policy Loss=-0.027479204218834638, Value Loss=0.11751777675934136
# Training iteration 2, Hyperparameter tuned = 50
# Epoch 2: Policy Loss=-0.03496693182736635, Value Loss=0.08624955578707158
# Training iteration 3, Hyperparameter tuned = 50
# Epoch 3: Policy Loss=-0.027463530451059343, Value Loss=0.10253519663587213
# Training iteration 4, Hyperparameter tuned = 50
# Epoch 4: Policy Loss=-0.03071322724223137, Value Loss=0.2539097101427615
# Training iteration 5, Hyperparameter tuned = 50
# Epoch 5: Policy Loss=-0.036296712756156924, Value Loss=0.11490381087176502
# Training iteration 6, Hyperparameter tuned = 50
# Epoch 6: Policy Loss=-0.021412387937307358, Value Loss=0.12875640380196274
# Training iteration 7, Hyperparameter tuned = 50
# Epoch 7: Policy Loss=-0.026734438017010687, Value Loss=0.08617343631573021
# Training iteration 8, Hyperparameter tuned = 50
# Epoch 8: Policy Loss=-0.0440759152173996, Value Loss=0.07619413712993264
# Training iteration 9, Hyperparameter tuned = 50
# Epoch 9: Policy Loss=-0.035357497557997705, Value Loss=0.0881686111818999
# Training iteration 10, Hyperparameter tuned = 50
# Epoch 10: Policy Loss=-0.02944662650115788, Value Loss=0.1400068318936974
# Training iteration 11, Hyperparameter tuned = 50
# Epoch 11: Policy Loss=-0.04746686545200646, Value Loss=0.08945686829276384
# Training iteration 12, Hyperparameter tuned = 50
# Epoch 12: Policy Loss=-0.02252625161781907, Value Loss=0.10752235677093268
# Training iteration 13, Hyperparameter tuned = 50
# Epoch 13: Policy Loss=-0.02794287506490946, Value Loss=0.21164128446951508
# Training iteration 14, Hyperparameter tuned = 50
# Epoch 14: Policy Loss=-0.02779007289558649, Value Loss=0.08911308615468443
# Training iteration 15, Hyperparameter tuned = 50
# Epoch 15: Policy Loss=-0.03874619234353304, Value Loss=0.050473353830166164
# Training iteration 16, Hyperparameter tuned = 50
# Epoch 16: Policy Loss=-0.02997851826250553, Value Loss=0.08322608950547875
# Training iteration 17, Hyperparameter tuned = 50
# Epoch 17: Policy Loss=-0.03243106821086258, Value Loss=0.0708458859520033
# Training iteration 18, Hyperparameter tuned = 50
# Epoch 18: Policy Loss=-0.027026797533035277, Value Loss=0.15678366150707007
# Training iteration 19, Hyperparameter tuned = 50
# Epoch 19: Policy Loss=-0.033495824793353675, Value Loss=0.12197450405918062
# Training iteration 20, Hyperparameter tuned = 50
# Epoch 20: Policy Loss=-0.03176196452230215, Value Loss=0.09559168867766857
# Training iteration 21, Hyperparameter tuned = 50
# Epoch 21: Policy Loss=-0.02822931218892336, Value Loss=0.0678976076003164
# Training iteration 22, Hyperparameter tuned = 50
# Epoch 22: Policy Loss=-0.038181015364825724, Value Loss=0.137264207014814
# Training iteration 23, Hyperparameter tuned = 50
# Epoch 23: Policy Loss=-0.04940817017108202, Value Loss=0.11754470300860703
# Training iteration 24, Hyperparameter tuned = 50
# Epoch 24: Policy Loss=-0.03204972390085459, Value Loss=0.11715922520961612
# Training iteration 25, Hyperparameter tuned = 50
# Epoch 25: Policy Loss=-0.04483988573774696, Value Loss=0.1295089694019407
# Training iteration 26, Hyperparameter tuned = 50
# Epoch 26: Policy Loss=-0.03948344675824046, Value Loss=0.08943370919674636
# Training iteration 27, Hyperparameter tuned = 50
# Epoch 27: Policy Loss=-0.0355994389206171, Value Loss=0.10425807956606149
# Training iteration 28, Hyperparameter tuned = 50
# Epoch 28: Policy Loss=-0.03500371597707272, Value Loss=0.06439083436504006
# Training iteration 29, Hyperparameter tuned = 50
# Epoch 29: Policy Loss=-0.03752848800737411, Value Loss=0.07502716216258705
# Training iteration 30, Hyperparameter tuned = 50
# Epoch 30: Policy Loss=-0.03778780888766051, Value Loss=0.11210639934055507
# Training iteration 31, Hyperparameter tuned = 50
# Epoch 31: Policy Loss=-0.03424862109124661, Value Loss=0.09914823245257139
# Training iteration 32, Hyperparameter tuned = 50
# Epoch 32: Policy Loss=-0.03667618952691555, Value Loss=0.06174972864799202
# Training iteration 33, Hyperparameter tuned = 50
# Epoch 33: Policy Loss=-0.03772951763123274, Value Loss=0.15011187350377442
# Training iteration 34, Hyperparameter tuned = 50
# Epoch 34: Policy Loss=-0.03483643263578415, Value Loss=0.06573588727973402
# Training iteration 35, Hyperparameter tuned = 50
# Epoch 35: Policy Loss=-0.030132733322679996, Value Loss=0.06242176563013345
# Training iteration 36, Hyperparameter tuned = 50
# Epoch 36: Policy Loss=-0.040513840168714524, Value Loss=0.06885324590839445
# Training iteration 37, Hyperparameter tuned = 50
# Epoch 37: Policy Loss=-0.0404921658243984, Value Loss=0.06911728608421981
# Training iteration 38, Hyperparameter tuned = 50
# Epoch 38: Policy Loss=-0.04200534716015682, Value Loss=0.10117143840529025
# Training iteration 39, Hyperparameter tuned = 50
# Epoch 39: Policy Loss=-0.044345714636147025, Value Loss=0.08445301715284587
# Training iteration 40, Hyperparameter tuned = 50
# Epoch 40: Policy Loss=-0.0406600159779191, Value Loss=0.07896418370306492
# Training iteration 41, Hyperparameter tuned = 50
# Epoch 41: Policy Loss=-0.04214292950928211, Value Loss=0.13164183138869703
# Training iteration 42, Hyperparameter tuned = 50
# Epoch 42: Policy Loss=-0.04209022782742977, Value Loss=0.10924042032565921
# Training iteration 43, Hyperparameter tuned = 50
# Epoch 43: Policy Loss=-0.04696344478055835, Value Loss=0.1113957748748362
# Training iteration 44, Hyperparameter tuned = 50
# Epoch 44: Policy Loss=-0.055736838644370436, Value Loss=0.09962006632238626
# Training iteration 45, Hyperparameter tuned = 50
# Epoch 45: Policy Loss=-0.05193061561323702, Value Loss=0.0809603608911857
# Training iteration 46, Hyperparameter tuned = 50
# Epoch 46: Policy Loss=-0.036005653738975525, Value Loss=0.20876623048447074
# Training iteration 47, Hyperparameter tuned = 50
# Epoch 47: Policy Loss=-0.03773447141051292, Value Loss=0.07275218293070793
# Training iteration 48, Hyperparameter tuned = 50
# Epoch 48: Policy Loss=-0.050609662123024465, Value Loss=0.24811107305809854
# Training iteration 49, Hyperparameter tuned = 50
# Epoch 49: Policy Loss=-0.026950704231858254, Value Loss=0.09887795479036868
# 2024-11-25 15:44:52,595	WARNING catalog.py:547 -- Custom ModelV2 should accept all custom options as **kwargs, instead of expecting them in config['custom_model_config']!
# 2024-11-25 15:44:52,651	INFO trainable.py:161 -- Trainable.setup took 11.019 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2024-11-25 15:44:52,658	WARNING util.py:61 -- Install gputil for GPU system monitoring.
# Training iteration 0, Hyperparameter tuned = 100
# Training iteration 1, Hyperparameter tuned = 100
# Epoch 1: Policy Loss=-0.006398083865642548, Value Loss=0.14317062594462185
# Training iteration 2, Hyperparameter tuned = 100
# Epoch 2: Policy Loss=-0.03382062748074532, Value Loss=0.13747797943651677
# Training iteration 3, Hyperparameter tuned = 100
# Epoch 3: Policy Loss=-0.03165035024285316, Value Loss=0.07473074875772
# Training iteration 4, Hyperparameter tuned = 100
# Epoch 4: Policy Loss=-0.02409469719044864, Value Loss=0.07348389531951398
# Training iteration 5, Hyperparameter tuned = 100
# Epoch 5: Policy Loss=-0.03428603395819664, Value Loss=0.0737431116681546
# Training iteration 6, Hyperparameter tuned = 100
# Epoch 6: Policy Loss=-0.03025009647011757, Value Loss=0.09638399704359472
# Training iteration 7, Hyperparameter tuned = 100
# Epoch 7: Policy Loss=-0.02652515396475792, Value Loss=0.07151495216879994
# Training iteration 8, Hyperparameter tuned = 100
# Epoch 8: Policy Loss=-0.02346951525658369, Value Loss=0.09542444727383553
# Training iteration 9, Hyperparameter tuned = 100
# Epoch 9: Policy Loss=-0.03119897627271712, Value Loss=0.12181353250518441
# Training iteration 10, Hyperparameter tuned = 100
# Epoch 10: Policy Loss=-0.028811671021394432, Value Loss=0.09038868279661984
# Training iteration 11, Hyperparameter tuned = 100
# Epoch 11: Policy Loss=-0.02735995078459382, Value Loss=0.09126067757606507
# Training iteration 12, Hyperparameter tuned = 100
# Epoch 12: Policy Loss=-0.02527144901454449, Value Loss=0.11920589113608003
# Training iteration 13, Hyperparameter tuned = 100
# Epoch 13: Policy Loss=-0.021994456897955386, Value Loss=0.06669485577382148
# Training iteration 14, Hyperparameter tuned = 100
# Epoch 14: Policy Loss=-0.02945359915494919, Value Loss=0.116446648882702
# Training iteration 15, Hyperparameter tuned = 100
# Epoch 15: Policy Loss=-0.02486761687323451, Value Loss=0.18793928431347012
# Training iteration 16, Hyperparameter tuned = 100
# Epoch 16: Policy Loss=-0.021023789402097464, Value Loss=0.11039848222397268
# Training iteration 17, Hyperparameter tuned = 100
# Epoch 17: Policy Loss=-0.029001767747104168, Value Loss=0.26205716280266644
# Training iteration 18, Hyperparameter tuned = 100
# Epoch 18: Policy Loss=-0.03410754600539803, Value Loss=0.09147727183997631
# Training iteration 19, Hyperparameter tuned = 100
# Epoch 19: Policy Loss=-0.02406508366577327, Value Loss=0.08807648495770991
# Training iteration 20, Hyperparameter tuned = 100
# Epoch 20: Policy Loss=-0.02953576507046819, Value Loss=0.08699063748121262
# Training iteration 21, Hyperparameter tuned = 100
# Epoch 21: Policy Loss=-0.03145345145836473, Value Loss=0.14599355465732514
# Training iteration 22, Hyperparameter tuned = 100
# Epoch 22: Policy Loss=-0.031577479168772696, Value Loss=0.08232274570968003
# Training iteration 23, Hyperparameter tuned = 100
# Epoch 23: Policy Loss=-0.02718618519604206, Value Loss=0.08555146291851998
# Training iteration 24, Hyperparameter tuned = 100
# Epoch 24: Policy Loss=-0.04329233143478632, Value Loss=0.06882172814104706
# Training iteration 25, Hyperparameter tuned = 100
# Epoch 25: Policy Loss=-0.025075236335396767, Value Loss=0.08276508616050705
# Training iteration 26, Hyperparameter tuned = 100
# Epoch 26: Policy Loss=-0.023786696791648864, Value Loss=0.1039344401564449
# Training iteration 27, Hyperparameter tuned = 100
# Epoch 27: Policy Loss=-0.029496766948141157, Value Loss=0.120536458613351
# Training iteration 28, Hyperparameter tuned = 100
# Epoch 28: Policy Loss=-0.0325464104115963, Value Loss=0.10886087353341281
# Training iteration 29, Hyperparameter tuned = 100
# Epoch 29: Policy Loss=-0.02192832315340638, Value Loss=0.08909549159929156
# Training iteration 30, Hyperparameter tuned = 100
# Epoch 30: Policy Loss=-0.032233748212456705, Value Loss=0.05323826455045491
# Training iteration 31, Hyperparameter tuned = 100
# Epoch 31: Policy Loss=-0.03457549741491675, Value Loss=0.08827896356582642
# Training iteration 32, Hyperparameter tuned = 100
# Epoch 32: Policy Loss=-0.023855345956981182, Value Loss=0.11059243417344987
# Training iteration 33, Hyperparameter tuned = 100
# Epoch 33: Policy Loss=-0.02567399013787508, Value Loss=0.10271136911585926
# Training iteration 34, Hyperparameter tuned = 100
# Epoch 34: Policy Loss=-0.0328089164942503, Value Loss=0.06888203208800406
# Training iteration 35, Hyperparameter tuned = 100
# Epoch 35: Policy Loss=-0.034064461383386514, Value Loss=0.12400337315164506
# Training iteration 36, Hyperparameter tuned = 100
# Epoch 36: Policy Loss=-0.02807006174232811, Value Loss=0.11520336176734418
# Training iteration 37, Hyperparameter tuned = 100
# Epoch 37: Policy Loss=-0.03643404595553875, Value Loss=0.14743867028038948
# Training iteration 38, Hyperparameter tuned = 100
# Epoch 38: Policy Loss=-0.029786227568984032, Value Loss=0.08142495261505246
# Training iteration 39, Hyperparameter tuned = 100
# Epoch 39: Policy Loss=-0.02228385031223297, Value Loss=0.1220259534753859
# Training iteration 40, Hyperparameter tuned = 100
# Epoch 40: Policy Loss=-0.03556282283738255, Value Loss=0.07789378206711263
# Training iteration 41, Hyperparameter tuned = 100
# Epoch 41: Policy Loss=-0.028701239861547947, Value Loss=0.06850712839979678
# Training iteration 42, Hyperparameter tuned = 100
# Epoch 42: Policy Loss=-0.024635358015075326, Value Loss=0.09167180673219263
# Training iteration 43, Hyperparameter tuned = 100
# Epoch 43: Policy Loss=-0.03628022577613592, Value Loss=0.0757758294325322
# Training iteration 44, Hyperparameter tuned = 100
# Epoch 44: Policy Loss=-0.030400021970272063, Value Loss=0.07750118432100862
# Training iteration 45, Hyperparameter tuned = 100
# Epoch 45: Policy Loss=-0.03486918091773987, Value Loss=0.055737590929493305
# Training iteration 46, Hyperparameter tuned = 100
# Epoch 46: Policy Loss=-0.026147569045424462, Value Loss=0.06654288485646248
# Training iteration 47, Hyperparameter tuned = 100
# Epoch 47: Policy Loss=-0.03464495284482837, Value Loss=0.07847757758572697
# Training iteration 48, Hyperparameter tuned = 100
# Epoch 48: Policy Loss=-0.02334042388945818, Value Loss=0.07559046446345746
# Training iteration 49, Hyperparameter tuned = 100
# Epoch 49: Policy Loss=-0.03332243360579014, Value Loss=0.12224585435353219
# 2024-11-25 16:04:45,034	WARNING catalog.py:547 -- Custom ModelV2 should accept all custom options as **kwargs, instead of expecting them in config['custom_model_config']!
# 2024-11-25 16:04:45,078	INFO trainable.py:161 -- Trainable.setup took 10.524 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2024-11-25 16:04:45,080	WARNING util.py:61 -- Install gputil for GPU system monitoring.
# Training iteration 0, Hyperparameter tuned = 200
# Training iteration 1, Hyperparameter tuned = 200
# Epoch 1: Policy Loss=-0.03173619272187352, Value Loss=0.18664179555140437
# Training iteration 2, Hyperparameter tuned = 200
# Epoch 2: Policy Loss=-0.04619578707963228, Value Loss=0.09109891845844686
# Training iteration 3, Hyperparameter tuned = 200
# Epoch 3: Policy Loss=-0.0253724183421582, Value Loss=0.1041819637734443
# Training iteration 4, Hyperparameter tuned = 200
# Epoch 4: Policy Loss=-0.04746631124988198, Value Loss=0.1783682401664555
# Training iteration 5, Hyperparameter tuned = 200
# Epoch 5: Policy Loss=-0.03427969895303249, Value Loss=0.07955291375983506
# Training iteration 6, Hyperparameter tuned = 200
# Epoch 6: Policy Loss=-0.013119543790817262, Value Loss=0.19543692477047445
# Training iteration 7, Hyperparameter tuned = 200
# Epoch 7: Policy Loss=-0.027579517886042595, Value Loss=0.1867255350574851
# Training iteration 8, Hyperparameter tuned = 200
# Epoch 8: Policy Loss=-0.029265824891626834, Value Loss=0.36309619605541227
# Training iteration 9, Hyperparameter tuned = 200
# Epoch 9: Policy Loss=-0.028245592564344404, Value Loss=0.3139886652957648
# Training iteration 10, Hyperparameter tuned = 200
# Epoch 10: Policy Loss=-0.026297455485910178, Value Loss=0.11544951177202165
# Training iteration 11, Hyperparameter tuned = 200
# Epoch 11: Policy Loss=-0.023523809760808943, Value Loss=0.09538331169635057
# Training iteration 12, Hyperparameter tuned = 200
# Epoch 12: Policy Loss=-0.029077861066907643, Value Loss=0.06410254421643913
# Training iteration 13, Hyperparameter tuned = 200
# Epoch 13: Policy Loss=-0.0189378897100687, Value Loss=0.09056074750609695
# Training iteration 14, Hyperparameter tuned = 200
# Epoch 14: Policy Loss=-0.008816452287137509, Value Loss=0.1624684927146882
# Training iteration 15, Hyperparameter tuned = 200
# Epoch 15: Policy Loss=-0.02222768098115921, Value Loss=0.06809450511354953
# Training iteration 16, Hyperparameter tuned = 200
# Epoch 16: Policy Loss=-0.010462514711543918, Value Loss=0.06932250656653195
# Training iteration 17, Hyperparameter tuned = 200
# Epoch 17: Policy Loss=-0.002664080411195755, Value Loss=0.20027755182236434
# Training iteration 18, Hyperparameter tuned = 200
# Epoch 18: Policy Loss=-0.0012325609102845192, Value Loss=0.15134774589911104
# Training iteration 19, Hyperparameter tuned = 200
# Epoch 19: Policy Loss=0.0011577533837407827, Value Loss=0.20595356247387828
# Training iteration 20, Hyperparameter tuned = 200
# Epoch 20: Policy Loss=0.004135344559326768, Value Loss=0.11382282320410013
# Training iteration 21, Hyperparameter tuned = 200
# Epoch 21: Policy Loss=-0.0060886858589947225, Value Loss=0.10336423389613629
# Training iteration 22, Hyperparameter tuned = 200
# Epoch 22: Policy Loss=-0.00286480825394392, Value Loss=0.08464352210052312
# Training iteration 23, Hyperparameter tuned = 200
# Epoch 23: Policy Loss=0.05124206721782684, Value Loss=0.07296496362425386
# Training iteration 24, Hyperparameter tuned = 200
# Epoch 24: Policy Loss=0.004190136261750013, Value Loss=0.21286124558188022
# Training iteration 25, Hyperparameter tuned = 200
# Epoch 25: Policy Loss=0.00230380492284894, Value Loss=0.09311231576837599
# Training iteration 26, Hyperparameter tuned = 200
# Epoch 26: Policy Loss=0.0017631714418530463, Value Loss=0.15612864907830953
# Training iteration 27, Hyperparameter tuned = 200
# Epoch 27: Policy Loss=0.004163366942666471, Value Loss=0.08956264154054225
# Training iteration 28, Hyperparameter tuned = 200
# Epoch 28: Policy Loss=0.0021223250404000284, Value Loss=0.1418988242186606
# Training iteration 29, Hyperparameter tuned = 200
# Epoch 29: Policy Loss=0.004521749727427959, Value Loss=0.15327811652328818
# Training iteration 30, Hyperparameter tuned = 200
# Epoch 30: Policy Loss=0.014338588658720255, Value Loss=0.09857222063466907
# Training iteration 31, Hyperparameter tuned = 200
# Epoch 31: Policy Loss=0.010974307544529438, Value Loss=0.14009787908755242
# Training iteration 32, Hyperparameter tuned = 200
# Epoch 32: Policy Loss=0.009960564207285643, Value Loss=0.07168243707623333
# Training iteration 33, Hyperparameter tuned = 200
# Epoch 33: Policy Loss=0.027635806500911714, Value Loss=0.4093457274604589
# Training iteration 34, Hyperparameter tuned = 200
# Epoch 34: Policy Loss=0.010245615998283029, Value Loss=0.1595090220682323
# Training iteration 35, Hyperparameter tuned = 200
# Epoch 35: Policy Loss=0.013483683387748897, Value Loss=0.0867319621425122
# Training iteration 36, Hyperparameter tuned = 200
# Epoch 36: Policy Loss=0.010128660574555397, Value Loss=0.07420278105419129
# Training iteration 37, Hyperparameter tuned = 200
# Epoch 37: Policy Loss=0.003813230488449335, Value Loss=0.17937595655210317
# Training iteration 38, Hyperparameter tuned = 200
# Epoch 38: Policy Loss=0.004431533087044954, Value Loss=0.08751412565819919
# Training iteration 39, Hyperparameter tuned = 200
# Epoch 39: Policy Loss=0.014914027266204357, Value Loss=0.11100424654781818
# Training iteration 40, Hyperparameter tuned = 200
# Epoch 40: Policy Loss=0.006950368764810264, Value Loss=0.09253246425185352
# Training iteration 41, Hyperparameter tuned = 200
# Epoch 41: Policy Loss=0.007442353293299675, Value Loss=0.16477238034829497
# Training iteration 42, Hyperparameter tuned = 200
# Epoch 42: Policy Loss=0.01710780899040401, Value Loss=0.096910001328215
# Training iteration 43, Hyperparameter tuned = 200
# Epoch 43: Policy Loss=0.0843321329401806, Value Loss=0.0806536476034671
# Training iteration 44, Hyperparameter tuned = 200
# Epoch 44: Policy Loss=0.054048912078142164, Value Loss=0.2776356052886695
# Training iteration 45, Hyperparameter tuned = 200
# Epoch 45: Policy Loss=0.08987972422270105, Value Loss=0.14118851786479353
# Training iteration 46, Hyperparameter tuned = 200
# Epoch 46: Policy Loss=0.06109596632421017, Value Loss=0.16736263326369227
# Training iteration 47, Hyperparameter tuned = 200
# Epoch 47: Policy Loss=0.01948264551348984, Value Loss=0.13319848757237196
# Training iteration 48, Hyperparameter tuned = 200
# Epoch 48: Policy Loss=0.05016530341701582, Value Loss=0.10110941531136632
# Training iteration 49, Hyperparameter tuned = 200
# Epoch 49: Policy Loss=0.057973152073100206, Value Loss=0.10470355609431863
# 2024-11-25 16:40:23,118	WARNING catalog.py:547 -- Custom ModelV2 should accept all custom options as **kwargs, instead of expecting them in config['custom_model_config']!
# 2024-11-25 16:40:23,175	WARNING util.py:61 -- Install gputil for GPU system monitoring.
# Training iteration 0, Hyperparameter tuned = 300
# Training iteration 1, Hyperparameter tuned = 300
# Epoch 1: Policy Loss=-0.03700927832629532, Value Loss=0.0507380591891706
# Training iteration 2, Hyperparameter tuned = 300
# Epoch 2: Policy Loss=-0.0379520820453763, Value Loss=0.08933048675768078
# Training iteration 3, Hyperparameter tuned = 300
# Epoch 3: Policy Loss=-0.050106734232977033, Value Loss=0.045398559411987664
# Training iteration 4, Hyperparameter tuned = 300
# Epoch 4: Policy Loss=-0.041092585418373344, Value Loss=0.04463474473450333
# Training iteration 5, Hyperparameter tuned = 300
# Epoch 5: Policy Loss=-0.024088615402579307, Value Loss=0.08704388823825866
# Training iteration 6, Hyperparameter tuned = 300
# Epoch 6: Policy Loss=-0.030103075392544268, Value Loss=0.20532349630258978
# Training iteration 7, Hyperparameter tuned = 300
# Epoch 7: Policy Loss=-0.014788086945191025, Value Loss=0.0899441834166646
# Training iteration 8, Hyperparameter tuned = 300
# Epoch 8: Policy Loss=-0.018978563378332182, Value Loss=0.058812965711113066
# Training iteration 9, Hyperparameter tuned = 300
# Epoch 9: Policy Loss=-0.0063539548963308335, Value Loss=0.07735853920690715
# Training iteration 10, Hyperparameter tuned = 300
# Epoch 10: Policy Loss=0.007169221416115761, Value Loss=0.05928168223705143
# Training iteration 11, Hyperparameter tuned = 300
# Epoch 11: Policy Loss=-4.3542496860027315e-05, Value Loss=0.0898390034493059
# Training iteration 12, Hyperparameter tuned = 300
# Epoch 12: Policy Loss=-6.479382514953613e-05, Value Loss=0.1125121993292123
# Training iteration 13, Hyperparameter tuned = 300
# Epoch 13: Policy Loss=0.0014024457335472106, Value Loss=0.11273601482622325
# Training iteration 14, Hyperparameter tuned = 300
# Epoch 14: Policy Loss=0.017666115537285806, Value Loss=0.22702721848152577
# Training iteration 15, Hyperparameter tuned = 300
# Epoch 15: Policy Loss=0.017901771892793475, Value Loss=0.06593637194484472
# Training iteration 16, Hyperparameter tuned = 300
# Epoch 16: Policy Loss=0.020163414240814744, Value Loss=0.09248500997200608
# Training iteration 17, Hyperparameter tuned = 300
# Epoch 17: Policy Loss=0.014648523852229119, Value Loss=0.06391528422944248
# Training iteration 18, Hyperparameter tuned = 300
# Epoch 18: Policy Loss=0.027402752209454775, Value Loss=0.06417469234205782
# Training iteration 19, Hyperparameter tuned = 300
# Epoch 19: Policy Loss=0.03291502557694912, Value Loss=0.07693878199905158
# Training iteration 20, Hyperparameter tuned = 300
# Epoch 20: Policy Loss=0.0335738212056458, Value Loss=0.06669013104401529
# Training iteration 21, Hyperparameter tuned = 300
# Epoch 21: Policy Loss=0.02946676254272461, Value Loss=0.053921831217594446
# Training iteration 22, Hyperparameter tuned = 300
# Epoch 22: Policy Loss=0.19705997943878173, Value Loss=0.055113656255416574
# Training iteration 23, Hyperparameter tuned = 300
# Epoch 23: Policy Loss=0.04707724700449035, Value Loss=0.035749426395632326
# Training iteration 24, Hyperparameter tuned = 300
# Epoch 24: Policy Loss=0.031634634267538785, Value Loss=0.03248845944879577
# Training iteration 25, Hyperparameter tuned = 300
# Epoch 25: Policy Loss=0.03458843355998397, Value Loss=0.0609370198007673
# Training iteration 26, Hyperparameter tuned = 300
# Epoch 26: Policy Loss=0.03609725169837475, Value Loss=0.04005389056634158
# Training iteration 27, Hyperparameter tuned = 300
# Epoch 27: Policy Loss=0.03539010675624013, Value Loss=0.048790904213674366
# Training iteration 28, Hyperparameter tuned = 300
# Epoch 28: Policy Loss=0.0897664961218834, Value Loss=0.08088752364739776
# Training iteration 29, Hyperparameter tuned = 300
# Epoch 29: Policy Loss=0.04295823719352484, Value Loss=0.051534312679432336
# Training iteration 30, Hyperparameter tuned = 300
# Epoch 30: Policy Loss=0.052025379207916556, Value Loss=0.059036422884091735
# Training iteration 31, Hyperparameter tuned = 300
# Epoch 31: Policy Loss=0.0498481726879254, Value Loss=0.0588569493079558
# Training iteration 32, Hyperparameter tuned = 300
# Epoch 32: Policy Loss=0.04329817327670753, Value Loss=0.12063430382870138
# Training iteration 33, Hyperparameter tuned = 300
# Epoch 33: Policy Loss=0.06420935690402985, Value Loss=0.03945110724773258
# Training iteration 34, Hyperparameter tuned = 300
# Epoch 34: Policy Loss=0.06774042878299952, Value Loss=0.046759999450296165
# Training iteration 35, Hyperparameter tuned = 300
# Epoch 35: Policy Loss=0.08440403968095779, Value Loss=0.058042417177930475
# Training iteration 36, Hyperparameter tuned = 300
# Epoch 36: Policy Loss=0.06165649487636984, Value Loss=0.0465081122983247
# Training iteration 37, Hyperparameter tuned = 300
# Epoch 37: Policy Loss=0.06820947432890534, Value Loss=0.0681738172005862
# Training iteration 38, Hyperparameter tuned = 300
# Epoch 38: Policy Loss=0.04997686333954334, Value Loss=0.07086573879700155
# Training iteration 39, Hyperparameter tuned = 300
# Epoch 39: Policy Loss=0.07289401165209711, Value Loss=0.07418638627510518
# Training iteration 40, Hyperparameter tuned = 300
# Epoch 40: Policy Loss=0.08904151175171136, Value Loss=0.07595228969119489
# Training iteration 41, Hyperparameter tuned = 300
# Epoch 41: Policy Loss=0.08668906321749091, Value Loss=0.04722873325459659
# Training iteration 42, Hyperparameter tuned = 300
# Epoch 42: Policy Loss=0.08633843421936035, Value Loss=0.07670051471330225
# Training iteration 43, Hyperparameter tuned = 300
# Epoch 43: Policy Loss=0.15495443565305322, Value Loss=0.10159157707821578
# Training iteration 44, Hyperparameter tuned = 300
# Epoch 44: Policy Loss=0.10422855334356428, Value Loss=0.05449711536522955
# Training iteration 45, Hyperparameter tuned = 300
# Epoch 45: Policy Loss=0.12003455103375017, Value Loss=0.059145455239340665
# Training iteration 46, Hyperparameter tuned = 300
# Epoch 46: Policy Loss=0.09243368221912533, Value Loss=0.05468399633653462
# Training iteration 47, Hyperparameter tuned = 300
# Epoch 47: Policy Loss=0.08869781319051981, Value Loss=0.04781495510134846
# Training iteration 48, Hyperparameter tuned = 300
# Epoch 48: Policy Loss=0.13336907795630396, Value Loss=0.050453639207407835
# Training iteration 49, Hyperparameter tuned = 300
# Epoch 49: Policy Loss=0.059658361151814464, Value Loss=0.09514322251547128
# 2024-11-25 17:36:02,036	WARNING catalog.py:547 -- Custom ModelV2 should accept all custom options as **kwargs, instead of expecting them in config['custom_model_config']!
# 2024-11-25 17:36:02,111	WARNING util.py:61 -- Install gputil for GPU system monitoring.
# Training iteration 0, Hyperparameter tuned = 400
# Training iteration 1, Hyperparameter tuned = 400
# Epoch 1: Policy Loss=-0.01952765613794327, Value Loss=0.1249958355538547
# Training iteration 2, Hyperparameter tuned = 400
# Epoch 2: Policy Loss=-0.019251867905259134, Value Loss=0.07450429816730321
# Training iteration 3, Hyperparameter tuned = 400
# Epoch 3: Policy Loss=-0.03189962025731802, Value Loss=0.10190617736428977
# Training iteration 4, Hyperparameter tuned = 400
# Epoch 4: Policy Loss=-0.021048419028520584, Value Loss=0.08878904196433723
# Training iteration 5, Hyperparameter tuned = 400
# Epoch 5: Policy Loss=-0.046148473992943764, Value Loss=0.046561852036975326
# Training iteration 6, Hyperparameter tuned = 400
# Epoch 6: Policy Loss=-0.039283707663416864, Value Loss=0.08353183215484022
# Training iteration 7, Hyperparameter tuned = 400
# Epoch 7: Policy Loss=-0.028334337417036295, Value Loss=0.1416443242598325
# Training iteration 8, Hyperparameter tuned = 400
# Epoch 8: Policy Loss=-0.028968203477561474, Value Loss=0.08789810392539948
# Training iteration 9, Hyperparameter tuned = 400
# Epoch 9: Policy Loss=-0.030780846495181324, Value Loss=0.07106502037495374
# Training iteration 10, Hyperparameter tuned = 400
# Epoch 10: Policy Loss=-0.04254984952509403, Value Loss=0.11200204511173069
# Training iteration 11, Hyperparameter tuned = 400
# Epoch 11: Policy Loss=-0.032352771181613206, Value Loss=0.05939231973141432
# Training iteration 12, Hyperparameter tuned = 400
# Epoch 12: Policy Loss=-0.02731237200088799, Value Loss=0.0712753043603152
# Training iteration 13, Hyperparameter tuned = 400
# Epoch 13: Policy Loss=-0.017487573027610778, Value Loss=0.07830217830836773
# Training iteration 14, Hyperparameter tuned = 400
# Epoch 14: Policy Loss=-0.008068414283916353, Value Loss=0.13727445198222996
# Training iteration 15, Hyperparameter tuned = 400
# Epoch 15: Policy Loss=0.007391187734901905, Value Loss=0.10213180772960186
# Training iteration 16, Hyperparameter tuned = 400
# Epoch 16: Policy Loss=0.006988618224859237, Value Loss=0.07969721538946033
# Training iteration 17, Hyperparameter tuned = 400
# Epoch 17: Policy Loss=0.0020701443403959275, Value Loss=0.14055323405191303
# Training iteration 18, Hyperparameter tuned = 400
# Epoch 18: Policy Loss=-0.005357229402288794, Value Loss=0.10873397569172084
# Training iteration 19, Hyperparameter tuned = 400
# Epoch 19: Policy Loss=0.005455796383321285, Value Loss=0.11349194718524813
# Training iteration 20, Hyperparameter tuned = 400
# Epoch 20: Policy Loss=0.00020932389423251153, Value Loss=0.08388486528769136
# Training iteration 21, Hyperparameter tuned = 400
# Epoch 21: Policy Loss=-0.002838522717356682, Value Loss=0.08179028496146203
# Training iteration 22, Hyperparameter tuned = 400
# Epoch 22: Policy Loss=0.019176055658608675, Value Loss=0.10688490372151137
# Training iteration 23, Hyperparameter tuned = 400
# Epoch 23: Policy Loss=0.0023529286682605743, Value Loss=0.11256157888099551
# Training iteration 24, Hyperparameter tuned = 400
# Epoch 24: Policy Loss=0.010122426766902209, Value Loss=0.0750399958062917
# Training iteration 25, Hyperparameter tuned = 400
# Epoch 25: Policy Loss=0.010612138770520687, Value Loss=0.14508581269532442
# Training iteration 26, Hyperparameter tuned = 400
# Epoch 26: Policy Loss=0.0036825298983603717, Value Loss=0.068776183584705
# Training iteration 27, Hyperparameter tuned = 400
# Epoch 27: Policy Loss=0.004322025692090392, Value Loss=0.10397283913567662
# Training iteration 28, Hyperparameter tuned = 400
# Epoch 28: Policy Loss=0.009466541148722172, Value Loss=0.1456258768308908
# Training iteration 29, Hyperparameter tuned = 400
# Epoch 29: Policy Loss=0.010761808161623776, Value Loss=0.07257679909467697
# Training iteration 30, Hyperparameter tuned = 400
# Epoch 30: Policy Loss=0.006103331167250872, Value Loss=0.07677871307358146
# Training iteration 31, Hyperparameter tuned = 400
# Epoch 31: Policy Loss=0.004609906785190105, Value Loss=0.06473314085043967
# Training iteration 32, Hyperparameter tuned = 400
# Epoch 32: Policy Loss=0.00866166832856834, Value Loss=0.059539268473163244
# Training iteration 33, Hyperparameter tuned = 400
# Epoch 33: Policy Loss=0.008220704514533281, Value Loss=0.05971988212317228
# Training iteration 34, Hyperparameter tuned = 400
# Epoch 34: Policy Loss=0.007710292898118496, Value Loss=0.06499516030307859
# Training iteration 35, Hyperparameter tuned = 400
# Epoch 35: Policy Loss=0.004330911925062537, Value Loss=0.05921376585029066
# Training iteration 36, Hyperparameter tuned = 400
# Epoch 36: Policy Loss=0.007289804555475712, Value Loss=0.08030524488072842
# Training iteration 37, Hyperparameter tuned = 400
# Epoch 37: Policy Loss=0.0022150637209415436, Value Loss=0.05125096476636827
# Training iteration 38, Hyperparameter tuned = 400
# Epoch 38: Policy Loss=0.015665539111942052, Value Loss=0.07554661534260959
# Training iteration 39, Hyperparameter tuned = 400
# Epoch 39: Policy Loss=0.01151762348599732, Value Loss=0.05224328758660704
# Training iteration 40, Hyperparameter tuned = 400
# Epoch 40: Policy Loss=0.030379468761384486, Value Loss=0.0662073172442615
# Training iteration 41, Hyperparameter tuned = 400
# Epoch 41: Policy Loss=0.017813761616125703, Value Loss=0.052777925222180784
# Training iteration 42, Hyperparameter tuned = 400
# Epoch 42: Policy Loss=0.010356298480182886, Value Loss=0.06670245689339936
# Training iteration 43, Hyperparameter tuned = 400
# Epoch 43: Policy Loss=0.019365123342722654, Value Loss=0.058225615806877615
# Training iteration 44, Hyperparameter tuned = 400
# Epoch 44: Policy Loss=0.02945642369799316, Value Loss=0.06612257086206227
# Training iteration 45, Hyperparameter tuned = 400
# Epoch 45: Policy Loss=0.011596909640356898, Value Loss=0.0632570939976722
# Training iteration 46, Hyperparameter tuned = 400
# Epoch 46: Policy Loss=0.051032940056174994, Value Loss=0.06577452697791158
# Training iteration 47, Hyperparameter tuned = 400
# Epoch 47: Policy Loss=0.026742485761642457, Value Loss=0.06507081105839461
# Training iteration 48, Hyperparameter tuned = 400
# Epoch 48: Policy Loss=0.010534299556165933, Value Loss=0.07243413754273206
# Training iteration 49, Hyperparameter tuned = 400
# Epoch 49: Policy Loss=0.01757663084194064, Value Loss=0.0727335691684857

# %% [markdown]
# Save the model

# %%
checkpoint_path = algo.save()
print(f"Checkpoint saved at: {checkpoint_path}")
# Out:
# Checkpoint saved at: TrainingResult(checkpoint=Checkpoint(filesystem=local, path=/tmp/tmp3dde7la9), metrics={'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'default_policy': {'custom_metrics': {}, 'learner_stats': {'cur_kl_coeff': 129431.96498219676, 'cur_lr': 0.004999999999999999, 'total_loss': 4938.084765930176, 'policy_loss': 0.01757663084194064, 'vf_loss': 0.0727335691684857, 'vf_explained_var': 0.52861546844244, 'kl': 0.03815127365291118, 'entropy': 9.985467059612274, 'entropy_coeff': 0.0}, 'model': {}, 'num_grad_updates_lifetime': 19800.5, 'diff_num_grad_updates_vs_sampler_policy': 199.5}}, 'num_env_steps_sampled': 25600, 'num_env_steps_trained': 25600, 'num_agent_steps_sampled': 25600, 'num_agent_steps_trained': 25600}, 'env_runners': {'episode_reward_max': -0.3758772503605857, 'episode_reward_min': -2.370826265527132, 'episode_reward_mean': -1.5309451746171383, 'episode_len_mean': 202.0, 'episode_media': {}, 'episodes_timesteps_total': 20200, 'policy_reward_min': {'default_policy': -2.370826265527132}, 'policy_reward_max': {'default_policy': -0.3758772503605857}, 'policy_reward_mean': {'default_policy': -1.5309451746171383}, 'custom_metrics': {'final_net_price_mean': 13183.84, 'final_net_price_min': 8772.78, 'final_net_price_max': 16924.744}, 'hist_stats': {'episode_reward': [-0.9273107093342035, -1.138362577619271, -0.7831770123356919, -1.0564804165528607, -0.9988835445227846, -1.2317357930697954, -0.3758772503605857, -1.6682510066768783, -1.31976225175541, -1.6831908563240725, -1.9902789352751875, -0.7706289952937758, -1.5770640656874924, -1.205667860516326, -1.278219888455629, -0.9106456245936505, -1.1230191303382324, -1.5783113378310847, -1.169946058517133, -1.3576698909657459, -1.5012081426107593, -1.9343014845694377, -1.312030201927871, -2.1172722810930145, -1.6840331248388758, -1.885225010258972, -2.0409994101296935, -1.474862366994811, -1.798867082497814, -1.2851465725856894, -1.67681027849249, -2.0046994382761762, -1.7893181762626043, -1.0883038426174916, -1.6369164744075821, -1.752490161750429, -1.5751259944330012, -1.3223835417752772, -1.7347614119890629, -2.049538548260303, -1.6775534325918862, -1.3182507060338533, -1.8275122041512826, -1.6799545111494896, -1.605937111324096, -2.370826265527132, -1.5463828132104036, -1.9220031620249074, -1.5296464848294753, -1.3623771262529354, -1.383989046633247, -1.5402525232646065, -1.7652480887117197, -1.5285899265880372, -1.6640959353280742, -1.6908228919359136, -1.5184396185469151, -1.6167134117540385, -1.4562564603106458, -1.5750149807485718, -1.6216331245940814, -1.556501065485727, -1.4546326396386147, -1.6845654932137952, -1.5055397271679858, -1.689073148358749, -1.5830356675468154, -1.7112406186118037, -1.58712518292749, -1.5684859266189701, -1.6114744754145545, -1.5248506244323405, -1.5884668872411, -1.6523646379638177, -1.606620060053685, -1.677402063617923, -1.5529783063945177, -1.5839619172704293, -1.7922150349661727, -1.5901651603222684, -1.5175140825441849, -1.5250803223906535, -1.6471925088198314, -1.6030660798276848, -1.516975681115606, -1.5132180817098075, -1.5017937536265151, -1.532032405331282, -1.5903653439844727, -1.5677842911621636, -1.544311617704384, -1.5993484916967102, -1.6118955660822478, -1.5158784786525867, -1.5626125626322047, -1.3615386319924365, -1.2108149022110362, -1.7054883241568055, -1.4306594237320618, -1.5059716977858713], 'episode_lengths': [202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202, 202], 'policy_default_policy_reward': [-0.9273107093342035, -1.138362577619271, -0.78317701 ...
